# %% [markdown]
# <a href="https://colab.research.google.com/github/ollema/nlp2019/blob/master/A1_BiLSTM_WSD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook uses parts of the RNN example:
# ```
# http://www.cse.chalmers.se/~richajo/nlp2019/l4/Text%20classification%20using%20RNNs.html
# ```
#
# To run this notebook, just press "Run all"!

# %%
# !wget https://raw.githubusercontent.com/ollema/nlp2019/master/a1_data/wsd_train.txt
# Out:
# --2019-11-13 09:39:24--  https://raw.githubusercontent.com/ollema/nlp2019/master/a1_data/wsd_train.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 46435645 (44M) [text/plain]
# Saving to: ‘wsd_train.txt.1’
#
# wsd_train.txt.1     100%[===================>]  44.28M   100MB/s    in 0.4s
#
# 2019-11-13 09:39:25 (100 MB/s) - ‘wsd_train.txt.1’ saved [46435645/46435645]

# %%
import torch
from torch import nn
import time
import torchtext

from collections import defaultdict, OrderedDict
import copy
import random
random.seed(1)
torch.manual_seed(1)

import matplotlib.pyplot as plt

# %config InlineBackend.figure_format = 'retina' 
plt.style.use('seaborn')


class WSDClassifier(nn.Module):
    
    def __init__(self, text_field, class_field, emb_dim, hidden_size, update_pretrained=False):
        super().__init__()        

        self.n = 70

        voc_size = len(text_field.vocab)
        n_senses = len(class_field.vocab)   

        self.dropout = nn.Dropout(0.25)
        self.dropout2d = nn.Dropout2d(0.05)
        
        self.embedding = nn.Embedding(voc_size, emb_dim)

        if text_field.vocab.vectors is not None:
            self.embedding.weight = torch.nn.Parameter(text_field.vocab.vectors, requires_grad=update_pretrained)
        
        # bidirectional LSTM
        self.lstm = nn.LSTM(input_size=emb_dim, hidden_size=hidden_size, bidirectional=True, num_layers=1)
        self.num_directions = 2

        # hidden layer
        self.a = nn.Linear(2 * hidden_size, 2 * hidden_size)

        # classification layers
        self.y = nn.Linear(2 * hidden_size, n_senses)
        self.softmax = nn.Softmax(dim=1)

        
    def forward(self, texts):
        embedded = self.embedding(texts)

        dropped_embedded = self.dropout2d(embedded)

        output, _ = self.lstm(dropped_embedded)
        # output, _ = self.lstm(embedded)

        self.batch_size = output.size()[1]

        output = output.view(-1, self.batch_size, self.num_directions, self.lstm.hidden_size)
        forward = output[70 - 1, :, 0, :]
        backward = output[70, :, 1, :]
        output = torch.cat([forward, backward], dim=1)
        dropped_output = self.dropout(output)
        
        hidden = self.a(dropped_output)

        dropped_hidden = self.dropout(hidden)

        return self.softmax(self.y(dropped_hidden))


def read_data(corpus_file, doc_start, with_padding = True):
    """ Parses input file and returns filtered datasets for each word-type in corpus as well as
    list of word-types found in corpus. """
    # Initialization
    text = torchtext.data.Field(sequential=True, tokenize=lambda x: x.split())
    label = torchtext.data.LabelField(is_target=True)
    datafields = [('text', text), ('label', label)]
    label_column = 0

    if with_padding == True:
        pad_string = '<pad>'
        sentence_length = 140
        half_sentence_length = int(sentence_length/2)
        with open(corpus_file, encoding='utf-8') as f:
            examples = []
            for line in f:
                columns = line.strip().split(maxsplit=doc_start)
                position_of_wordtype = int(columns[2])

                # Split the long string doc into array and extract words before the wordtype.
                doc = columns[-1]
                doc_string_vector = doc.split()
                temp_pad = [pad_string for x in range(0,70)]

                padded_doc = []
                padded_doc.extend(temp_pad)
                padded_doc.extend(doc_string_vector)
                padded_doc.extend(temp_pad)

                sliced_doc = padded_doc[position_of_wordtype:position_of_wordtype + 140]

                if len(sliced_doc) != 140:
                    print(sliced_doc)
                    raise RuntimeError

                sliced_doc = " ".join(sliced_doc)
                label = columns[label_column]

                examples.append(torchtext.data.Example.fromlist([sliced_doc, label], datafields))
    else:
        with open(corpus_file, encoding='utf-8') as f:
            examples = []
            for line in f:
                columns = line.strip().split(maxsplit=doc_start)
                doc = columns[-1]
                label = columns[label_column]
                examples.append(torchtext.data.Example.fromlist([doc, label], datafields))
    unfiltered_data = torchtext.data.Dataset(examples, datafields,filter_pred=None)

    # Read complete dataset to get set of word-types. E.i 'keep', 'line'...
    filter_function = None
    word_types = set()
    for example in unfiltered_data.examples:
        word_types.add(example.label.split("%", 1)[0])
    word_types = list(word_types)

    # Create filtered datasets for each word-type
    filtered_datasets = OrderedDict()
    for a_word_type in word_types:
        filter_function = lambda ex: ex.label.split("%", 1)[0] == a_word_type
        text = torchtext.data.Field(sequential=True, tokenize=lambda x: x.split())
        label = torchtext.data.LabelField(is_target=True)
        datafields = [('text', text), ('label', label)]

        filtered_data_set = torchtext.data.Dataset(examples, datafields, filter_pred=filter_function)
        filtered_datasets[a_word_type] = (filtered_data_set, text, label)
    return filtered_datasets


def evaluate_validation(scores, loss_function, gold):
    guesses = scores.argmax(dim=1)
    n_correct = (guesses == gold).sum().item()
    return n_correct, loss_function(scores, gold).item()


use_pretrained = True
filtered_datasets = read_data('wsd_train.txt', doc_start=4)

if use_pretrained:
    print('We are using pre-trained word embeddings.')
else:
    print('We are training word embeddings from scratch.')

models = OrderedDict()
max_verifications = OrderedDict()
model_vocabs = OrderedDict()
model_label_vocabs = OrderedDict()

for word_type, filtered_dataset in filtered_datasets.items():
    dataset = filtered_dataset[0]
    text = filtered_dataset[1]
    label = filtered_dataset[2]

    train, valid = dataset.split([0.8, 0.2])

    if use_pretrained:
        text.build_vocab(train, vectors="glove.6B.100d")
    else:        
        text.build_vocab(train, max_size=10000)
    
    model_vocabs[word_type] = text.vocab
    label.build_vocab(train)
    model_label_vocabs[word_type] = label.vocab
        
    model = WSDClassifier(text, label, emb_dim=100, hidden_size=74, update_pretrained=True)

    device = 'cuda'
    model.to(device)

    train_iterator = torchtext.data.Iterator(
        train,
        device=device,
        batch_size=128,
        repeat=False,
        train=True,
        sort=False)

    valid_iterator = torchtext.data.Iterator(
        valid,
        device=device,
        batch_size=128,
        repeat=False,
        train=False,
        sort=False)

    loss_function = torch.nn.CrossEntropyLoss()   
    optimizer = torch.optim.SGD(model.parameters(), lr=2, momentum=0.1) 
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.96)


    train_batches = list(train_iterator)
    valid_batches = list(valid_iterator)

    history = defaultdict(list)
    max_val_acc = -1

    print(f"Training {word_type}...")
    for i in range(50):
        
        t0 = time.time()
        
        loss_sum = 0
        n_batches = 0

        model.train()
        
        for batch in train_batches:
                        
            scores = model(batch.text)
            loss = loss_function(scores, batch.label)

            optimizer.zero_grad()            
            loss.backward()
            optimizer.step()

            loss_sum += loss.item()
            n_batches += 1
        
        train_loss = loss_sum / n_batches
        history['train_loss'].append(train_loss)
        
        n_correct = 0
        n_valid = len(valid)
        loss_sum = 0
        n_batches = 0

        model.eval()
        
        for batch in valid_batches:
            scores = model(batch.text)
            n_corr_batch, loss_batch = evaluate_validation(scores, loss_function, batch.label)
            loss_sum += loss_batch
            n_correct += n_corr_batch
            n_batches += 1
        val_acc = n_correct / n_valid
        val_loss = loss_sum / n_batches

        history['val_loss'].append(val_loss)
        history['val_acc'].append(val_acc)

        if val_acc > max_val_acc:
            max_val_acc = val_acc
            models[word_type] = copy.deepcopy(model)
            max_verifications[word_type] = max_val_acc
        
        scheduler.step()

        t1 = time.time()

        if (i+1) % 10 == 0:
            print(f'Epoch {i+1}: train loss = {train_loss:.4f}, val loss = {val_loss:.4f}, val acc: {val_acc:.4f}, time = {t1-t0:.4f}, lr = {optimizer.param_groups[0]["lr"]}')

    plt.plot(history['train_loss'])
    plt.plot(history['val_loss'])
    plt.plot(history['val_acc'])
    plt.legend(['training loss', 'validation loss', 'validation accuracy'])
    plt.show()
# Out:
# .vector_cache/glove.6B.zip: 0.00B [00:00, ?B/s]
# We are using pre-trained word embeddings.
# .vector_cache/glove.6B.zip: 862MB [06:30, 2.21MB/s]
# 100%|█████████▉| 399490/400000 [00:19<00:00, 20052.00it/s]
# Training common...
# 100%|█████████▉| 399490/400000 [00:30<00:00, 20052.00it/s]
# Epoch 10: train loss = 1.0471, val loss = 1.0874, val acc: 0.6476, time = 0.3745, lr = 1.3296652719830016
# Epoch 20: train loss = 0.9916, val loss = 1.0596, val acc: 0.6734, time = 0.3713, lr = 0.8840048677588148
# Epoch 30: train loss = 0.9561, val loss = 1.0627, val acc: 0.6705, time = 0.3736, lr = 0.5877152864614109
# Epoch 40: train loss = 0.9317, val loss = 1.0624, val acc: 0.6762, time = 0.3722, lr = 0.39073230311063983
# Epoch 50: train loss = 0.9143, val loss = 1.0664, val acc: 0.6619, time = 0.3739, lr = 0.25977158704407677
# Training force...
# Epoch 10: train loss = 1.5174, val loss = 1.4936, val acc: 0.7713, time = 0.5942, lr = 1.3296652719830016
# Epoch 20: train loss = 1.4492, val loss = 1.4750, val acc: 0.7913, time = 0.6001, lr = 0.8840048677588148
# Epoch 30: train loss = 1.4243, val loss = 1.4442, val acc: 0.8167, time = 0.6102, lr = 0.5877152864614109
# Epoch 40: train loss = 1.4114, val loss = 1.4608, val acc: 0.8004, time = 0.6105, lr = 0.39073230311063983
# Epoch 50: train loss = 1.4004, val loss = 1.4426, val acc: 0.8203, time = 0.6055, lr = 0.25977158704407677
# Training critical...
# Epoch 10: train loss = 1.1092, val loss = 1.1490, val acc: 0.7476, time = 0.3369, lr = 1.3296652719830016
# Epoch 20: train loss = 1.0617, val loss = 1.1197, val acc: 0.7764, time = 0.3393, lr = 0.8840048677588148
# Epoch 30: train loss = 1.0379, val loss = 1.0964, val acc: 0.8019, time = 0.3415, lr = 0.5877152864614109
# Epoch 40: train loss = 1.0177, val loss = 1.0862, val acc: 0.8019, time = 0.3425, lr = 0.39073230311063983
# Epoch 50: train loss = 1.0091, val loss = 1.0883, val acc: 0.8051, time = 0.3373, lr = 0.25977158704407677
# Training major...
# Epoch 10: train loss = 1.0868, val loss = 1.2244, val acc: 0.4884, time = 0.3369, lr = 1.3296652719830016
# Epoch 20: train loss = 0.9781, val loss = 1.0866, val acc: 0.6545, time = 0.3362, lr = 0.8840048677588148
# Epoch 30: train loss = 0.9468, val loss = 1.0724, val acc: 0.6512, time = 0.3322, lr = 0.5877152864614109
# Epoch 40: train loss = 0.9243, val loss = 1.0837, val acc: 0.6312, time = 0.3335, lr = 0.39073230311063983
# Epoch 50: train loss = 0.9066, val loss = 1.0948, val acc: 0.6246, time = 0.3330, lr = 0.25977158704407677
# Training point...
# Epoch 10: train loss = 1.7046, val loss = 1.6887, val acc: 0.5849, time = 0.4003, lr = 1.3296652719830016
# Epoch 20: train loss = 1.7027, val loss = 1.6886, val acc: 0.5849, time = 0.4026, lr = 0.8840048677588148
# Epoch 30: train loss = 1.7021, val loss = 1.6886, val acc: 0.5849, time = 0.4021, lr = 0.5877152864614109
# Epoch 40: train loss = 1.7025, val loss = 1.6883, val acc: 0.5849, time = 0.4045, lr = 0.39073230311063983
# Epoch 50: train loss = 1.7022, val loss = 1.6882, val acc: 0.5849, time = 0.4005, lr = 0.25977158704407677
# Training see...
# Epoch 10: train loss = 1.9174, val loss = 1.8996, val acc: 0.6353, time = 1.3638, lr = 1.3296652719830016
# Epoch 20: train loss = 1.9174, val loss = 1.8996, val acc: 0.6353, time = 1.3581, lr = 0.8840048677588148
# Epoch 30: train loss = 1.9174, val loss = 1.8996, val acc: 0.6353, time = 1.4027, lr = 0.5877152864614109
# Epoch 40: train loss = 1.9174, val loss = 1.8996, val acc: 0.6353, time = 1.4109, lr = 0.39073230311063983
# Epoch 50: train loss = 1.9174, val loss = 1.8996, val acc: 0.6353, time = 1.4064, lr = 0.25977158704407677
# Training bring...
# Epoch 10: train loss = 1.7111, val loss = 1.6964, val acc: 0.5972, time = 0.5367, lr = 1.3296652719830016
# Epoch 20: train loss = 1.6313, val loss = 1.6514, val acc: 0.6212, time = 0.5423, lr = 0.8840048677588148
# Epoch 30: train loss = 1.5930, val loss = 1.6450, val acc: 0.6273, time = 0.5364, lr = 0.5877152864614109
# Epoch 40: train loss = 1.5663, val loss = 1.6507, val acc: 0.6293, time = 0.5363, lr = 0.39073230311063983
# Epoch 50: train loss = 1.5489, val loss = 1.6392, val acc: 0.6293, time = 0.5327, lr = 0.25977158704407677
# Training extend...
# Epoch 10: train loss = 1.6002, val loss = 1.5897, val acc: 0.5653, time = 0.5336, lr = 1.3296652719830016
# Epoch 20: train loss = 1.5407, val loss = 1.5510, val acc: 0.6020, time = 0.5339, lr = 0.8840048677588148
# Epoch 30: train loss = 1.4980, val loss = 1.5335, val acc: 0.6184, time = 0.5297, lr = 0.5877152864614109
# Epoch 40: train loss = 1.4438, val loss = 1.4897, val acc: 0.6755, time = 0.5267, lr = 0.39073230311063983
# Epoch 50: train loss = 1.4243, val loss = 1.4880, val acc: 0.6714, time = 0.5275, lr = 0.25977158704407677
# Training build...
# Epoch 10: train loss = 2.0409, val loss = 2.0924, val acc: 0.3527, time = 0.5327, lr = 1.3296652719830016
# Epoch 20: train loss = 1.9837, val loss = 2.0397, val acc: 0.4228, time = 0.5299, lr = 0.8840048677588148
# Epoch 30: train loss = 1.9531, val loss = 1.9977, val acc: 0.4669, time = 0.5373, lr = 0.5877152864614109
# Epoch 40: train loss = 1.9364, val loss = 1.9925, val acc: 0.4749, time = 0.5324, lr = 0.39073230311063983
# Epoch 50: train loss = 1.9257, val loss = 2.0007, val acc: 0.4589, time = 0.5303, lr = 0.25977158704407677
# Training active...
# Epoch 10: train loss = 1.1167, val loss = 1.0253, val acc: 0.8731, time = 0.3035, lr = 1.3296652719830016
# Epoch 20: train loss = 1.0352, val loss = 1.0218, val acc: 0.8657, time = 0.2988, lr = 0.8840048677588148
# Epoch 30: train loss = 1.0231, val loss = 1.0201, val acc: 0.8657, time = 0.3003, lr = 0.5877152864614109
# Epoch 40: train loss = 1.0110, val loss = 1.0175, val acc: 0.8657, time = 0.3044, lr = 0.39073230311063983
# Epoch 50: train loss = 1.0056, val loss = 1.0186, val acc: 0.8731, time = 0.3047, lr = 0.25977158704407677
# Training national...
# Epoch 10: train loss = 1.3231, val loss = 1.3616, val acc: 0.6667, time = 0.4720, lr = 1.3296652719830016
# Epoch 20: train loss = 1.2241, val loss = 1.2392, val acc: 0.8019, time = 0.4690, lr = 0.8840048677588148
# Epoch 30: train loss = 1.1949, val loss = 1.2295, val acc: 0.8065, time = 0.4665, lr = 0.5877152864614109
# Epoch 40: train loss = 1.1717, val loss = 1.2368, val acc: 0.7925, time = 0.4699, lr = 0.39073230311063983
# Epoch 50: train loss = 1.1717, val loss = 1.2267, val acc: 0.8112, time = 0.4685, lr = 0.25977158704407677
# Training position...
# Epoch 10: train loss = 1.4993, val loss = 1.4840, val acc: 0.5495, time = 0.4661, lr = 1.3296652719830016
# Epoch 20: train loss = 1.3309, val loss = 1.4163, val acc: 0.6351, time = 0.4657, lr = 0.8840048677588148
# Epoch 30: train loss = 1.2640, val loss = 1.3610, val acc: 0.7072, time = 0.4856, lr = 0.5877152864614109
# Epoch 40: train loss = 1.2301, val loss = 1.3563, val acc: 0.6982, time = 0.4819, lr = 0.39073230311063983
# Epoch 50: train loss = 1.2133, val loss = 1.3424, val acc: 0.7095, time = 0.4724, lr = 0.25977158704407677
# Training professional...
# Epoch 10: train loss = 1.0938, val loss = 1.1056, val acc: 0.8229, time = 0.4517, lr = 1.3296652719830016
# Epoch 20: train loss = 1.0662, val loss = 1.0874, val acc: 0.8254, time = 0.4569, lr = 0.8840048677588148
# Epoch 30: train loss = 1.0508, val loss = 1.0855, val acc: 0.8329, time = 0.4433, lr = 0.5877152864614109
# Epoch 40: train loss = 1.0365, val loss = 1.0861, val acc: 0.8254, time = 0.4374, lr = 0.39073230311063983
# Epoch 50: train loss = 1.0429, val loss = 1.0840, val acc: 0.8329, time = 0.4494, lr = 0.25977158704407677
# Training security...
# Epoch 10: train loss = 1.4743, val loss = 1.5028, val acc: 0.6721, time = 0.4853, lr = 1.3296652719830016
# Epoch 20: train loss = 1.4328, val loss = 1.4243, val acc: 0.7436, time = 0.4806, lr = 0.8840048677588148
# Epoch 30: train loss = 1.3428, val loss = 1.3388, val acc: 0.8406, time = 0.4766, lr = 0.5877152864614109
# Epoch 40: train loss = 1.3115, val loss = 1.3394, val acc: 0.8383, time = 0.4817, lr = 0.39073230311063983
# Epoch 50: train loss = 1.2972, val loss = 1.3263, val acc: 0.8453, time = 0.4790, lr = 0.25977158704407677
# Training positive...
# Epoch 10: train loss = 1.1985, val loss = 1.2646, val acc: 0.6296, time = 0.2628, lr = 1.3296652719830016
# Epoch 20: train loss = 1.0963, val loss = 1.1793, val acc: 0.7202, time = 0.2645, lr = 0.8840048677588148
# Epoch 30: train loss = 1.0520, val loss = 1.1114, val acc: 0.8066, time = 0.2661, lr = 0.5877152864614109
# Epoch 40: train loss = 1.0369, val loss = 1.1270, val acc: 0.7695, time = 0.2627, lr = 0.39073230311063983
# Epoch 50: train loss = 1.0249, val loss = 1.1026, val acc: 0.7942, time = 0.2652, lr = 0.25977158704407677
# Training order...
# Epoch 10: train loss = 1.2262, val loss = 1.2525, val acc: 0.6683, time = 0.4442, lr = 1.3296652719830016
# Epoch 20: train loss = 1.0730, val loss = 1.0945, val acc: 0.8354, time = 0.4490, lr = 0.8840048677588148
# Epoch 30: train loss = 1.0255, val loss = 1.0598, val acc: 0.8628, time = 0.4524, lr = 0.5877152864614109
# Epoch 40: train loss = 1.0068, val loss = 1.0611, val acc: 0.8479, time = 0.4450, lr = 0.39073230311063983
# Epoch 50: train loss = 0.9886, val loss = 1.0579, val acc: 0.8529, time = 0.4504, lr = 0.25977158704407677
# Training bad...
# Epoch 10: train loss = 0.9867, val loss = 0.9898, val acc: 0.7514, time = 0.3718, lr = 1.3296652719830016
# Epoch 20: train loss = 0.9262, val loss = 0.9809, val acc: 0.7630, time = 0.3735, lr = 0.8840048677588148
# Epoch 30: train loss = 0.8936, val loss = 0.9397, val acc: 0.8006, time = 0.3764, lr = 0.5877152864614109
# Epoch 40: train loss = 0.8862, val loss = 0.9402, val acc: 0.8092, time = 0.3652, lr = 0.39073230311063983
# Epoch 50: train loss = 0.8683, val loss = 0.9313, val acc: 0.8092, time = 0.3681, lr = 0.25977158704407677
# Training hold...
# Epoch 10: train loss = 1.9814, val loss = 1.9285, val acc: 0.6144, time = 0.6842, lr = 1.3296652719830016
# Epoch 20: train loss = 1.8943, val loss = 1.8938, val acc: 0.6480, time = 0.6811, lr = 0.8840048677588148
# Epoch 30: train loss = 1.8581, val loss = 1.8575, val acc: 0.6832, time = 0.6782, lr = 0.5877152864614109
# Epoch 40: train loss = 1.8303, val loss = 1.8419, val acc: 0.6976, time = 0.6657, lr = 0.39073230311063983
# Epoch 50: train loss = 1.8246, val loss = 1.8438, val acc: 0.7008, time = 0.6601, lr = 0.25977158704407677
# Training find...
# Epoch 10: train loss = 1.8252, val loss = 1.7629, val acc: 0.6958, time = 0.5069, lr = 1.3296652719830016
# Epoch 20: train loss = 1.7813, val loss = 1.7462, val acc: 0.7125, time = 0.5169, lr = 0.8840048677588148
# Epoch 30: train loss = 1.7560, val loss = 1.7287, val acc: 0.7292, time = 0.5038, lr = 0.5877152864614109
# Epoch 40: train loss = 1.7360, val loss = 1.7265, val acc: 0.7292, time = 0.5003, lr = 0.39073230311063983
# Epoch 50: train loss = 1.7264, val loss = 1.7206, val acc: 0.7375, time = 0.4895, lr = 0.25977158704407677
# Training line...
# Epoch 10: train loss = 1.6919, val loss = 1.6915, val acc: 0.8512, time = 1.1651, lr = 1.3296652719830016
# Epoch 20: train loss = 1.6919, val loss = 1.6915, val acc: 0.8512, time = 1.1742, lr = 0.8840048677588148
# Epoch 30: train loss = 1.6919, val loss = 1.6915, val acc: 0.8512, time = 1.1661, lr = 0.5877152864614109
# Epoch 40: train loss = 1.6919, val loss = 1.6915, val acc: 0.8512, time = 1.1746, lr = 0.39073230311063983
# Epoch 50: train loss = 1.6919, val loss = 1.6915, val acc: 0.8512, time = 1.1608, lr = 0.25977158704407677
# Training keep...
# Epoch 10: train loss = 1.9018, val loss = 1.8715, val acc: 0.6747, time = 1.1321, lr = 1.3296652719830016
# Epoch 20: train loss = 1.8317, val loss = 1.8463, val acc: 0.6988, time = 1.1539, lr = 0.8840048677588148
# Epoch 30: train loss = 1.7686, val loss = 1.7953, val acc: 0.7498, time = 1.1388, lr = 0.5877152864614109
# Epoch 40: train loss = 1.7403, val loss = 1.7867, val acc: 0.7544, time = 1.1385, lr = 0.39073230311063983
# Epoch 50: train loss = 1.7294, val loss = 1.7800, val acc: 0.7627, time = 1.1273, lr = 0.25977158704407677
# Training serve...
# Epoch 10: train loss = 1.8072, val loss = 1.7909, val acc: 0.5825, time = 0.6402, lr = 1.3296652719830016
# Epoch 20: train loss = 1.7379, val loss = 1.7695, val acc: 0.5990, time = 0.6393, lr = 0.8840048677588148
# Epoch 30: train loss = 1.6918, val loss = 1.7472, val acc: 0.6139, time = 0.6352, lr = 0.5877152864614109
# Epoch 40: train loss = 1.6675, val loss = 1.7319, val acc: 0.6403, time = 0.6363, lr = 0.39073230311063983
# Epoch 50: train loss = 1.6525, val loss = 1.7269, val acc: 0.6436, time = 0.6397, lr = 0.25977158704407677
# Training place...
# Epoch 10: train loss = 1.5341, val loss = 1.6203, val acc: 0.5415, time = 0.4329, lr = 1.3296652719830016
# Epoch 20: train loss = 1.4568, val loss = 1.4039, val acc: 0.7176, time = 0.4272, lr = 0.8840048677588148
# Epoch 30: train loss = 1.4206, val loss = 1.3718, val acc: 0.7280, time = 0.4295, lr = 0.5877152864614109
# Epoch 40: train loss = 1.3844, val loss = 1.3410, val acc: 0.7772, time = 0.4318, lr = 0.39073230311063983
# Epoch 50: train loss = 1.3670, val loss = 1.3209, val acc: 0.8135, time = 0.4367, lr = 0.25977158704407677
# Training time...
# Epoch 10: train loss = 1.3748, val loss = 1.3336, val acc: 0.5401, time = 0.4653, lr = 1.3296652719830016
# Epoch 20: train loss = 1.1693, val loss = 1.1541, val acc: 0.7406, time = 0.4635, lr = 0.8840048677588148
# Epoch 30: train loss = 1.1021, val loss = 1.1248, val acc: 0.7736, time = 0.4822, lr = 0.5877152864614109
# Epoch 40: train loss = 1.0711, val loss = 1.1363, val acc: 0.7571, time = 0.4742, lr = 0.39073230311063983
# Epoch 50: train loss = 1.0514, val loss = 1.1398, val acc: 0.7594, time = 0.4735, lr = 0.25977158704407677
# Training lead...
# Epoch 10: train loss = 1.8376, val loss = 1.7939, val acc: 0.4804, time = 0.5430, lr = 1.3296652719830016
# Epoch 20: train loss = 1.7386, val loss = 1.7557, val acc: 0.5098, time = 0.5438, lr = 0.8840048677588148
# Epoch 30: train loss = 1.6838, val loss = 1.7610, val acc: 0.5059, time = 0.5512, lr = 0.5877152864614109
# Epoch 40: train loss = 1.6523, val loss = 1.7107, val acc: 0.5569, time = 0.5476, lr = 0.39073230311063983
# Epoch 50: train loss = 1.6327, val loss = 1.7077, val acc: 0.5667, time = 0.5497, lr = 0.25977158704407677
# Training case...
# Epoch 10: train loss = 1.8211, val loss = 1.8184, val acc: 0.4565, time = 0.5133, lr = 1.3296652719830016
# Epoch 20: train loss = 1.7088, val loss = 1.7765, val acc: 0.4820, time = 0.5027, lr = 0.8840048677588148
# Epoch 30: train loss = 1.6544, val loss = 1.7528, val acc: 0.5117, time = 0.5111, lr = 0.5877152864614109
# Epoch 40: train loss = 1.6080, val loss = 1.7428, val acc: 0.5265, time = 0.5155, lr = 0.39073230311063983
# Epoch 50: train loss = 1.5715, val loss = 1.7368, val acc: 0.5329, time = 0.5118, lr = 0.25977158704407677
# Training regular...
# Epoch 10: train loss = 1.7063, val loss = 1.7004, val acc: 0.5848, time = 0.4439, lr = 1.3296652719830016
# Epoch 20: train loss = 1.6797, val loss = 1.6772, val acc: 0.5823, time = 0.4345, lr = 0.8840048677588148
# Epoch 30: train loss = 1.6164, val loss = 1.6511, val acc: 0.6430, time = 0.4330, lr = 0.5877152864614109
# Epoch 40: train loss = 1.5904, val loss = 1.6452, val acc: 0.6456, time = 0.4430, lr = 0.39073230311063983
# Epoch 50: train loss = 1.5736, val loss = 1.6392, val acc: 0.6633, time = 0.4297, lr = 0.25977158704407677
# Training physical...
# Epoch 10: train loss = 1.3248, val loss = 1.3867, val acc: 0.6544, time = 0.4063, lr = 1.3296652719830016
# Epoch 20: train loss = 1.2779, val loss = 1.3635, val acc: 0.6781, time = 0.3993, lr = 0.8840048677588148
# Epoch 30: train loss = 1.2597, val loss = 1.3600, val acc: 0.6913, time = 0.4016, lr = 0.5877152864614109
# Epoch 40: train loss = 1.2348, val loss = 1.3538, val acc: 0.6887, time = 0.3997, lr = 0.39073230311063983
# Epoch 50: train loss = 1.2300, val loss = 1.3499, val acc: 0.6834, time = 0.4029, lr = 0.25977158704407677
# Training life...
# Epoch 10: train loss = 1.7360, val loss = 1.8082, val acc: 0.5748, time = 0.4668, lr = 1.3296652719830016
# Epoch 20: train loss = 1.6528, val loss = 1.7099, val acc: 0.6682, time = 0.4651, lr = 0.8840048677588148
# Epoch 30: train loss = 1.6280, val loss = 1.6973, val acc: 0.6682, time = 0.4734, lr = 0.5877152864614109
# Epoch 40: train loss = 1.6067, val loss = 1.6933, val acc: 0.6752, time = 0.4733, lr = 0.39073230311063983
# Epoch 50: train loss = 1.5967, val loss = 1.6924, val acc: 0.6799, time = 0.4756, lr = 0.25977158704407677
# Training follow...
# Epoch 10: train loss = 2.0047, val loss = 1.9905, val acc: 0.5599, time = 0.7108, lr = 1.3296652719830016
# Epoch 20: train loss = 1.9724, val loss = 1.9664, val acc: 0.5842, time = 0.7217, lr = 0.8840048677588148
# Epoch 30: train loss = 1.9617, val loss = 1.9627, val acc: 0.5842, time = 0.7238, lr = 0.5877152864614109
# Epoch 40: train loss = 1.9496, val loss = 1.9567, val acc: 0.5918, time = 0.7235, lr = 0.39073230311063983
# Epoch 50: train loss = 1.9450, val loss = 1.9622, val acc: 0.5857, time = 0.7262, lr = 0.25977158704407677

# %%
avg = sum(max_verifications.values())/30

fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
plt.bar(list(max_verifications.keys()), max_verifications.values(), color='g')
x = [i for i in range(0,30)]
y = [0.3 for i in range(0,30)]
plt.plot(x,y,'b--')
x = [i for i in range(0,30)]
y = [avg for i in range(0,30)]
plt.plot(x,y,'b--')
plt.tick_params(axis='both', which='major', labelsize=30) 
plt.xticks(rotation='vertical')
axes = plt.gca()
axes.set_xlim([-0.5,29.5])
axes.set_ylim([0,1])
plt.show()

# %%
# !wget https://raw.githubusercontent.com/peterSvenningsson/NLP_documents_/master/wsd_test_blind.txt
# Out:
# --2019-11-13 10:01:03--  https://raw.githubusercontent.com/peterSvenningsson/NLP_documents_/master/wsd_test_blind.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7987686 (7.6M) [text/plain]
# Saving to: ‘wsd_test_blind.txt’
#
# wsd_test_blind.txt  100%[===================>]   7.62M  30.1MB/s    in 0.3s
#
# 2019-11-13 10:01:07 (30.1 MB/s) - ‘wsd_test_blind.txt’ saved [7987686/7987686]

# %%
def read_test_data(corpus_file, doc_start):
    TEXT = torchtext.data.Field(sequential=True, tokenize=lambda x: x.split())
    WORDTYPE = torchtext.data.Field()
    datafields = [('text', TEXT), ('wordtype', WORDTYPE)]
    pad_string = '<pad>'
    sentence_length = 140
    half_sentence_length = int(sentence_length/2)
    with open(corpus_file, encoding='utf-8') as f:
        examples = []
        for line in f:
            columns = line.strip().split(maxsplit=doc_start)
            position_of_wordtype = int(columns[2])

            # Split the long string doc into array and extract words before the wordtype.
            doc = columns[-1]
            doc_string_vector = doc.split()
            temp_pad = [pad_string for x in range(0,70)]

            padded_doc = []
            padded_doc.extend(temp_pad)
            padded_doc.extend(doc_string_vector)
            padded_doc.extend(temp_pad)

            sliced_doc = padded_doc[position_of_wordtype:position_of_wordtype + 140]

            if len(sliced_doc) != 140:
                print(sliced_doc)
                raise RuntimeError

            sliced_doc = " ".join(sliced_doc)

            wordtype = columns[1].split('.')[0]
            examples.append(torchtext.data.Example.fromlist([sliced_doc, wordtype], datafields))
    dataset = torchtext.data.Dataset(examples, datafields)
    return (dataset, TEXT, WORDTYPE)

# %%
test_dataset = read_test_data('wsd_test_blind.txt', doc_start=4)
for example in test_dataset[0].examples:
    test_example_string = example.text
    example_wordtype = example.wordtype[0]

    # Load vocabs
    example_vocab = model_vocabs[example_wordtype]
    example_label_vocabs = model_label_vocabs[example_wordtype]

    # Encode string
    encoded_example = torch.tensor([example_vocab.stoi[x] for x in test_example_string],device=device, requires_grad = False)

    # Load correct model
    model = models[example_wordtype]
    model.lstm.flatten_parameters()

    # Get prediction
    scores = model(encoded_example.unsqueeze(1))
    prediction = scores.argmax(dim=1)
    
    # Decode prediction
    decoded_prediction = example_label_vocabs.itos[prediction]
    print(decoded_prediction)
# Out:
# physical%5:00:00:material:01
# see%2:31:00::
# line%1:04:01::
# keep%2:41:03::
# national%3:01:01::
# keep%2:41:03::
# serve%2:42:12::
# keep%2:42:07::
# position%1:04:01::
# find%2:31:10::
# extend%2:30:01::
# line%1:04:01::
# keep%2:41:03::
# active%5:00:00:involved:00
# bad%3:00:00::
# see%2:31:00::
# national%5:00:00:public:00
# line%1:04:01::
# security%1:12:00::
# regular%5:00:00:standard:02
# order%1:26:00::
# follow%2:41:00::
# professional%3:00:02::
# bad%5:00:00:intense:00
# security%1:21:01::
# line%1:04:01::
# see%2:31:00::
# force%1:07:01::
# keep%2:41:03::
# build%2:30:02::
# line%1:04:01::
# hold%2:40:00::
# bring%2:35:04::
# extend%2:30:06::
# common%5:00:00:shared:00
# professional%3:01:00::
# hold%2:35:03::
# serve%2:42:01::
# find%2:40:02::
# professional%3:01:01::
# line%1:04:01::
# see%2:31:00::
# point%1:28:00::
# bring%2:36:01::
# life%1:28:00::
# order%1:10:00::
# bring%2:36:00::
# security%1:26:00::
# professional%3:01:01::
# find%2:32:00::
# positive%5:00:00:plus:00
# lead%2:41:00::
# life%1:28:02::
# see%2:31:00::
# keep%2:41:03::
# keep%2:41:03::
# follow%2:38:01::
# national%3:00:01::
# extend%2:30:09::
# keep%2:40:00::
# hold%2:31:01::
# position%1:26:00::
# see%2:31:00::
# see%2:31:00::
# keep%2:42:07::
# line%1:04:01::
# order%1:14:00::
# see%2:31:00::
# positive%3:00:01::
# life%1:28:01::
# see%2:31:00::
# build%2:36:00::
# line%1:04:01::
# see%2:31:00::
# force%1:14:00::
# line%1:04:01::
# critical%3:00:01::
# keep%2:41:03::
# common%3:00:01::
# keep%2:42:07::
# life%1:28:01::
# follow%2:41:00::
# lead%2:38:00::
# build%2:31:03::
# serve%2:42:01::
# keep%2:41:03::
# position%1:09:00::
# see%2:31:00::
# see%2:31:00::
# extend%2:30:09::
# force%1:14:00::
# order%1:26:00::
# major%3:00:06::
# order%1:14:00::
# hold%2:35:03::
# extend%2:30:01::
# follow%2:41:00::
# physical%3:01:00::
# extend%2:30:06::
# see%2:31:00::
# point%1:28:00::
# line%1:04:01::
# life%1:28:00::
# order%1:10:03::
# national%3:00:00::
# build%2:36:09::
# place%1:15:04::
# security%1:12:00::
# lead%2:41:00::
# case%1:26:00::
# major%3:00:02::
# hold%2:31:01::
# find%2:40:02::
# case%1:10:02::
# point%1:28:00::
# find%2:31:10::
# security%1:26:00::
# follow%2:38:13::
# serve%2:42:12::
# line%1:04:01::
# critical%5:00:00:indispensable:00
# common%5:00:00:shared:00
# force%1:04:01::
# keep%2:40:00::
# hold%2:31:01::
# see%2:31:00::
# follow%2:41:00::
# order%1:10:03::
# critical%3:00:03::
# life%1:28:01::
# line%1:04:01::
# physical%3:01:00::
# line%1:04:01::
# national%3:00:01::
# place%1:15:00::
# professional%5:00:00:white-collar:00
# follow%2:42:02::
# major%3:00:07::
# hold%2:40:00::
# find%2:40:02::
# time%1:28:00::
# critical%5:00:00:indispensable:00
# line%1:04:01::
# keep%2:41:03::
# active%3:00:03::
# place%1:15:00::
# time%1:11:00::
# regular%5:00:00:scheduled:00
# physical%3:00:00::
# physical%5:00:00:material:01
# life%1:28:01::
# place%1:15:00::
# see%2:31:00::
# line%1:04:01::
# follow%2:41:00::
# active%5:00:00:involved:00
# extend%2:30:09::
# regular%5:00:00:symmetrical:00
# extend%2:40:04::
# bring%2:36:00::
# regular%5:00:00:frequent:00
# security%1:12:00::
# serve%2:42:01::
# bad%5:00:00:inferior:02
# build%2:30:02::
# line%1:04:01::
# point%1:28:00::
# line%1:04:01::
# national%3:00:01::
# bad%5:00:00:intense:00
# hold%2:36:00::
# build%2:36:09::
# physical%5:00:02:material:01
# lead%2:41:12::
# position%1:26:00::
# lead%2:38:00::
# see%2:31:00::
# security%1:21:01::
# order%1:10:01::
# line%1:04:01::
# follow%2:38:13::
# follow%2:38:13::
# order%1:10:01::
# life%1:28:01::
# professional%3:01:01::
# positive%3:00:01::
# line%1:04:01::
# active%3:00:03::
# national%3:00:00::
# line%1:04:01::
# bring%2:35:04::
# point%1:28:00::
# keep%2:41:03::
# force%1:07:01::
# serve%2:41:02::
# lead%2:38:00::
# physical%5:00:00:material:01
# place%1:15:04::
# hold%2:40:04::
# bring%2:36:01::
# physical%3:01:00::
# see%2:31:00::
# major%3:00:01::
# bad%5:00:00:inferior:02
# common%5:00:00:familiar:02
# build%2:31:03::
# critical%3:00:03::
# serve%2:42:01::
# life%1:26:01::
# see%2:31:00::
# hold%2:35:03::
# major%3:00:06::
# see%2:31:00::
# physical%3:00:00::
# major%3:00:06::
# keep%2:42:07::
# physical%5:00:00:material:01
# physical%3:00:00::
# bring%2:36:00::
# extend%2:30:01::
# see%2:31:00::
# place%1:04:01::
# line%1:04:01::
# find%2:40:02::
# national%5:00:00:domestic:00
# find%2:40:02::
# order%1:14:00::
# national%3:00:00::
# common%5:00:00:familiar:02
# bring%2:36:01::
# point%1:28:00::
# time%1:28:06::
# security%1:14:00::
# find%2:32:00::
# keep%2:41:03::
# see%2:31:00::
# national%3:00:01::
# order%1:10:00::
# bring%2:35:04::
# active%5:00:00:operational:00
# physical%5:00:00:material:01
# case%1:04:00::
# build%2:36:00::
# extend%2:30:02::
# major%3:00:06::
# professional%3:00:02::
# critical%3:00:01::
# keep%2:42:07::
# bad%5:00:00:intense:00
# follow%2:38:00::
# active%5:00:00:involved:00
# lead%2:41:00::
# point%1:09:01::
# major%3:00:07::
# follow%2:38:13::
# follow%2:38:00::
# hold%2:35:03::
# serve%2:41:02::
# see%2:31:00::
# critical%3:00:03::
# bring%2:38:00::
# lead%2:41:12::
# extend%2:30:06::
# line%1:04:01::
# find%2:40:02::
# see%2:31:00::
# keep%2:42:00::
# see%2:31:00::
# find%2:40:02::
# extend%2:30:06::
# keep%2:41:03::
# major%3:00:07::
# security%1:14:00::
# hold%2:31:01::
# point%1:28:00::
# line%1:04:01::
# line%1:04:01::
# keep%2:42:00::
# line%1:04:01::
# point%1:09:01::
# position%1:15:00::
# position%1:26:00::
# lead%2:38:01::
# see%2:31:00::
# bring%2:38:00::
# see%2:31:00::
# see%2:31:00::
# force%1:14:01::
# life%1:28:01::
# professional%3:01:01::
# security%1:26:00::
# place%1:15:00::
# see%2:31:00::
# security%1:21:04::
# build%2:31:03::
# time%1:28:05::
# find%2:32:01::
# security%1:04:00::
# time%1:28:06::
# active%5:00:00:operational:00
# position%1:04:01::
# place%1:15:04::
# life%1:28:02::
# time%1:28:05::
# active%5:00:00:involved:00
# bring%2:35:04::
# hold%2:36:00::
# force%1:04:01::
# extend%2:30:06::
# point%1:28:00::
# serve%2:41:02::
# case%1:10:02::
# professional%5:00:00:white-collar:00
# line%1:04:01::
# follow%2:41:00::
# lead%2:41:12::
# national%5:00:00:domestic:00
# see%2:31:00::
# hold%2:40:00::
# hold%2:40:00::
# professional%3:01:01::
# lead%2:41:12::
# life%1:28:00::
# regular%5:00:00:scheduled:00
# find%2:40:02::
# major%3:00:02::
# national%5:00:00:domestic:00
# major%3:00:06::
# regular%5:00:00:standard:02
# order%1:14:00::
# position%1:04:01::
# line%1:04:01::
# regular%5:00:00:scheduled:00
# critical%5:00:00:indispensable:00
# life%1:28:02::
# see%2:31:00::
# time%1:11:00::
# build%2:31:03::
# see%2:31:00::
# regular%5:00:00:scheduled:00
# bad%5:00:00:intense:00
# professional%3:01:01::
# security%1:14:00::
# see%2:31:00::
# professional%3:00:01::
# common%3:00:01::
# national%3:00:00::
# point%1:09:01::
# position%1:15:00::
# time%1:28:05::
# point%1:28:00::
# national%3:01:01::
# hold%2:35:03::
# build%2:30:02::
# force%1:18:00::
# security%1:12:00::
# follow%2:42:02::
# line%1:04:01::
# common%3:00:01::
# line%1:04:01::
# time%1:28:05::
# keep%2:40:00::
# keep%2:40:00::
# hold%2:40:04::
# point%1:09:01::
# line%1:04:01::
# case%1:10:01::
# security%1:14:00::
# force%1:18:00::
# force%1:07:02::
# see%2:31:00::
# physical%3:01:00::
# security%1:21:01::
# order%1:10:01::
# case%1:04:00::
# case%1:04:00::
# lead%2:41:12::
# order%1:26:00::
# position%1:09:00::
# follow%2:38:13::
# line%1:04:01::
# line%1:04:01::
# life%1:28:01::
# serve%2:42:12::
# line%1:04:01::
# keep%2:42:07::
# follow%2:38:01::
# security%1:26:00::
# national%5:00:00:domestic:00
# follow%2:38:01::
# hold%2:31:01::
# serve%2:41:02::
# see%2:31:00::
# see%2:31:00::
# professional%3:01:01::
# build%2:30:02::
# lead%2:42:12::
# active%3:00:03::
# keep%2:41:03::
# case%1:10:02::
# common%5:00:00:shared:00
# keep%2:42:00::
# build%2:31:03::
# line%1:04:01::
# see%2:31:00::
# serve%2:42:01::
# positive%3:00:01::
# order%1:26:00::
# build%2:31:03::
# point%1:09:01::
# see%2:31:00::
# professional%3:01:00::
# time%1:11:00::
# see%2:31:00::
# national%3:01:01::
# lead%2:38:01::
# line%1:04:01::
# physical%5:00:00:material:01
# find%2:40:02::
# national%5:00:00:public:00
# extend%2:30:06::
# time%1:11:00::
# force%1:14:00::
# find%2:32:01::
# keep%2:41:03::
# follow%2:38:00::
# bring%2:35:00::
# regular%5:00:00:scheduled:00
# common%5:00:00:familiar:02
# serve%2:42:00::
# professional%3:00:01::
# find%2:40:02::
# order%1:10:00::
# regular%3:00:00::
# bad%5:00:00:intense:00
# regular%3:00:00::
# bring%2:36:00::
# hold%2:35:03::
# see%2:31:00::
# keep%2:41:03::
# extend%2:30:01::
# see%2:31:00::
# place%1:26:00::
# position%1:26:00::
# major%3:00:06::
# force%1:04:01::
# lead%2:38:00::
# keep%2:42:00::
# time%1:28:06::
# follow%2:41:00::
# find%2:32:01::
# bring%2:35:00::
# physical%3:01:00::
# extend%2:30:01::
# follow%2:38:00::
# place%1:15:04::
# see%2:31:00::
# keep%2:40:00::
# see%2:31:00::
# regular%5:00:00:standard:02
# force%1:07:01::
# bad%5:00:00:intense:00
# regular%5:00:00:scheduled:00
# national%3:01:01::
# line%1:04:01::
# major%3:00:07::
# build%2:30:02::
# see%2:31:00::
# common%5:00:00:familiar:02
# follow%2:41:00::
# line%1:04:01::
# lead%2:38:00::
# point%1:28:00::
# line%1:04:01::
# keep%2:41:03::
# force%1:07:02::
# line%1:04:01::
# extend%2:40:04::
# physical%3:01:00::
# follow%2:41:00::
# physical%3:01:00::
# point%1:28:00::
# find%2:31:10::
# point%1:09:01::
# place%1:15:04::
# case%1:10:02::
# place%1:26:00::
# order%1:10:00::
# active%5:00:00:involved:00
# bring%2:38:00::
# see%2:31:00::
# case%1:11:00::
# lead%2:42:12::
# build%2:30:02::
# time%1:28:05::
# line%1:04:01::
# extend%2:40:04::
# hold%2:31:01::
# physical%5:00:02:material:01
# physical%5:00:02:material:01
# serve%2:41:02::
# order%1:10:03::
# force%1:07:02::
# active%5:00:00:operational:00
# see%2:31:00::
# point%1:09:01::
# force%1:14:00::
# life%1:28:00::
# follow%2:38:13::
# force%1:14:01::
# keep%2:42:00::
# keep%2:41:03::
# position%1:09:00::
# positive%3:00:01::
# case%1:04:00::
# build%2:36:09::
# major%3:00:06::
# common%5:00:00:familiar:02
# point%1:09:01::
# critical%3:00:03::
# physical%3:00:00::
# see%2:31:00::
# keep%2:42:07::
# hold%2:42:00::
# build%2:36:09::
# line%1:04:01::
# keep%2:42:07::
# see%2:31:00::
# time%1:28:00::
# major%3:00:07::
# physical%5:00:02:material:01
# keep%2:42:00::
# hold%2:31:01::
# keep%2:42:07::
# professional%5:00:00:white-collar:00
# follow%2:41:00::
# positive%5:00:00:plus:00
# common%3:00:02::
# lead%2:41:12::
# place%1:04:01::
# security%1:12:00::
# find%2:40:02::
# line%1:04:01::
# place%1:04:01::
# line%1:04:01::
# security%1:04:00::
# case%1:10:02::
# life%1:26:01::
# bad%5:00:00:intense:00
# order%1:14:00::
# see%2:31:00::
# life%1:28:02::
# keep%2:42:00::
# lead%2:38:01::
# force%1:14:00::
# line%1:04:01::
# follow%2:38:13::
# case%1:11:00::
# case%1:10:01::
# serve%2:42:00::
# critical%5:00:00:indispensable:00
# extend%2:30:06::
# bad%3:00:00::
# life%1:28:01::
# time%1:11:00::
# force%1:04:01::
# line%1:04:01::
# place%1:26:00::
# time%1:28:05::
# see%2:31:00::
# bad%5:00:00:inferior:02
# life%1:26:01::
# serve%2:42:03::
# national%5:00:00:domestic:00
# hold%2:31:01::
# position%1:09:00::
# professional%3:00:01::
# line%1:04:01::
# active%3:00:03::
# case%1:11:00::
# hold%2:35:03::
# line%1:04:01::
# active%5:00:00:operational:00
# physical%3:00:00::
# follow%2:38:13::
# security%1:21:04::
# serve%2:42:03::
# national%3:00:01::
# critical%5:00:00:indispensable:00
# follow%2:42:02::
# point%1:09:01::
# case%1:10:02::
# keep%2:40:00::
# serve%2:42:03::
# life%1:26:01::
# hold%2:40:00::
# keep%2:42:07::
# line%1:04:01::
# place%1:04:01::
# bring%2:36:00::
# point%1:28:00::
# keep%2:40:00::
# national%5:00:00:public:00
# active%3:00:03::
# common%3:00:01::
# force%1:07:02::
# follow%2:38:01::
# extend%2:30:01::
# see%2:31:00::
# follow%2:38:01::
# see%2:31:00::
# life%1:28:01::
# security%1:14:00::
# positive%3:00:01::
# place%1:04:01::
# common%5:00:00:shared:00
# order%1:10:01::
# hold%2:31:01::
# keep%2:41:03::
# see%2:31:00::
# line%1:04:01::
# force%1:14:01::
# force%1:18:00::
# security%1:14:00::
# follow%2:38:00::
# hold%2:31:01::
# point%1:28:00::
# position%1:26:02::
# lead%2:41:00::
# extend%2:40:04::
# bad%5:00:00:inferior:02
# serve%2:42:12::
# serve%2:42:01::
# position%1:15:00::
# follow%2:41:00::
# physical%3:01:00::
# serve%2:33:00::
# bad%3:00:00::
# bring%2:38:00::
# see%2:31:00::
# bad%3:00:00::
# bad%5:00:00:intense:00
# bring%2:38:00::
# order%1:10:00::
# case%1:26:00::
# case%1:10:01::
# line%1:04:01::
# build%2:31:03::
# time%1:11:00::
# bring%2:38:00::
# active%3:00:07::
# keep%2:40:00::
# critical%3:00:02::
# point%1:09:01::
# extend%2:40:04::
# positive%5:00:00:advantageous:00
# line%1:04:01::
# professional%3:00:01::
# hold%2:42:00::
# national%3:01:01::
# national%5:00:00:domestic:00
# force%1:18:00::
# security%1:14:00::
# hold%2:40:04::
# follow%2:38:00::
# line%1:04:01::
# position%1:26:02::
# line%1:04:01::
# find%2:40:02::
# regular%5:00:00:standard:02
# build%2:31:03::
# see%2:31:00::
# lead%2:38:01::
# build%2:30:02::
# keep%2:41:03::
# security%1:21:01::
# positive%5:00:00:advantageous:00
# time%1:28:00::
# order%1:10:03::
# find%2:31:10::
# extend%2:40:04::
# find%2:31:10::
# physical%5:00:02:material:01
# see%2:31:00::
# keep%2:41:03::
# critical%5:00:00:indispensable:00
# positive%5:00:00:plus:00
# life%1:26:01::
# order%1:10:03::
# security%1:26:00::
# case%1:10:02::
# case%1:11:00::
# see%2:31:00::
# see%2:31:00::
# critical%3:00:03::
# follow%2:41:00::
# lead%2:42:12::
# extend%2:30:06::
# security%1:26:00::
# find%2:31:10::
# life%1:28:02::
# lead%2:38:01::
# life%1:28:01::
# line%1:04:01::
# bring%2:38:00::
# extend%2:30:06::
# position%1:26:00::
# keep%2:40:00::
# lead%2:41:12::
# positive%3:00:01::
# case%1:10:02::
# regular%5:00:00:standard:02
# physical%3:01:00::
# keep%2:42:00::
# force%1:18:00::
# see%2:31:00::
# extend%2:30:02::
# physical%5:00:00:material:01
# see%2:31:00::
# follow%2:42:02::
# professional%3:00:02::
# major%3:00:02::
# critical%3:00:03::
# build%2:30:02::
# regular%5:00:00:symmetrical:00
# life%1:28:01::
# line%1:04:01::
# national%3:00:01::
# hold%2:36:00::
# see%2:31:00::
# serve%2:33:00::
# serve%2:42:03::
# security%1:21:01::
# physical%5:00:02:material:01
# national%5:00:00:domestic:00
# find%2:32:01::
# common%5:00:00:shared:00
# security%1:21:01::
# see%2:31:00::
# keep%2:42:07::
# regular%5:00:00:frequent:00
# order%1:10:03::
# keep%2:41:03::
# extend%2:30:01::
# order%1:10:00::
# case%1:11:00::
# extend%2:30:02::
# life%1:26:01::
# national%3:01:01::
# find%2:32:01::
# regular%5:00:00:scheduled:00
# time%1:28:06::
# critical%3:00:03::
# force%1:07:01::
# bring%2:36:01::
# time%1:28:06::
# see%2:31:00::
# build%2:36:09::
# follow%2:41:00::
# order%1:10:03::
# hold%2:36:00::
# time%1:28:00::
# common%5:00:00:shared:00
# build%2:36:09::
# time%1:28:00::
# physical%3:01:00::
# order%1:10:00::
# time%1:11:00::
# order%1:14:00::
# case%1:04:00::
# build%2:36:00::
# physical%5:00:00:material:01
# see%2:31:00::
# follow%2:41:00::
# national%5:00:00:domestic:00
# active%5:00:00:involved:00
# serve%2:42:00::
# hold%2:36:00::
# national%3:00:00::
# serve%2:42:01::
# time%1:11:00::
# place%1:15:04::
# professional%3:01:01::
# position%1:04:01::
# hold%2:31:01::
# line%1:04:01::
# case%1:04:00::
# keep%2:40:00::
# hold%2:31:01::
# bad%5:00:00:intense:00
# critical%3:00:03::
# order%1:10:03::
# order%1:10:01::
# position%1:09:00::
# active%3:00:03::
# line%1:04:01::
# position%1:04:01::
# line%1:04:01::
# serve%2:42:00::
# national%5:00:00:public:00
# national%5:00:00:domestic:00
# see%2:31:00::
# point%1:09:01::
# force%1:07:01::
# build%2:30:02::
# national%5:00:00:domestic:00
# serve%2:42:12::
# hold%2:31:01::
# keep%2:40:00::
# see%2:31:00::
# extend%2:30:06::
# bring%2:36:00::
# follow%2:38:01::
# critical%3:00:01::
# point%1:09:01::
# lead%2:42:12::
# see%2:31:00::
# life%1:28:01::
# line%1:04:01::
# common%5:00:00:familiar:02
# line%1:04:01::
# find%2:31:10::
# order%1:10:03::
# life%1:28:01::
# order%1:14:00::
# see%2:31:00::
# extend%2:30:02::
# see%2:31:00::
# hold%2:40:00::
# extend%2:30:06::
# case%1:26:00::
# line%1:04:01::
# physical%3:01:00::
# hold%2:35:03::
# keep%2:41:03::
# regular%5:00:00:scheduled:00
# critical%3:00:03::
# physical%5:00:00:material:01
# professional%3:00:02::
# line%1:04:01::
# critical%3:00:03::
# position%1:09:00::
# national%5:00:00:public:00
# security%1:21:04::
# line%1:04:01::
# line%1:04:01::
# life%1:28:00::
# critical%3:00:02::
# lead%2:41:00::
# position%1:26:00::
# hold%2:36:00::
# follow%2:38:13::
# line%1:04:01::
# bad%5:00:00:intense:00
# order%1:10:01::
# force%1:14:01::
# force%1:04:01::
# order%1:14:00::
# keep%2:42:00::
# see%2:31:00::
# major%3:00:07::
# force%1:14:00::
# serve%2:41:02::
# see%2:31:00::
# case%1:10:01::
# case%1:10:01::
# force%1:07:02::
# build%2:30:02::
# find%2:40:02::
# see%2:31:00::
# life%1:28:02::
# follow%2:38:13::
# life%1:28:02::
# national%3:01:01::
# case%1:26:00::
# see%2:31:00::
# line%1:04:01::
# line%1:04:01::
# build%2:31:03::
# see%2:31:00::
# national%3:00:00::
# point%1:28:00::
# see%2:31:00::
# build%2:31:03::
# positive%3:00:01::
# national%3:00:00::
# extend%2:30:01::
# line%1:04:01::
# major%3:00:02::
# keep%2:40:00::
# regular%5:00:00:frequent:00
# line%1:04:01::
# line%1:04:01::
# order%1:10:01::
# bring%2:35:04::
# lead%2:42:12::
# life%1:28:01::
# life%1:28:01::
# position%1:09:00::
# hold%2:31:01::
# bring%2:38:00::
# security%1:21:04::
# life%1:28:01::
# common%5:00:00:familiar:02
# find%2:31:10::
# hold%2:40:04::
# extend%2:30:02::
# time%1:28:05::
# life%1:28:01::
# hold%2:40:04::
# bring%2:36:01::
# force%1:14:00::
# life%1:26:01::
# keep%2:40:00::
# critical%3:00:01::
# positive%3:00:01::
# point%1:09:01::
# order%1:10:00::
# case%1:10:02::
# point%1:09:01::
# security%1:14:00::
# find%2:32:01::
# professional%3:01:01::
# see%2:31:00::
# line%1:04:01::
# follow%2:42:02::
# line%1:04:01::
# see%2:31:00::
# position%1:26:00::
# national%3:01:01::
# line%1:04:01::
# build%2:36:00::
# build%2:36:00::
# force%1:14:01::
# force%1:07:02::
# lead%2:42:12::
# see%2:31:00::
# see%2:31:00::
# hold%2:40:00::
# keep%2:40:00::
# physical%5:00:00:material:01
# regular%5:00:00:standard:02
# position%1:04:01::
# follow%2:38:13::
# position%1:04:01::
# active%3:00:03::
# life%1:28:00::
# physical%5:00:02:material:01
# positive%3:00:01::
# find%2:40:02::
# find%2:40:02::
# positive%5:00:00:plus:00
# active%5:00:00:operational:00
# follow%2:38:00::
# major%3:00:06::
# regular%3:00:00::
# national%3:00:01::
# build%2:31:03::
# see%2:31:00::
# physical%5:00:00:material:01
# order%1:10:01::
# see%2:31:00::
# find%2:40:02::
# line%1:04:01::
# line%1:04:01::
# find%2:32:00::
# active%3:00:03::
# line%1:04:01::
# keep%2:41:03::
# find%2:40:02::
# active%5:00:00:operational:00
# lead%2:38:01::
# follow%2:42:02::
# point%1:28:00::
# line%1:04:01::
# life%1:28:01::
# order%1:10:03::
# hold%2:36:00::
# see%2:31:00::
# national%3:00:00::
# professional%3:00:01::
# national%5:00:00:public:00
# line%1:04:01::
# follow%2:38:01::
# national%3:00:00::
# force%1:18:00::
# build%2:36:09::
# force%1:14:00::
# line%1:04:01::
# see%2:31:00::
# force%1:18:00::
# lead%2:38:00::
# case%1:26:00::
# see%2:31:00::
# line%1:04:01::
# common%3:00:02::
# see%2:31:00::
# time%1:11:00::
# point%1:28:00::
# hold%2:31:01::
# order%1:26:00::
# order%1:10:00::
# bring%2:35:00::
# order%1:26:00::
# line%1:04:01::
# see%2:31:00::
# national%3:00:01::
# line%1:04:01::
# serve%2:33:00::
# see%2:31:00::
# serve%2:42:00::
# see%2:31:00::
# serve%2:41:02::
# hold%2:40:00::
# line%1:04:01::
# see%2:31:00::
# order%1:14:00::
# see%2:31:00::
# see%2:31:00::
# professional%5:00:00:white-collar:00
# common%3:00:01::
# lead%2:42:12::
# line%1:04:01::
# serve%2:42:01::
# bad%5:00:00:intense:00
# case%1:10:01::
# lead%2:41:00::
# see%2:31:00::
# place%1:15:00::
# physical%3:01:00::
# case%1:11:00::
# serve%2:42:03::
# bad%5:00:00:intense:00
# place%1:15:00::
# order%1:14:00::
# line%1:04:01::
# see%2:31:00::
# position%1:09:00::
# find%2:31:10::
# security%1:21:04::
# follow%2:38:13::
# serve%2:33:00::
# serve%2:41:02::
# place%1:26:00::
# see%2:31:00::
# extend%2:30:02::
# find%2:40:02::
# lead%2:41:00::
# time%1:28:06::
# find%2:40:02::
# bring%2:38:00::
# major%3:00:02::
# position%1:26:00::
# physical%5:00:00:material:01
# keep%2:41:03::
# lead%2:41:12::
# see%2:31:00::
# time%1:28:05::
# line%1:04:01::
# common%3:00:02::
# position%1:04:01::
# point%1:09:01::
# national%3:01:00::
# active%5:00:00:involved:00
# position%1:09:00::
# life%1:26:01::
# order%1:10:00::
# major%3:00:06::
# regular%5:00:00:frequent:00
# find%2:40:02::
# hold%2:36:00::
# build%2:36:00::
# bring%2:38:00::
# extend%2:30:02::
# position%1:09:00::
# keep%2:42:00::
# life%1:28:01::
# common%3:00:02::
# keep%2:42:00::
# physical%3:00:00::
# national%3:00:00::
# serve%2:41:02::
# build%2:31:03::
# hold%2:35:03::
# build%2:36:00::
# extend%2:30:02::
# force%1:14:01::
# force%1:14:01::
# position%1:04:01::
# national%3:01:01::
# bring%2:36:00::
# regular%5:00:00:frequent:00
# serve%2:42:12::
# force%1:14:01::
# case%1:04:00::
# find%2:32:01::
# bad%5:00:00:intense:00
# case%1:26:00::
# point%1:28:00::
# see%2:31:00::
# follow%2:38:00::
# see%2:31:00::
# line%1:04:01::
# line%1:04:01::
# follow%2:42:02::
# critical%5:00:00:indispensable:00
# critical%3:00:01::
# keep%2:42:07::
# keep%2:42:00::
# common%3:00:02::
# follow%2:41:00::
# see%2:31:00::
# life%1:28:02::
# keep%2:40:00::
# critical%3:00:02::
# extend%2:30:09::
# follow%2:38:00::
# follow%2:41:00::
# follow%2:38:13::
# lead%2:38:00::
# critical%3:00:01::
# line%1:04:01::
# serve%2:33:00::
# positive%3:00:04::
# serve%2:41:02::
# security%1:21:01::
# point%1:09:01::
# life%1:28:01::
# line%1:04:01::
# find%2:40:02::
# build%2:30:02::
# active%3:00:03::
# position%1:26:00::
# force%1:14:00::
# keep%2:40:00::
# common%3:00:02::
# lead%2:41:00::
# see%2:31:00::
# force%1:04:01::
# security%1:12:00::
# bad%3:00:00::
# national%5:00:00:domestic:00
# physical%3:00:00::
# time%1:28:05::
# keep%2:41:03::
# hold%2:42:00::
# security%1:26:00::
# hold%2:40:00::
# time%1:28:05::
# hold%2:35:03::
# keep%2:41:03::
# national%3:00:00::
# keep%2:40:00::
# see%2:31:00::
# regular%5:00:00:scheduled:00
# serve%2:41:02::
# line%1:04:01::
# see%2:31:00::
# case%1:10:02::
# line%1:04:01::
# life%1:28:01::
# time%1:28:06::
# lead%2:42:12::
# case%1:04:00::
# keep%2:42:07::
# critical%3:00:02::
# line%1:04:01::
# position%1:26:00::
# see%2:31:00::
# life%1:28:00::
# place%1:04:01::
# see%2:31:00::
# order%1:10:01::
# positive%5:00:00:advantageous:00
# security%1:21:01::
# time%1:28:06::
# see%2:31:00::
# order%1:14:00::
# keep%2:41:03::
# common%5:00:00:familiar:02
# see%2:31:00::
# line%1:04:01::
# see%2:31:00::
# keep%2:41:03::
# position%1:09:00::
# extend%2:30:02::
# regular%5:00:00:frequent:00
# time%1:11:00::
# point%1:09:01::
# follow%2:38:13::
# professional%3:00:01::
# keep%2:42:07::
# national%5:00:00:domestic:00
# critical%3:00:01::
# serve%2:42:01::
# national%5:00:00:domestic:00
# serve%2:42:01::
# national%3:01:01::
# physical%3:00:00::
# time%1:28:06::
# lead%2:38:00::
# force%1:04:01::
# keep%2:41:03::
# security%1:21:01::
# national%3:00:01::
# find%2:31:10::
# serve%2:42:03::
# national%5:00:00:public:00
# active%5:00:00:involved:00
# life%1:28:01::
# see%2:31:00::
# keep%2:41:03::
# keep%2:40:00::
# extend%2:30:01::
# time%1:28:05::
# line%1:04:01::
# time%1:28:06::
# case%1:10:01::
# follow%2:41:00::
# major%3:00:02::
# keep%2:42:00::
# bad%5:00:00:intense:00
# build%2:31:03::
# serve%2:41:02::
# place%1:26:00::
# line%1:04:01::
# follow%2:38:01::
# national%3:00:00::
# bring%2:38:00::
# security%1:14:00::
# serve%2:41:02::
# see%2:31:00::
# extend%2:30:02::
# professional%3:00:01::
# critical%5:00:00:indispensable:00
# find%2:40:02::
# line%1:04:01::
# professional%5:00:00:white-collar:00
# keep%2:41:03::
# bad%5:00:00:inferior:02
# line%1:04:01::
# life%1:26:01::
# point%1:28:00::
# point%1:28:00::
# positive%5:00:00:plus:00
# national%3:00:00::
# national%3:00:01::
# find%2:32:00::
# time%1:28:05::
# find%2:40:02::
# bring%2:36:00::
# bad%5:00:00:inferior:02
# regular%3:00:00::
# line%1:04:01::
# follow%2:41:00::
# security%1:21:04::
# bad%5:00:00:intense:00
# regular%5:00:00:scheduled:00
# follow%2:38:00::
# keep%2:41:03::
# line%1:04:01::
# place%1:26:00::
# find%2:40:02::
# follow%2:38:13::
# time%1:28:05::
# see%2:31:00::
# keep%2:42:07::
# line%1:04:01::
# physical%3:00:00::
# order%1:10:03::
# common%3:00:02::
# place%1:15:00::
# professional%3:00:02::
# time%1:11:00::
# positive%3:00:01::
# see%2:31:00::
# position%1:04:01::
# find%2:31:10::
# find%2:40:02::
# case%1:10:02::
# common%3:00:01::
# positive%5:00:00:plus:00
# follow%2:38:13::
# point%1:09:01::
# see%2:31:00::
# active%5:00:00:operational:00
# time%1:28:05::
# hold%2:42:00::
# line%1:04:01::
# lead%2:38:00::
# place%1:26:00::
# build%2:36:00::
# find%2:31:10::
# keep%2:41:03::
# keep%2:42:00::
# order%1:26:00::
# major%3:00:07::
# physical%5:00:00:material:01
# build%2:31:03::
# follow%2:38:00::
# point%1:28:00::
# security%1:21:01::
# bad%3:00:00::
# professional%3:01:01::
# hold%2:40:00::
# national%5:00:00:domestic:00
# bad%5:00:00:intense:00
# see%2:31:00::
# build%2:31:03::
# see%2:31:00::
# line%1:04:01::
# active%5:00:00:operational:00
# extend%2:30:06::
# extend%2:30:06::
# see%2:31:00::
# regular%3:00:00::
# see%2:31:00::
# extend%2:30:06::
# serve%2:42:01::
# security%1:21:01::
# position%1:09:00::
# regular%5:00:00:standard:02
# position%1:15:00::
# force%1:07:01::
# extend%2:40:04::
# keep%2:41:03::
# line%1:04:01::
# critical%3:00:01::
# major%3:00:06::
# hold%2:36:00::
# follow%2:38:13::
# security%1:21:04::
# keep%2:41:03::
# security%1:21:04::
# build%2:30:02::
# see%2:31:00::
# find%2:40:02::
# time%1:28:05::
# hold%2:36:00::
# active%3:00:07::
# follow%2:38:01::
# professional%3:01:00::
# bring%2:35:00::
# critical%3:00:02::
# critical%3:00:01::
# follow%2:38:01::
# bring%2:35:04::
# see%2:31:00::
# national%3:01:01::
# case%1:11:00::
# regular%5:00:00:scheduled:00
# line%1:04:01::
# place%1:15:04::
# serve%2:33:00::
# line%1:04:01::
# keep%2:42:00::
# major%3:00:07::
# line%1:04:01::
# lead%2:38:01::
# serve%2:33:00::
# point%1:09:01::
# lead%2:38:01::
# lead%2:42:12::
# position%1:26:02::
# see%2:31:00::
# keep%2:40:00::
# extend%2:30:06::
# national%3:00:00::
# order%1:10:03::
# professional%5:00:00:white-collar:00
# keep%2:42:00::
# lead%2:41:12::
# national%3:01:01::
# order%1:10:00::
# hold%2:31:01::
# place%1:15:00::
# bad%5:00:00:intense:00
# point%1:09:01::
# line%1:04:01::
# see%2:31:00::
# physical%3:00:00::
# order%1:10:03::
# build%2:31:03::
# place%1:15:00::
# bring%2:36:01::
# keep%2:42:07::
# keep%2:42:07::
# critical%3:00:01::
# physical%3:00:00::
# see%2:31:00::
# place%1:04:01::
# follow%2:41:00::
# serve%2:42:01::
# critical%3:00:03::
# position%1:15:00::
# order%1:10:01::
# see%2:31:00::
# see%2:31:00::
# force%1:07:02::
# keep%2:42:00::
# see%2:31:00::
# positive%3:00:01::
# regular%3:00:00::
# life%1:26:01::
# find%2:40:02::
# force%1:14:00::
# security%1:21:04::
# professional%3:01:00::
# force%1:14:00::
# follow%2:38:00::
# see%2:31:00::
# order%1:10:00::
# extend%2:30:02::
# security%1:26:00::
# serve%2:42:01::
# case%1:11:00::
# keep%2:42:00::
# line%1:04:01::
# line%1:04:01::
# extend%2:30:06::
# keep%2:42:00::
# bad%5:00:00:inferior:02
# national%3:00:01::
# keep%2:42:00::
# see%2:31:00::
# line%1:04:01::
# security%1:14:00::
# point%1:09:01::
# line%1:04:01::
# place%1:15:00::
# build%2:36:09::
# lead%2:41:00::
# order%1:14:00::
# hold%2:40:00::
# positive%3:00:01::
# serve%2:42:12::
# professional%5:00:00:white-collar:00
# serve%2:41:02::
# keep%2:42:00::
# see%2:31:00::
# line%1:04:01::
# force%1:04:01::
# hold%2:36:00::
# regular%5:00:00:scheduled:00
# keep%2:41:03::
# follow%2:38:01::
# critical%5:00:00:indispensable:00
# professional%3:00:01::
# regular%5:00:00:frequent:00
# line%1:04:01::
# case%1:11:00::
# lead%2:38:00::
# extend%2:30:06::
# follow%2:38:13::
# position%1:26:00::
# physical%3:00:00::
# find%2:32:01::
# keep%2:41:03::
# point%1:28:00::
# case%1:10:01::
# common%5:00:00:familiar:02
# major%3:00:07::
# place%1:15:00::
# point%1:28:00::
# keep%2:41:03::
# keep%2:42:07::
# follow%2:38:13::
# force%1:07:01::
# bad%3:00:00::
# see%2:31:00::
# keep%2:41:03::
# see%2:31:00::
# hold%2:42:00::
# see%2:31:00::
# common%5:00:00:shared:00
# bad%5:00:00:intense:00
# national%3:00:01::
# keep%2:41:03::
# hold%2:35:03::
# security%1:12:00::
# extend%2:30:06::
# national%3:00:01::
# case%1:26:00::
# build%2:36:00::
# regular%5:00:00:frequent:00
# hold%2:40:00::
# see%2:31:00::
# common%5:00:00:familiar:02
# place%1:26:00::
# point%1:09:01::
# extend%2:40:04::
# bad%5:00:00:intense:00
# bring%2:35:04::
# keep%2:42:07::
# keep%2:40:00::
# keep%2:41:03::
# order%1:10:03::
# serve%2:42:00::
# line%1:04:01::
# national%3:00:00::
# line%1:04:01::
# hold%2:42:00::
# line%1:04:01::
# line%1:04:01::
# common%5:00:00:familiar:02
# national%3:01:01::
# position%1:26:00::
# time%1:28:05::
# line%1:04:01::
# see%2:31:00::
# case%1:10:01::
# position%1:26:00::
# build%2:36:09::
# position%1:04:01::
# keep%2:42:00::
# point%1:09:01::
# point%1:28:00::
# hold%2:42:00::
# see%2:31:00::
# follow%2:38:00::
# hold%2:42:00::
# national%3:00:00::
# life%1:28:00::
# see%2:31:00::
# regular%5:00:00:standard:02
# see%2:31:00::
# see%2:31:00::
# regular%5:00:00:standard:02
# physical%5:00:00:material:01
# extend%2:30:02::
# regular%5:00:00:frequent:00
# bring%2:38:00::
# keep%2:42:07::
# lead%2:42:12::
# security%1:21:01::
# keep%2:40:00::
# point%1:09:01::
# see%2:31:00::
# find%2:32:01::
# life%1:26:01::
# regular%5:00:00:frequent:00
# position%1:26:00::
# serve%2:33:00::
# see%2:31:00::
# see%2:31:00::
# position%1:09:00::
# professional%3:01:00::
# keep%2:42:00::
# serve%2:42:00::
# regular%5:00:00:standard:02
# regular%5:00:00:frequent:00
# hold%2:36:00::
# physical%5:00:00:material:01
# keep%2:41:03::
# serve%2:42:01::
# keep%2:41:03::
# keep%2:41:03::
# physical%5:00:02:material:01
# physical%5:00:00:material:01
# position%1:09:00::
# bring%2:36:00::
# serve%2:42:01::
# bad%5:00:00:inferior:02
# professional%3:01:00::
# line%1:04:01::
# life%1:26:01::
# bad%5:00:00:intense:00
# find%2:40:02::
# line%1:04:01::
# life%1:28:01::
# see%2:31:00::
# line%1:04:01::
# line%1:04:01::
# follow%2:42:02::
# national%5:00:00:domestic:00
# extend%2:30:01::
# line%1:04:01::
# line%1:04:01::
# hold%2:31:01::
# professional%3:01:00::
# professional%5:00:00:white-collar:00
# hold%2:31:01::
# see%2:31:00::
# bring%2:38:00::
# physical%5:00:00:material:01
# life%1:28:00::
# extend%2:30:02::
# line%1:04:01::
# positive%3:00:01::
# see%2:31:00::
# professional%5:00:00:white-collar:00
# extend%2:30:01::
# build%2:36:00::
# follow%2:38:01::
# extend%2:30:09::
# place%1:04:01::
# force%1:04:01::
# point%1:09:01::
# build%2:36:00::
# follow%2:41:00::
# build%2:31:03::
# see%2:31:00::
# force%1:07:02::
# extend%2:30:09::
# follow%2:38:01::
# see%2:31:00::
# order%1:10:00::
# build%2:36:09::
# see%2:31:00::
# place%1:15:00::
# follow%2:42:02::
# build%2:36:09::
# lead%2:41:12::
# line%1:04:01::
# time%1:28:05::
# positive%3:00:01::
# force%1:14:00::
# time%1:28:05::
# common%5:00:00:shared:00
# regular%5:00:00:standard:02
# place%1:15:04::
# national%3:00:01::
# keep%2:41:03::
# critical%3:00:01::
# common%5:00:00:shared:00
# keep%2:41:03::
# line%1:04:01::
# build%2:36:09::
# professional%5:00:00:white-collar:00
# positive%5:00:00:plus:00
# force%1:14:01::
# common%3:00:02::
# physical%5:00:00:material:01
# time%1:28:06::
# order%1:10:03::
# bring%2:35:00::
# regular%5:00:00:frequent:00
# build%2:30:02::
# professional%3:01:01::
# see%2:31:00::
# extend%2:30:06::
# line%1:04:01::
# physical%5:00:00:material:01
# extend%2:30:02::
# keep%2:41:03::
# serve%2:42:03::
# build%2:31:03::
# order%1:10:00::
# major%3:00:01::
# see%2:31:00::
# common%3:00:01::
# keep%2:41:03::
# line%1:04:01::
# line%1:04:01::
# keep%2:42:00::
# position%1:26:00::
# place%1:26:00::
# force%1:14:01::
# follow%2:38:01::
# force%1:04:01::
# life%1:28:02::
# keep%2:40:00::
# physical%3:00:00::
# security%1:21:04::
# regular%5:00:00:scheduled:00
# force%1:14:01::
# force%1:14:01::
# force%1:04:01::
# see%2:31:00::
# bad%5:00:00:intense:00
# point%1:28:00::
# follow%2:42:02::
# follow%2:38:00::
# bad%3:00:00::
# line%1:04:01::
# professional%3:01:00::
# find%2:32:00::
# serve%2:42:12::
# extend%2:30:06::
# lead%2:38:00::
# line%1:04:01::
# regular%3:00:00::
# line%1:04:01::
# professional%3:01:00::
# time%1:28:05::
# point%1:28:00::
# common%3:00:02::
# hold%2:36:00::
# keep%2:42:00::
# find%2:31:10::
# lead%2:38:00::
# security%1:14:00::
# security%1:21:01::
# professional%3:01:00::
# see%2:31:00::
# keep%2:40:00::
# follow%2:38:00::
# national%3:01:01::
# extend%2:30:06::
# point%1:28:00::
# bring%2:35:04::
# national%3:01:01::
# bad%5:00:00:inferior:02
# positive%5:00:00:advantageous:00
# follow%2:38:01::
# positive%5:00:00:advantageous:00
# line%1:04:01::
# regular%5:00:00:standard:02
# national%3:00:01::
# regular%5:00:00:standard:02
# build%2:36:00::
# hold%2:35:03::
# point%1:28:00::
# life%1:28:00::
# regular%5:00:00:standard:02
# common%3:00:01::
# regular%3:00:00::
# see%2:31:00::
# serve%2:33:00::
# serve%2:42:00::
# line%1:04:01::
# time%1:28:05::
# common%3:00:01::
# physical%3:00:00::
# national%3:00:00::
# time%1:28:00::
# force%1:07:01::
# position%1:04:01::
# bring%2:38:00::
# see%2:31:00::
# case%1:26:00::
# regular%5:00:00:scheduled:00
# professional%3:01:01::
# line%1:04:01::
# regular%5:00:00:scheduled:00
# bad%3:00:00::
# extend%2:30:01::
# line%1:04:01::
# professional%5:00:00:white-collar:00
# common%3:00:02::
# lead%2:41:12::
# point%1:28:00::
# hold%2:31:01::
# build%2:36:09::
# see%2:31:00::
# see%2:31:00::
# national%5:00:00:domestic:00
# regular%5:00:00:frequent:00
# build%2:30:02::
# life%1:28:00::
# keep%2:41:03::
# lead%2:41:12::
# point%1:28:00::
# security%1:12:00::
# security%1:26:00::
# keep%2:41:03::
# hold%2:35:03::
# serve%2:41:02::
# positive%5:00:00:plus:00
# keep%2:41:03::
# find%2:31:10::
# national%3:00:01::
# time%1:28:05::
# see%2:31:00::
# life%1:26:01::
# order%1:10:01::
# order%1:10:03::
# line%1:04:01::
# see%2:31:00::
# common%5:00:00:familiar:02
# point%1:28:00::
# point%1:09:01::
# serve%2:41:02::
# force%1:14:00::
# serve%2:41:02::
# time%1:28:00::
# professional%5:00:00:white-collar:00
# physical%5:00:02:material:01
# build%2:36:00::
# find%2:40:02::
# bring%2:38:00::
# place%1:15:00::
# security%1:26:00::
# keep%2:41:03::
# keep%2:41:03::
# critical%3:00:03::
# regular%5:00:00:standard:02
# find%2:32:00::
# hold%2:35:03::
# hold%2:36:00::
# line%1:04:01::
# hold%2:31:01::
# see%2:31:00::
# keep%2:40:00::
# regular%5:00:00:usual:00
# position%1:04:01::
# extend%2:30:01::
# place%1:15:00::
# line%1:04:01::
# case%1:26:00::
# build%2:36:09::
# extend%2:30:02::
# case%1:10:02::
# find%2:32:00::
# physical%5:00:00:material:01
# see%2:31:00::
# position%1:15:00::
# active%5:00:00:operational:00
# order%1:10:03::
# serve%2:42:00::
# keep%2:41:03::
# force%1:07:01::
# extend%2:40:04::
# serve%2:42:01::
# see%2:31:00::
# bring%2:36:00::
# serve%2:42:12::
# build%2:36:09::
# active%5:00:00:involved:00
# extend%2:30:06::
# find%2:32:01::
# lead%2:38:00::
# place%1:04:01::
# build%2:31:03::
# positive%5:00:00:advantageous:00
# life%1:28:00::
# security%1:21:01::
# case%1:04:00::
# build%2:36:09::
# national%3:01:00::
# major%3:00:07::
# lead%2:38:01::
# case%1:11:00::
# lead%2:38:01::
# time%1:28:06::
# see%2:31:00::
# place%1:04:01::
# see%2:31:00::
# national%5:00:00:domestic:00
# force%1:07:01::
# force%1:18:00::
# critical%5:00:00:indispensable:00
# force%1:04:01::
# life%1:28:01::
# see%2:31:00::
# extend%2:30:06::
# serve%2:41:02::
# place%1:26:00::
# hold%2:40:00::
# life%1:28:00::
# critical%3:00:03::
# keep%2:40:00::
# national%5:00:00:public:00
# keep%2:42:00::
# extend%2:30:09::
# follow%2:38:00::
# major%3:00:06::
# critical%3:00:01::
# line%1:04:01::
# extend%2:40:04::
# bad%3:00:00::
# critical%5:00:00:indispensable:00
# bad%3:00:00::
# time%1:28:05::
# position%1:09:00::
# serve%2:42:01::
# case%1:26:00::
# follow%2:38:00::
# bad%5:00:00:inferior:02
# extend%2:30:09::
# extend%2:40:04::
# security%1:14:00::
# life%1:28:02::
# security%1:21:01::
# follow%2:38:01::
# force%1:14:01::
# regular%3:00:00::
# position%1:04:01::
# major%3:00:02::
# professional%5:00:00:white-collar:00
# keep%2:42:07::
# professional%3:00:02::
# place%1:04:01::
# lead%2:41:00::
# bring%2:38:00::
# keep%2:42:07::
# professional%3:00:01::
# life%1:28:01::
# life%1:28:01::
# major%3:00:02::
# position%1:26:00::
# bad%5:00:00:intense:00
# follow%2:42:02::
# force%1:14:01::
# life%1:26:01::
# life%1:26:01::
# hold%2:40:04::
# lead%2:38:00::
# serve%2:41:02::
# common%5:00:00:shared:00
# place%1:15:04::
# national%3:01:01::
# hold%2:40:04::
# national%3:01:01::
# extend%2:30:06::
# point%1:28:00::
# hold%2:31:01::
# see%2:31:00::
# find%2:31:10::
# life%1:28:00::
# hold%2:35:03::
# line%1:04:01::
# keep%2:42:07::
# positive%3:00:01::
# extend%2:30:01::
# keep%2:41:03::
# see%2:31:00::
# critical%3:00:01::
# time%1:11:00::
# keep%2:42:00::
# find%2:40:02::
# place%1:15:04::
# case%1:10:01::
# extend%2:40:04::
# hold%2:40:00::
# bring%2:36:01::
# see%2:31:00::
# find%2:40:02::
# active%3:00:07::
# follow%2:41:00::
# bad%5:00:00:intense:00
# physical%5:00:02:material:01
# professional%3:01:01::
# follow%2:41:00::
# case%1:10:02::
# professional%3:01:00::
# see%2:31:00::
# point%1:28:00::
# hold%2:40:00::
# national%3:01:01::
# bring%2:38:00::
# hold%2:35:03::
# common%3:00:02::
# keep%2:42:07::
# point%1:09:01::
# keep%2:42:00::
# time%1:11:00::
# follow%2:38:01::
# follow%2:38:13::
# life%1:28:01::
# force%1:04:01::
# keep%2:41:03::
# position%1:26:00::
# critical%3:00:02::
# time%1:28:05::
# bring%2:36:01::
# order%1:10:00::
# keep%2:42:00::
# extend%2:40:04::
# security%1:04:00::
# line%1:04:01::
# extend%2:40:04::
# bad%5:00:00:intense:00
# critical%3:00:01::
# security%1:12:00::
# common%3:00:01::
# major%3:00:06::
# keep%2:41:03::
# find%2:40:02::
# professional%3:01:01::
# physical%3:00:00::
# keep%2:40:00::
# national%3:01:01::
# force%1:07:01::
# bring%2:36:01::
# bring%2:38:00::
# national%3:00:01::
# point%1:09:01::
# bad%5:00:00:inferior:02
# find%2:40:02::
# see%2:31:00::
# place%1:26:00::
# lead%2:42:12::
# position%1:26:00::
# professional%3:01:00::
# place%1:26:00::
# line%1:04:01::
# professional%3:00:01::
# time%1:28:05::
# follow%2:38:00::
# line%1:04:01::
# extend%2:30:02::
# security%1:26:00::
# major%3:00:07::
# hold%2:40:00::
# common%3:00:02::
# see%2:31:00::
# see%2:31:00::
# line%1:04:01::
# life%1:28:00::
# security%1:26:00::
# bring%2:35:00::
# common%3:00:01::
# see%2:31:00::
# place%1:26:00::
# security%1:26:00::
# build%2:36:09::
# follow%2:41:00::
# keep%2:41:03::
# regular%5:00:00:usual:00
# regular%5:00:00:standard:02
# see%2:31:00::
# bring%2:36:01::
# line%1:04:01::
# life%1:26:01::
# place%1:04:01::
# keep%2:42:00::
# hold%2:40:00::
# find%2:40:02::
# time%1:28:05::
# line%1:04:01::
# professional%5:00:00:white-collar:00
# lead%2:41:12::
# force%1:07:01::
# order%1:10:01::
# follow%2:41:00::
# force%1:07:02::
# find%2:40:02::
# national%3:00:01::
# line%1:04:01::
# position%1:26:00::
# regular%5:00:00:symmetrical:00
# professional%5:00:00:white-collar:00
# follow%2:42:02::
# serve%2:42:12::
# positive%3:00:01::
# line%1:04:01::
# follow%2:38:13::
# build%2:36:00::
# case%1:11:00::
# life%1:28:02::
# bring%2:35:04::
# national%3:00:01::
# place%1:15:00::
# line%1:04:01::
# life%1:28:02::
# bring%2:38:00::
# follow%2:41:00::
# hold%2:36:00::
# build%2:36:09::
# place%1:15:04::
# national%3:01:00::
# serve%2:42:03::
# keep%2:42:00::
# serve%2:42:00::
# bring%2:35:04::
# line%1:04:01::
# critical%3:00:01::
# see%2:31:00::
# security%1:12:00::
# lead%2:41:12::
# national%3:00:01::
# line%1:04:01::
# order%1:10:03::
# life%1:28:01::
# active%5:00:00:involved:00
# bad%5:00:00:intense:00
# line%1:04:01::
# life%1:28:00::
# lead%2:41:12::
# line%1:04:01::
# regular%5:00:00:frequent:00
# extend%2:30:02::
# life%1:28:01::
# regular%5:00:00:frequent:00
# bad%5:00:00:intense:00
# extend%2:30:06::
# place%1:15:00::
# lead%2:42:12::
# keep%2:41:03::
# keep%2:42:07::
# build%2:31:03::
# professional%3:00:02::
# major%3:00:07::
# build%2:31:03::
# position%1:15:00::
# professional%3:00:02::
# life%1:28:01::
# line%1:04:01::
# national%5:00:00:public:00
# follow%2:38:13::
# keep%2:42:00::
# point%1:09:01::
# see%2:31:00::
# build%2:30:02::
# serve%2:41:02::
# build%2:36:00::
# keep%2:41:03::
# critical%3:00:03::
# national%5:00:00:domestic:00
# see%2:31:00::
# time%1:11:00::
# extend%2:30:01::
# regular%3:00:00::
# keep%2:42:07::
# see%2:31:00::
# keep%2:41:03::
# line%1:04:01::
# keep%2:41:03::
# see%2:31:00::
# force%1:18:00::
# professional%3:00:01::
# physical%5:00:02:material:01
# critical%5:00:00:indispensable:00
# extend%2:40:04::
# point%1:09:01::
# position%1:15:00::
# hold%2:31:01::
# extend%2:30:09::
# point%1:28:00::
# keep%2:40:00::
# bring%2:35:00::
# line%1:04:01::
# serve%2:33:00::
# keep%2:41:03::
# hold%2:40:00::
# see%2:31:00::
# major%3:00:02::
# bring%2:35:04::
# extend%2:30:06::
# order%1:10:01::
# professional%5:00:00:white-collar:00
# follow%2:41:00::
# follow%2:38:01::
# line%1:04:01::
# point%1:09:01::
# major%3:00:07::
# line%1:04:01::
# place%1:15:00::
# hold%2:31:01::
# build%2:30:02::
# line%1:04:01::
# common%5:00:00:familiar:02
# life%1:26:01::
# common%5:00:00:shared:00
# point%1:28:00::
# physical%5:00:00:material:01
# follow%2:41:00::
# see%2:31:00::
# lead%2:41:12::
# hold%2:40:00::
# find%2:32:01::
# find%2:31:10::
# national%5:00:00:domestic:00
# hold%2:36:00::
# professional%3:01:01::
# place%1:04:01::
# force%1:14:00::
# keep%2:41:03::
# order%1:26:00::
# physical%3:01:00::
# time%1:28:05::
# follow%2:42:02::
# serve%2:33:00::
# lead%2:41:00::
# find%2:40:02::
# find%2:32:01::
# serve%2:42:00::
# find%2:40:02::
# position%1:04:01::
# time%1:28:06::
# force%1:18:00::
# force%1:07:01::
# professional%3:01:00::
# see%2:31:00::
# build%2:36:09::
# build%2:36:09::
# critical%3:00:03::
# lead%2:41:12::
# active%5:00:00:involved:00
# point%1:09:01::
# force%1:04:01::
# case%1:26:00::
# case%1:04:00::
# active%5:00:00:involved:00
# extend%2:30:06::
# case%1:10:01::
# common%3:00:01::
# major%3:00:02::
# hold%2:36:00::
# line%1:04:01::
# national%3:00:00::
# active%3:00:07::
# see%2:31:00::
# bring%2:35:00::
# physical%3:01:00::
# serve%2:42:00::
# see%2:31:00::
# active%3:00:07::
# keep%2:40:00::
# lead%2:41:12::
# keep%2:41:03::
# see%2:31:00::
# line%1:04:01::
# lead%2:41:12::
# professional%5:00:00:white-collar:00
# positive%3:00:01::
# follow%2:38:13::
# life%1:28:01::
# extend%2:30:09::
# national%3:01:01::
# position%1:09:00::
# build%2:31:03::
# keep%2:41:03::
# lead%2:41:00::
# hold%2:35:03::
# build%2:31:03::
# force%1:07:02::
# serve%2:33:00::
# keep%2:41:03::
# find%2:31:10::
# line%1:04:01::
# professional%3:00:01::
# force%1:07:02::
# find%2:40:02::
# regular%5:00:00:standard:02
# follow%2:38:01::
# lead%2:41:12::
# order%1:14:00::
# case%1:04:00::
# serve%2:42:00::
# positive%3:00:01::
# line%1:04:01::
# life%1:26:01::
# active%5:00:00:operational:00
# force%1:14:01::
# keep%2:42:00::
# bring%2:38:00::
# regular%5:00:00:scheduled:00
# see%2:31:00::
# see%2:31:00::
# regular%5:00:00:scheduled:00
# national%3:00:00::
# keep%2:42:07::
# order%1:14:00::
# major%3:00:02::
# security%1:21:04::
# active%5:00:00:operational:00
# build%2:36:00::
# follow%2:41:00::
# build%2:31:03::
# positive%3:00:04::
# physical%3:01:00::
# keep%2:42:07::
# keep%2:41:03::
# hold%2:31:01::
# security%1:21:04::
# lead%2:38:01::
# find%2:40:02::
# security%1:21:01::
# hold%2:31:01::
# see%2:31:00::
# follow%2:38:13::
# build%2:30:02::
# follow%2:38:13::
# build%2:30:02::
# bring%2:36:00::
# lead%2:42:12::
# physical%5:00:00:material:01
# critical%3:00:02::
# professional%3:01:01::
# life%1:28:01::
# order%1:10:01::
# case%1:11:00::
# position%1:09:00::
# see%2:31:00::
# national%3:01:00::
# national%3:00:01::
# national%3:00:00::
# see%2:31:00::
# extend%2:30:06::
# life%1:26:01::
# active%5:00:00:involved:00
# serve%2:42:12::
# position%1:09:00::
# national%5:00:00:public:00
# hold%2:31:01::
# extend%2:30:02::
# build%2:36:00::
# see%2:31:00::
# serve%2:42:00::
# keep%2:40:00::
# position%1:04:01::
# see%2:31:00::
# security%1:21:01::
# build%2:30:02::
# life%1:26:01::
# keep%2:41:03::
# follow%2:38:13::
# physical%3:00:00::
# see%2:31:00::
# critical%3:00:03::
# see%2:31:00::
# security%1:14:00::
# follow%2:41:00::
# positive%3:00:01::
# see%2:31:00::
# time%1:28:05::
# serve%2:42:03::
# see%2:31:00::
# positive%3:00:04::
# critical%5:00:00:indispensable:00
# see%2:31:00::
# follow%2:41:00::
# security%1:21:04::
# build%2:30:02::
# positive%3:00:04::
# position%1:09:00::
# build%2:30:02::
# line%1:04:01::
# force%1:18:00::
# keep%2:42:00::
# keep%2:42:00::
# follow%2:38:13::
# extend%2:30:06::
# extend%2:30:06::
# time%1:28:05::
# see%2:31:00::
# place%1:15:00::
# see%2:31:00::
# time%1:28:05::
# follow%2:41:00::
# critical%3:00:03::
# life%1:26:01::
# follow%2:38:01::
# see%2:31:00::
# line%1:04:01::
# major%3:00:01::
# see%2:31:00::
# build%2:36:00::
# order%1:10:01::
# time%1:28:05::
# regular%5:00:00:frequent:00
# build%2:36:09::
# case%1:26:00::
# lead%2:38:00::
# bring%2:35:00::
# order%1:10:00::
# line%1:04:01::
# regular%5:00:00:frequent:00
# hold%2:42:00::
# physical%3:00:00::
# force%1:04:01::
# active%3:00:07::
# find%2:40:02::
# extend%2:30:09::
# follow%2:38:13::
# bad%5:00:00:intense:00
# lead%2:41:00::
# regular%5:00:00:standard:02
# hold%2:42:00::
# point%1:28:00::
# point%1:28:00::
# regular%5:00:00:scheduled:00
# see%2:31:00::
# force%1:14:00::
# order%1:10:03::
# case%1:11:00::
# line%1:04:01::
# active%5:00:00:operational:00
# common%5:00:00:shared:00
# bring%2:35:04::
# serve%2:42:01::
# regular%5:00:00:standard:02
# line%1:04:01::
# see%2:31:00::
# keep%2:41:03::
# position%1:26:00::
# bad%5:00:00:intense:00
# force%1:14:00::
# professional%3:01:00::
# serve%2:42:12::
# force%1:14:01::
# major%3:00:02::
# see%2:31:00::
# line%1:04:01::
# build%2:31:03::
# hold%2:40:04::
# regular%5:00:00:scheduled:00
# hold%2:31:01::
# bring%2:36:00::
# time%1:28:06::
# keep%2:41:03::
# physical%3:00:00::
# force%1:14:00::
# see%2:31:00::
# find%2:32:01::
# security%1:14:00::
# see%2:31:00::
# position%1:15:00::
# security%1:21:01::
# lead%2:38:00::
# point%1:28:00::
# see%2:31:00::
# line%1:04:01::
# lead%2:41:12::
# serve%2:42:00::
# hold%2:31:01::
# extend%2:30:06::
# keep%2:42:07::
# find%2:40:02::
# lead%2:41:00::
# keep%2:42:00::
# line%1:04:01::
# place%1:15:00::
# national%5:00:00:domestic:00
# physical%5:00:00:material:01
# bring%2:35:04::
# force%1:07:01::
# see%2:31:00::
# bring%2:35:00::
# life%1:28:01::
# keep%2:41:03::
# major%3:00:06::
# force%1:07:02::
# see%2:31:00::
# find%2:31:10::
# see%2:31:00::
# case%1:04:00::
# follow%2:38:13::
# place%1:26:00::
# keep%2:42:00::
# follow%2:38:01::
# line%1:04:01::
# line%1:04:01::
# point%1:28:00::
# point%1:09:01::
# keep%2:42:07::
# lead%2:42:12::
# point%1:28:00::
# place%1:04:01::
# professional%3:01:01::
# extend%2:30:02::
# case%1:11:00::
# force%1:07:01::
# life%1:28:00::
# physical%3:00:00::
# place%1:15:04::
# find%2:31:10::
# critical%3:00:03::
# security%1:12:00::
# build%2:36:09::
# positive%3:00:04::
# extend%2:30:06::
# place%1:15:00::
# hold%2:40:00::
# security%1:21:01::
# force%1:07:02::
# life%1:26:01::
# place%1:04:01::
# see%2:31:00::
# see%2:31:00::
# keep%2:41:03::
# follow%2:38:13::
# point%1:09:01::
# common%5:00:00:familiar:02
# keep%2:41:03::
# order%1:10:00::
# see%2:31:00::
# physical%3:01:00::
# keep%2:41:03::
# major%3:00:07::
# bring%2:38:00::
# line%1:04:01::
# security%1:14:00::
# case%1:04:00::
# force%1:14:00::
# time%1:11:00::
# build%2:36:00::
# keep%2:42:07::
# common%3:00:02::
# line%1:04:01::
# bad%5:00:00:intense:00
# position%1:09:00::
# point%1:28:00::
# find%2:40:02::
# force%1:07:02::
# professional%3:00:01::
# line%1:04:01::
# critical%5:00:00:indispensable:00
# lead%2:38:00::
# case%1:10:02::
# case%1:26:00::
# line%1:04:01::
# extend%2:29:01::
# active%5:00:00:operational:00
# keep%2:40:00::
# follow%2:38:01::
# bring%2:36:00::
# national%3:01:01::
# hold%2:42:00::
# bad%5:00:00:intense:00
# lead%2:41:00::
# follow%2:41:00::
# physical%5:00:00:material:01
# build%2:30:02::
# follow%2:38:00::
# extend%2:29:01::
# build%2:36:09::
# physical%5:00:00:material:01
# life%1:28:01::
# see%2:31:00::
# extend%2:30:01::
# serve%2:33:00::
# time%1:28:05::
# see%2:31:00::
# force%1:14:01::
# force%1:14:00::
# extend%2:30:01::
# build%2:30:02::
# lead%2:38:00::
# physical%3:01:00::
# bad%5:00:00:intense:00
# bring%2:36:00::
# hold%2:35:03::
# physical%3:00:00::
# professional%5:00:00:white-collar:00
# hold%2:36:00::
# order%1:10:03::
# position%1:04:01::
# life%1:28:01::
# follow%2:41:00::
# serve%2:42:00::
# professional%3:00:02::
# physical%3:00:00::
# keep%2:42:00::
# critical%5:00:00:indispensable:00
# national%5:00:00:domestic:00
# follow%2:41:00::
# point%1:09:01::
# hold%2:42:00::
# regular%5:00:00:standard:02
# bring%2:35:00::
# see%2:31:00::
# critical%3:00:02::
# national%3:01:00::
# line%1:04:01::
# national%5:00:00:domestic:00
# keep%2:42:07::
# lead%2:42:12::
# hold%2:40:00::
# point%1:09:01::
# national%3:00:00::
# position%1:09:00::
# line%1:04:01::
# bring%2:35:04::
# bad%5:00:00:intense:00
# time%1:28:05::
# hold%2:36:00::
# national%3:01:00::
# keep%2:41:03::
# physical%5:00:00:material:01
# keep%2:41:03::
# keep%2:40:00::
# follow%2:38:01::
# point%1:28:00::
# regular%5:00:00:standard:02
# line%1:04:01::
# force%1:04:01::
# line%1:04:01::
# see%2:31:00::
# physical%5:00:00:material:01
# regular%5:00:00:standard:02
# follow%2:38:13::
# serve%2:42:12::
# position%1:15:00::
# order%1:14:00::
# keep%2:41:03::
# see%2:31:00::
# find%2:32:00::
# professional%3:00:02::
# point%1:28:00::
# find%2:32:01::
# common%5:00:00:shared:00
# bring%2:35:04::
# national%3:00:01::
# time%1:28:06::
# line%1:04:01::
# build%2:36:00::
# point%1:09:01::
# case%1:10:02::
# active%5:00:00:involved:00
# regular%5:00:00:standard:02
# point%1:09:01::
# position%1:09:00::
# common%3:00:01::
# see%2:31:00::
# line%1:04:01::
# serve%2:42:01::
# force%1:04:01::
# place%1:15:00::
# case%1:10:02::
# national%5:00:00:domestic:00
# major%3:00:02::
# case%1:04:00::
# keep%2:42:00::
# follow%2:38:01::
# follow%2:41:00::
# see%2:31:00::
# line%1:04:01::
# line%1:04:01::
# life%1:28:00::
# find%2:32:00::
# follow%2:38:13::
# life%1:28:01::
# line%1:04:01::
# security%1:12:00::
# see%2:31:00::
# positive%5:00:00:plus:00
# position%1:04:01::
# serve%2:42:00::
# build%2:36:09::
# national%3:01:01::
# life%1:26:01::
# follow%2:38:13::
# order%1:14:00::
# force%1:07:02::
# place%1:04:01::
# hold%2:36:00::
# serve%2:41:02::
# serve%2:33:00::
# keep%2:41:03::
# physical%3:01:00::
# position%1:26:02::
# major%3:00:07::
# see%2:31:00::
# extend%2:30:06::
# case%1:26:00::
# build%2:30:02::
# life%1:26:01::
# time%1:11:00::
# security%1:21:01::
# follow%2:42:02::
# see%2:31:00::
# order%1:10:03::
# case%1:10:02::
# order%1:10:01::
# active%5:00:00:involved:00
# position%1:15:00::
# find%2:31:10::
# bring%2:35:00::
# lead%2:41:12::
# extend%2:30:02::
# line%1:04:01::
# national%5:00:00:domestic:00
# find%2:40:02::
# hold%2:40:00::
# line%1:04:01::
# force%1:14:01::
# bring%2:38:00::
# line%1:04:01::
# bring%2:38:00::
# keep%2:40:00::
# bad%5:00:00:intense:00
# find%2:32:00::
# life%1:28:00::
# critical%3:00:03::
# bad%5:00:00:intense:00
# point%1:28:00::
# bring%2:36:01::
# keep%2:41:03::
# regular%5:00:00:standard:02
# keep%2:40:00::
# build%2:31:03::
# positive%3:00:04::
# point%1:28:00::
# place%1:15:00::
# national%5:00:00:public:00
# extend%2:30:02::
# point%1:28:00::
# follow%2:38:01::
# follow%2:38:01::
# follow%2:38:13::
# line%1:04:01::
# keep%2:41:03::
# order%1:10:03::
# see%2:31:00::
# critical%3:00:03::
# see%2:31:00::
# find%2:32:00::
# hold%2:31:01::
# follow%2:38:13::
# extend%2:30:06::
# position%1:04:01::
# case%1:04:00::
# keep%2:41:03::
# line%1:04:01::
# extend%2:40:04::
# order%1:10:03::
# serve%2:42:01::
# regular%5:00:00:standard:02
# serve%2:33:00::
# see%2:31:00::
# extend%2:30:02::
# find%2:31:10::
# hold%2:31:01::
# serve%2:41:02::
# point%1:09:01::
# extend%2:29:01::
# lead%2:41:12::
# serve%2:42:03::
# find%2:32:01::
# place%1:15:04::
# keep%2:40:00::
# point%1:09:01::
# professional%3:01:01::
# keep%2:41:03::
# order%1:26:00::
# security%1:21:01::
# line%1:04:01::
# bad%5:00:00:intense:00
# critical%5:00:00:indispensable:00
# see%2:31:00::
# force%1:04:01::
# find%2:40:02::
# national%3:00:01::
# order%1:10:00::
# serve%2:41:02::
# life%1:28:01::
# case%1:11:00::
# force%1:14:01::
# security%1:14:00::
# major%3:00:06::
# professional%3:01:00::
# serve%2:41:02::
# force%1:04:01::
# find%2:32:01::
# keep%2:42:00::
# build%2:31:03::
# regular%5:00:00:usual:00
# bad%3:00:00::
# extend%2:30:01::
# national%3:00:01::
# hold%2:36:00::
# positive%3:00:01::
# place%1:04:01::
# lead%2:38:00::
# major%3:00:06::
# active%3:00:07::
# order%1:26:00::
# build%2:36:00::
# see%2:31:00::
# national%5:00:00:domestic:00
# hold%2:36:00::
# line%1:04:01::
# follow%2:38:01::
# hold%2:31:01::
# ...
# life%1:28:00::
# find%2:32:00::
# physical%3:00:00::
# bring%2:35:00::
# bring%2:35:00::
# force%1:18:00::
# keep%2:41:03::
# bring%2:35:00::
# serve%2:41:02::
# physical%3:00:00::
# find%2:31:10::
# follow%2:42:02::
# place%1:15:00::
# positive%3:00:04::
# common%3:00:01::
# point%1:09:01::
# line%1:04:01::
# keep%2:42:07::
# national%3:01:01::
# serve%2:41:02::
# line%1:04:01::
# see%2:31:00::
# point%1:09:01::
# point%1:28:00::
# lead%2:38:01::
# security%1:21:01::
# see%2:31:00::
# positive%3:00:01::
# force%1:04:01::
# bring%2:38:00::
# keep%2:42:07::
# professional%3:01:00::
# find%2:31:10::
# see%2:31:00::
# order%1:10:01::
# life%1:28:01::
# common%5:00:00:familiar:02
# see%2:31:00::
# line%1:04:01::
# serve%2:41:02::
# follow%2:38:01::
# find%2:32:01::
# serve%2:41:02::
# extend%2:40:04::
# hold%2:36:00::
# national%5:00:00:public:00
# line%1:04:01::
# line%1:04:01::
# critical%5:00:00:indispensable:00
# major%3:00:02::
# see%2:31:00::
# serve%2:33:00::
# force%1:04:01::
# physical%5:00:02:material:01
# life%1:28:00::
# build%2:36:09::
# line%1:04:01::
# common%3:00:01::
# professional%3:00:01::
# point%1:09:01::
# line%1:04:01::
# extend%2:29:01::
# find%2:31:10::
# line%1:04:01::
# lead%2:38:00::
# keep%2:41:03::
# keep%2:40:00::
# find%2:32:01::
# keep%2:42:00::
# place%1:15:00::
# extend%2:40:04::
# major%3:00:06::
# position%1:04:01::
# active%3:00:07::
# follow%2:41:00::
# time%1:28:06::
# keep%2:40:00::
# critical%3:00:03::
# security%1:14:00::
# follow%2:42:02::
# see%2:31:00::
# place%1:04:01::
# case%1:04:00::
# line%1:04:01::
# force%1:18:00::
# security%1:26:00::
# see%2:31:00::
# serve%2:42:12::
# find%2:40:02::
# see%2:31:00::
# hold%2:40:00::
# major%3:00:06::
# serve%2:41:02::
# major%3:00:06::
# major%3:00:07::
# position%1:26:02::
# line%1:04:01::
# see%2:31:00::
# serve%2:42:03::
# see%2:31:00::
# line%1:04:01::
# see%2:31:00::
# bad%5:00:00:intense:00
# keep%2:42:00::
# order%1:10:01::
# professional%3:01:00::
# see%2:31:00::
# place%1:15:00::
# time%1:28:05::
# active%3:00:03::
# bad%5:00:00:intense:00
# hold%2:31:01::
# positive%3:00:01::
# follow%2:38:13::
# hold%2:40:04::
# follow%2:41:00::
# see%2:31:00::
# order%1:10:03::
# time%1:11:00::
# regular%5:00:00:standard:02
# line%1:04:01::
# extend%2:30:09::
# security%1:21:01::
# serve%2:33:00::
# case%1:10:01::
# physical%3:01:00::
# case%1:10:01::
# security%1:12:00::
# keep%2:42:00::
# position%1:09:00::
# national%3:00:01::
# position%1:15:00::
# hold%2:31:01::
# keep%2:41:03::
# active%5:00:00:involved:00
# serve%2:41:02::
# line%1:04:01::
# lead%2:38:00::
# line%1:04:01::
# follow%2:41:00::
# major%3:00:07::
# line%1:04:01::
# hold%2:40:04::
# security%1:26:00::
# case%1:10:01::
# build%2:31:03::
# force%1:07:02::
# professional%5:00:00:white-collar:00
# order%1:10:03::
# regular%5:00:00:standard:02
# see%2:31:00::
# line%1:04:01::
# see%2:31:00::
# order%1:10:03::
# security%1:21:01::
# lead%2:38:00::
# positive%3:00:01::
# line%1:04:01::
# force%1:07:01::
# line%1:04:01::
# lead%2:42:12::
# point%1:28:00::
# lead%2:42:12::
# common%3:00:02::
# serve%2:33:00::
# hold%2:40:00::
# position%1:15:00::
# see%2:31:00::
# see%2:31:00::
# active%5:00:00:operational:00
# lead%2:41:00::
# lead%2:38:01::
# see%2:31:00::
# point%1:28:00::
# place%1:26:00::
# point%1:09:01::
# line%1:04:01::
# extend%2:30:06::
# follow%2:38:01::
# critical%3:00:01::
# hold%2:40:04::
# build%2:31:03::
# active%3:00:07::
# case%1:10:02::
# see%2:31:00::
# hold%2:31:01::
# bring%2:36:00::
# line%1:04:01::
# serve%2:33:00::
# positive%3:00:01::
# force%1:18:00::
# life%1:28:01::
# case%1:10:02::
# physical%5:00:00:material:01
# see%2:31:00::
# hold%2:35:03::
# keep%2:41:03::
# build%2:36:09::
# bad%5:00:00:intense:00
# force%1:04:01::
# see%2:31:00::
# life%1:26:01::
# bring%2:35:04::
# serve%2:41:02::
# bad%5:00:00:intense:00
# see%2:31:00::
# see%2:31:00::
# serve%2:42:12::
# keep%2:41:03::
# common%3:00:02::
# see%2:31:00::
# order%1:10:00::
# bring%2:38:00::
# active%5:00:00:involved:00
# regular%3:00:00::
# line%1:04:01::
# lead%2:38:00::
# line%1:04:01::
# time%1:28:05::
# security%1:26:00::
# hold%2:40:00::
# positive%3:00:01::
# keep%2:41:03::
# professional%5:00:00:white-collar:00
# regular%5:00:00:standard:02
# keep%2:42:07::
# follow%2:38:00::
# find%2:40:02::
# follow%2:38:13::
# critical%3:00:03::
# common%5:00:00:familiar:02
# position%1:09:00::
# keep%2:41:03::
# see%2:31:00::
# security%1:21:04::
# common%3:00:02::
# follow%2:41:00::
# lead%2:41:12::
# major%3:00:07::
# active%5:00:00:operational:00
# line%1:04:01::
# time%1:11:00::
# see%2:31:00::
# lead%2:41:12::
# keep%2:42:00::
# follow%2:38:00::
# bad%5:00:00:intense:00
# serve%2:42:03::
# physical%5:00:02:material:01
# major%3:00:06::
# hold%2:36:00::
# build%2:31:03::
# order%1:26:00::
# common%3:00:02::
# position%1:04:01::
# line%1:04:01::
# follow%2:38:13::
# keep%2:40:00::
# lead%2:41:12::
# see%2:31:00::
# professional%3:00:01::
# point%1:28:00::
# professional%3:01:01::
# active%5:00:00:involved:00
# line%1:04:01::
# national%3:01:00::
# national%3:00:01::
# serve%2:42:03::
# position%1:09:00::
# find%2:40:02::
# build%2:36:09::
# find%2:32:01::
# time%1:28:05::
# line%1:04:01::
# point%1:09:01::
# line%1:04:01::
# build%2:36:00::
# see%2:31:00::
# bad%5:00:00:intense:00
# hold%2:40:00::
# major%3:00:07::
# serve%2:42:01::
# lead%2:38:00::
# build%2:36:00::
# follow%2:38:00::
# line%1:04:01::
# serve%2:33:00::
# security%1:26:00::
# force%1:04:01::
# extend%2:30:02::
# regular%5:00:00:standard:02
# line%1:04:01::
# regular%3:00:00::
# build%2:36:09::
# see%2:31:00::
# line%1:04:01::
# serve%2:33:00::
# line%1:04:01::
# case%1:26:00::
# follow%2:38:00::
# security%1:14:00::
# case%1:11:00::
# critical%3:00:03::
# line%1:04:01::
# life%1:26:01::
# national%5:00:00:domestic:00
# see%2:31:00::
# hold%2:35:03::
# lead%2:38:01::
# force%1:14:01::
# time%1:28:00::
# keep%2:41:03::
# follow%2:41:00::
# critical%3:00:01::
# professional%3:01:00::
# regular%5:00:00:symmetrical:00
# positive%5:00:00:advantageous:00
# bring%2:36:01::
# serve%2:33:00::
# force%1:04:01::
# bring%2:35:00::
# physical%3:00:00::
# keep%2:41:03::
# security%1:14:00::
# extend%2:30:09::
# see%2:31:00::
# keep%2:42:00::
# lead%2:41:00::
# time%1:11:00::
# place%1:15:00::
# extend%2:30:02::
# lead%2:41:00::
# see%2:31:00::
# time%1:28:06::
# serve%2:42:12::
# bad%5:00:00:intense:00
# bad%5:00:00:intense:00
# security%1:21:01::
# critical%3:00:02::
# hold%2:36:00::
# see%2:31:00::
# keep%2:42:00::
# line%1:04:01::
# hold%2:31:01::
# serve%2:42:03::
# line%1:04:01::
# positive%3:00:01::
# time%1:11:00::
# point%1:28:00::
# place%1:26:00::
# build%2:30:02::
# lead%2:41:12::
# national%3:01:00::
# serve%2:41:02::
# build%2:36:00::
# force%1:07:01::
# point%1:28:00::
# see%2:31:00::
# extend%2:40:04::
# force%1:18:00::
# lead%2:42:12::
# active%5:00:00:involved:00
# critical%3:00:02::
# critical%5:00:00:indispensable:00
# position%1:26:00::
# serve%2:33:00::
# physical%3:01:00::
# follow%2:38:01::
# position%1:09:00::
# bad%5:00:00:intense:00
# lead%2:41:12::
# case%1:26:00::
# follow%2:38:13::
# case%1:04:00::
# common%5:00:00:shared:00
# active%5:00:00:involved:00
# see%2:31:00::
# line%1:04:01::
# security%1:26:00::
# order%1:10:03::
# line%1:04:01::
# build%2:36:00::
# serve%2:33:00::
# keep%2:41:03::
# critical%3:00:02::
# point%1:09:01::
# extend%2:30:02::
# order%1:14:00::
# active%5:00:00:operational:00
# force%1:07:01::
# life%1:26:01::
# see%2:31:00::
# serve%2:42:03::
# security%1:14:00::
# lead%2:41:00::
# security%1:21:01::
# force%1:07:01::
# force%1:07:02::
# national%3:00:01::
# build%2:31:03::
# place%1:04:01::
# keep%2:42:00::
# physical%5:00:02:material:01
# see%2:31:00::
# bad%5:00:00:intense:00
# serve%2:33:00::
# see%2:31:00::
# line%1:04:01::
# line%1:04:01::
# professional%3:00:01::
# time%1:28:05::
# physical%3:00:00::
# common%3:00:02::
# extend%2:29:01::
# force%1:07:01::
# security%1:14:00::
# serve%2:42:03::
# time%1:28:05::
# major%3:00:02::
# hold%2:36:00::
# line%1:04:01::
# extend%2:30:09::
# see%2:31:00::
# follow%2:41:00::
# line%1:04:01::
# lead%2:38:00::
# line%1:04:01::
# see%2:31:00::
# bring%2:35:04::
# major%3:00:06::
# national%3:00:00::
# hold%2:40:00::
# lead%2:41:12::
# place%1:26:00::
# keep%2:42:07::
# see%2:31:00::
# line%1:04:01::
# position%1:26:00::
# physical%5:00:02:material:01
# line%1:04:01::
# critical%3:00:03::
# force%1:14:01::
# life%1:28:02::
# serve%2:41:02::
# national%3:01:01::
# follow%2:38:13::
# see%2:31:00::
# see%2:31:00::
# physical%3:00:00::
# extend%2:40:04::
# regular%5:00:00:frequent:00
# life%1:28:02::
# bad%3:00:00::
# place%1:15:04::
# place%1:26:00::
# line%1:04:01::
# security%1:26:00::
# see%2:31:00::
# common%3:00:01::
# position%1:26:02::
# serve%2:42:00::
# keep%2:41:03::
# position%1:15:00::
# extend%2:40:04::
# see%2:31:00::
# see%2:31:00::
# see%2:31:00::
# position%1:09:00::
# force%1:04:01::
# life%1:28:00::
# common%5:00:00:familiar:02
# lead%2:38:01::
# major%3:00:02::
# bring%2:38:00::
# position%1:26:00::
# case%1:26:00::
# bring%2:36:00::
# serve%2:42:00::
# see%2:31:00::
# line%1:04:01::
# extend%2:30:09::
# bad%3:00:00::
# lead%2:41:00::
# keep%2:42:00::
# point%1:09:01::
# bring%2:35:00::
# serve%2:42:03::
# case%1:26:00::
# hold%2:40:00::
# national%5:00:00:public:00
# national%3:01:00::
# national%5:00:00:domestic:00
# force%1:14:01::
# line%1:04:01::
# life%1:28:01::
# regular%5:00:00:scheduled:00
# bring%2:35:04::
# case%1:11:00::
# follow%2:38:13::
# security%1:26:00::
# line%1:04:01::
# serve%2:41:02::
# position%1:15:00::
# critical%3:00:01::
# find%2:40:02::
# professional%3:01:00::
# keep%2:40:00::
# national%3:01:01::
# security%1:21:01::
# keep%2:41:03::
# place%1:26:00::
# bad%5:00:00:inferior:02
# life%1:28:01::
# common%3:00:02::
# time%1:28:00::
# line%1:04:01::
# serve%2:33:00::
# case%1:26:00::
# line%1:04:01::
# time%1:28:00::
# build%2:30:02::
# see%2:31:00::
# case%1:10:01::
# place%1:04:01::
# follow%2:41:00::
# common%5:00:00:shared:00
# case%1:26:00::
# place%1:15:00::
# place%1:15:04::
# life%1:26:01::
# see%2:31:00::
# time%1:28:06::
# serve%2:42:00::
# follow%2:38:01::
# security%1:21:04::
# bad%5:00:00:intense:00
# critical%3:00:03::
# active%3:00:03::
# time%1:28:06::
# see%2:31:00::
# see%2:31:00::
# hold%2:31:01::
# follow%2:38:01::
# follow%2:38:13::
# find%2:31:10::
# bring%2:36:00::
# hold%2:35:03::
# position%1:04:01::
# follow%2:41:00::
# major%3:00:06::
# hold%2:31:01::
# major%3:00:02::
# professional%3:01:01::
# extend%2:30:01::
# build%2:36:09::
# place%1:26:00::
# order%1:10:00::
# active%5:00:00:operational:00
# bad%5:00:00:intense:00
# physical%5:00:00:material:01
# keep%2:41:03::
# critical%3:00:01::
# major%3:00:02::
# build%2:30:02::
# hold%2:35:03::
# order%1:10:03::
# position%1:04:01::
# bring%2:35:00::
# line%1:04:01::
# lead%2:38:00::
# force%1:07:02::
# time%1:28:06::
# security%1:21:01::
# extend%2:30:06::
# regular%5:00:00:standard:02
# critical%3:00:01::
# life%1:26:01::
# see%2:31:00::
# regular%5:00:00:frequent:00
# regular%5:00:00:frequent:00
# keep%2:42:00::
# order%1:26:00::
# life%1:28:00::
# life%1:28:02::
# find%2:32:00::
# time%1:28:06::
# keep%2:42:00::
# see%2:31:00::
# point%1:09:01::
# line%1:04:01::
# major%3:00:02::
# hold%2:40:04::
# life%1:28:01::
# keep%2:41:03::
# hold%2:35:03::
# physical%5:00:02:material:01
# build%2:31:03::
# lead%2:38:01::
# serve%2:41:02::
# major%3:00:02::
# position%1:26:00::
# case%1:10:01::
# order%1:10:03::
# keep%2:42:00::
# build%2:31:03::
# follow%2:38:13::
# extend%2:30:06::
# hold%2:40:00::
# physical%5:00:02:material:01
# force%1:18:00::
# bring%2:35:00::
# time%1:28:05::
# bad%5:00:00:intense:00
# life%1:26:01::
# build%2:36:00::
# time%1:28:05::
# keep%2:41:03::
# follow%2:38:00::
# extend%2:30:06::
# see%2:31:00::
# line%1:04:01::
# time%1:28:05::
# follow%2:42:02::
# order%1:10:00::
# find%2:40:02::
# see%2:31:00::
# force%1:14:00::
# find%2:31:10::
# case%1:10:01::
# serve%2:41:02::
# hold%2:40:00::
# place%1:04:01::
# line%1:04:01::
# see%2:31:00::
# professional%3:01:01::
# place%1:15:00::
# case%1:11:00::
# hold%2:31:01::
# position%1:15:00::
# see%2:31:00::
# life%1:28:01::
# active%5:00:00:operational:00
# physical%3:00:00::
# force%1:14:01::
# regular%5:00:00:frequent:00
# position%1:09:00::
# bring%2:36:00::
# major%3:00:02::
# keep%2:40:00::
# case%1:10:02::
# place%1:15:00::
# see%2:31:00::
# hold%2:40:04::
# active%3:00:03::
# major%3:00:02::
# keep%2:42:07::
# line%1:04:01::
# lead%2:41:12::
# position%1:04:01::
# keep%2:42:00::
# find%2:31:10::
# find%2:40:02::
# bring%2:36:00::
# follow%2:41:00::
# see%2:31:00::
# extend%2:29:01::
# build%2:36:00::
# find%2:40:02::
# hold%2:36:00::
# position%1:26:02::
# keep%2:41:03::
# serve%2:33:00::
# line%1:04:01::
# serve%2:42:12::
# active%5:00:00:operational:00
# bring%2:36:01::
# professional%3:01:00::
# follow%2:38:01::
# see%2:31:00::
# line%1:04:01::
# order%1:10:01::
# life%1:28:01::
# line%1:04:01::
# build%2:36:00::
# national%3:01:01::
# build%2:36:00::
# time%1:28:05::
# see%2:31:00::
# keep%2:41:03::
# professional%3:01:00::
# keep%2:42:07::
# order%1:10:00::
# physical%3:01:00::
# positive%3:00:01::
# common%5:00:00:shared:00
# keep%2:42:00::
# point%1:28:00::
# position%1:26:02::
# position%1:04:01::
# line%1:04:01::
# life%1:28:02::
# extend%2:40:04::
# order%1:10:03::
# time%1:28:00::
# major%3:00:06::
# bring%2:35:04::
# lead%2:41:00::
# hold%2:31:01::
# professional%3:00:02::
# critical%5:00:00:indispensable:00
# physical%5:00:00:material:01
# professional%3:01:01::
# build%2:36:00::
# critical%3:00:03::
# professional%5:00:00:white-collar:00
# serve%2:42:03::
# bring%2:38:00::
# force%1:14:00::
# common%5:00:00:familiar:02
# hold%2:35:03::
# extend%2:30:02::
# line%1:04:01::
# active%3:00:07::
# life%1:26:01::
# line%1:04:01::
# line%1:04:01::
# place%1:04:01::
# common%3:00:02::
# find%2:32:01::
# force%1:14:00::
# see%2:31:00::
# bad%5:00:00:intense:00
# hold%2:31:01::
# critical%3:00:03::
# hold%2:40:04::
# national%5:00:00:public:00
# hold%2:31:01::
# order%1:26:00::
# keep%2:41:03::
# national%3:00:01::
# national%3:00:00::
# extend%2:30:01::
# line%1:04:01::
# follow%2:38:13::
# common%5:00:00:familiar:02
# time%1:11:00::
# see%2:31:00::
# bad%5:00:00:inferior:02
# case%1:11:00::
# point%1:28:00::
# see%2:31:00::
# see%2:31:00::
# position%1:04:01::
# find%2:32:01::
# build%2:31:03::
# keep%2:40:00::
# bring%2:36:01::
# force%1:07:02::
# line%1:04:01::
# critical%3:00:02::
# extend%2:30:02::
# order%1:10:01::
# extend%2:30:01::
# line%1:04:01::
# find%2:31:10::
# time%1:28:05::
# major%3:00:02::
# line%1:04:01::
# follow%2:38:01::
# security%1:21:04::
# positive%5:00:00:advantageous:00
# bad%3:00:00::
# active%3:00:07::
# major%3:00:02::
# see%2:31:00::
# hold%2:40:00::
# case%1:04:00::
# position%1:26:02::
# follow%2:42:02::
# place%1:15:04::
# time%1:11:00::
# build%2:36:00::
# keep%2:41:03::
# active%3:00:03::
# keep%2:42:07::
# follow%2:41:00::
# security%1:26:00::
# line%1:04:01::
# lead%2:42:12::
# force%1:07:02::
# time%1:28:06::
# follow%2:41:00::
# major%3:00:07::
# serve%2:42:03::
# see%2:31:00::
# security%1:21:01::
# positive%3:00:04::
# case%1:26:00::
# line%1:04:01::
# see%2:31:00::
# serve%2:42:12::
# lead%2:41:12::
# national%3:01:00::
# point%1:28:00::
# line%1:04:01::
# extend%2:29:01::
# active%5:00:00:involved:00
# see%2:31:00::
# keep%2:41:03::
# position%1:26:02::
# physical%3:00:00::
# physical%5:00:00:material:01
# find%2:40:02::
# national%3:01:01::
# see%2:31:00::
# see%2:31:00::
# major%3:00:07::
# see%2:31:00::
# critical%3:00:02::
# place%1:15:04::
# positive%5:00:00:advantageous:00
# find%2:32:00::
# case%1:10:02::
# follow%2:38:13::
# life%1:28:01::
# professional%3:01:00::
# force%1:18:00::
# bring%2:35:00::
# regular%5:00:00:standard:02
# common%5:00:00:familiar:02
# extend%2:30:09::
# extend%2:30:01::
# hold%2:42:00::
# keep%2:40:00::
# keep%2:41:03::
# position%1:15:00::
# positive%5:00:00:plus:00
# security%1:12:00::
# lead%2:42:12::
# see%2:31:00::
# lead%2:42:12::
# active%5:00:00:involved:00
# order%1:10:03::
# time%1:28:00::
# common%5:00:00:familiar:02
# life%1:26:01::
# positive%5:00:00:advantageous:00
# see%2:31:00::
# order%1:10:01::
# line%1:04:01::
# extend%2:30:09::
# hold%2:40:00::
# extend%2:40:04::
# case%1:10:02::
# keep%2:42:00::
# bring%2:35:00::
# active%5:00:00:operational:00
# extend%2:30:09::
# keep%2:41:03::
# common%5:00:00:shared:00
# life%1:28:00::
# lead%2:41:00::
# critical%3:00:01::
# regular%5:00:00:scheduled:00
# national%5:00:00:public:00
# line%1:04:01::
# position%1:09:00::
# force%1:14:00::
# life%1:28:01::
# bring%2:35:00::
# physical%5:00:00:material:01
# active%5:00:00:involved:00
# keep%2:41:03::
# active%5:00:00:operational:00
# national%3:00:00::
# line%1:04:01::
# keep%2:40:00::
# keep%2:40:00::
# time%1:11:00::
# follow%2:38:00::
# keep%2:42:07::
# see%2:31:00::
# physical%5:00:00:material:01
# see%2:31:00::
# life%1:26:01::
# lead%2:41:12::
# keep%2:41:03::
# regular%3:00:00::
# professional%3:01:01::
# see%2:31:00::
# professional%5:00:00:white-collar:00
# place%1:15:04::
# see%2:31:00::
# point%1:28:00::
# force%1:14:01::
# keep%2:42:07::
# positive%5:00:00:plus:00
# keep%2:42:00::
# find%2:32:01::
# life%1:28:01::
# national%5:00:00:domestic:00
# bring%2:38:00::
# major%3:00:07::
# point%1:09:01::
# lead%2:41:12::
# find%2:32:00::
# follow%2:41:00::
# life%1:26:01::
# major%3:00:02::
# see%2:31:00::
# security%1:14:00::
# line%1:04:01::
# line%1:04:01::
# build%2:36:09::
# bring%2:38:00::
# build%2:30:02::
# keep%2:41:03::
# case%1:11:00::
# serve%2:42:01::
# life%1:28:00::
# follow%2:42:02::
# line%1:04:01::
# critical%3:00:02::
# major%3:00:02::
# keep%2:41:03::
# time%1:28:00::
# follow%2:38:00::
# hold%2:40:00::
# regular%5:00:00:scheduled:00

# %%
print(avg)
# Out:
# 0.7233317960990072
