# %% [markdown]
# <a href="https://colab.research.google.com/github/ollema/nlp2019/blob/master/A1_BERT_WSD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook uses parts of the BERT example:
# ```
# http://www.cse.chalmers.se/~richajo/nlp2019/l5/Text%20classification%20using%20BERT.html
# ```
#
# To run this notebook, just press "Run all"!

# %%
# !pip install transformers
# !wget https://raw.githubusercontent.com/ollema/nlp2019/master/a1_data/wsd_train.txt
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.6/dist-packages (2.1.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from transformers) (1.17.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from transformers) (4.28.1)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.6/dist-packages (from transformers) (0.0.35)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.6/dist-packages (from transformers) (0.1.83)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.6/dist-packages (from transformers) (1.10.13)
# Requirement already satisfied: regex in /usr/local/lib/python3.6/dist-packages (from transformers) (2019.11.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from transformers) (2.21.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (0.14.0)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (7.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (1.12.0)
# Requirement already satisfied: botocore<1.14.0,>=1.13.13 in /usr/local/lib/python3.6/dist-packages (from boto3->transformers) (1.13.13)
# Requirement already satisfied: s3transfer<0.3.0,>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from boto3->transformers) (0.2.1)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3->transformers) (0.9.4)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2019.9.11)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: python-dateutil<2.8.1,>=2.1; python_version >= "2.7" in /usr/local/lib/python3.6/dist-packages (from botocore<1.14.0,>=1.13.13->boto3->transformers) (2.6.1)
# Requirement already satisfied: docutils<0.16,>=0.10 in /usr/local/lib/python3.6/dist-packages (from botocore<1.14.0,>=1.13.13->boto3->transformers) (0.15.2)
# --2019-11-13 09:39:22--  https://raw.githubusercontent.com/ollema/nlp2019/master/a1_data/wsd_train.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 46435645 (44M) [text/plain]
# Saving to: ‘wsd_train.txt.2’
#
# wsd_train.txt.2     100%[===================>]  44.28M   291MB/s    in 0.2s
#
# 2019-11-13 09:39:22 (291 MB/s) - ‘wsd_train.txt.2’ saved [46435645/46435645]

# %%
import torch
from torch import nn
import time
import torchtext

from collections import defaultdict, OrderedDict
import copy
import random
import sys
random.seed(1)
torch.manual_seed(1)

import matplotlib.pyplot as plt

# %config InlineBackend.figure_format = 'retina' 
plt.style.use('seaborn')

from transformers import DistilBertTokenizer, DistilBertForSequenceClassification, AdamW
model_name = 'distilbert-base-uncased'

tokenizer = DistilBertTokenizer.from_pretrained(model_name)

# A small helper function that will call the BERT tokenizer and truncate.
def bert_tokenize(sen):
    return tokenizer.tokenize(sen)[:138]


def read_data(corpus_file, doc_start, with_padding = True):
    """ Parses input file and returns filtered datasets for each word-type in corpus as well as
    list of word-types found in corpus. """
    # Initialization
    text = torchtext.data.Field(sequential=True, tokenize=bert_tokenize, pad_token=tokenizer.pad_token,
                                init_token=tokenizer.cls_token, eos_token=tokenizer.sep_token)
    label = torchtext.data.LabelField(is_target=True)
    datafields = [('text', text), ('label', label)]
    label_column = 0

    if with_padding == True:
        pad_string = tokenizer.pad_token
        sentence_length = 140
        half_sentence_length = int(sentence_length/2)
        with open(corpus_file, encoding='utf-8') as f:
            examples = []
            for line in f:
                columns = line.strip().split(maxsplit=doc_start)
                position_of_wordtype = int(columns[2])

                # Split the long string doc into array and extract words before the wordtype.
                doc = columns[-1]
                doc_string_vector = doc.split()
                temp_pad = [pad_string for x in range(0,70)]

                padded_doc = []
                padded_doc.extend(temp_pad)
                padded_doc.extend(doc_string_vector)
                padded_doc.extend(temp_pad)

                sliced_doc = padded_doc[position_of_wordtype:position_of_wordtype + 140]

                if len(sliced_doc) != 140:
                    print(sliced_doc)
                    raise RuntimeError

                sliced_doc = " ".join(sliced_doc)
                label = columns[label_column]

                examples.append(torchtext.data.Example.fromlist([sliced_doc, label], datafields))
    else:
        with open(corpus_file, encoding='utf-8') as f:
            examples = []
            for line in f:
                columns = line.strip().split(maxsplit=doc_start)
                doc = columns[-1]
                label = columns[label_column]
                examples.append(torchtext.data.Example.fromlist([doc, label], datafields))
    unfiltered_data = torchtext.data.Dataset(examples, datafields,filter_pred=None)

    # Read complete dataset to get set of word-types. E.i 'keep', 'line'...
    filter_function = None
    word_types = set()
    for example in unfiltered_data.examples:
        word_types.add(example.label.split("%", 1)[0])
    word_types = list(word_types)

    # Create filtered datasets for each word-type
    filtered_datasets = OrderedDict()
    for a_word_type in word_types:
        filter_function = lambda ex: ex.label.split("%", 1)[0] == a_word_type
        text = torchtext.data.Field(sequential=True, tokenize=bert_tokenize, pad_token=tokenizer.pad_token,
                                    init_token=tokenizer.cls_token, eos_token=tokenizer.sep_token)
        label = torchtext.data.LabelField(is_target=True)
        datafields = [('text', text), ('label', label)]

        filtered_data_set = torchtext.data.Dataset(examples, datafields, filter_pred=filter_function)
        filtered_datasets[a_word_type] = (filtered_data_set, text, label)
    return filtered_datasets


def evaluate_validation(scores, gold):
    guesses = scores.argmax(dim=1)
    return (guesses == gold).sum().item()

filtered_datasets = read_data('wsd_train.txt', doc_start=4)

models = OrderedDict()
max_verifications = OrderedDict()
model_vocabs = OrderedDict()
model_label_vocabs = OrderedDict()

for word_type, filtered_dataset in filtered_datasets.items():
    dataset = filtered_dataset[0]
    text = filtered_dataset[1]
    label = filtered_dataset[2]

    train, valid = dataset.split([0.8, 0.2])
    
    text.build_vocab(train)
    model_vocabs[word_type] = text.vocab
    label.build_vocab(train)
    model_label_vocabs[word_type] = label.vocab

    text.vocab.stoi = tokenizer.vocab
    text.vocab.itos = list(tokenizer.vocab)

    device = 'cuda'

    train_iterator = torchtext.data.Iterator(
        train,
        device=device,
        batch_size=32,
        repeat=False,
        train=True,
        sort=False)

    valid_iterator = torchtext.data.Iterator(
        valid,
        device=device,
        batch_size=32,
        repeat=False,
        train=False,
        sort=False)
    
    n_senses = len(label.vocab)

    print(f"Using DistilBertForSequenceClassification")
    model = DistilBertForSequenceClassification.from_pretrained(model_name, num_labels=n_senses)
    model.cuda()

    no_decay = ['bias', 'LayerNorm.weight']
    decay = 0.01
    optimizer_grouped_parameters = [
        {'params': [p for n, p in model.named_parameters() if not any(nd in n for nd in no_decay)], 'weight_decay': decay},
        {'params': [p for n, p in model.named_parameters() if any(nd in n for nd in no_decay)], 'weight_decay': 0.0}
    ]

    optimizer = AdamW(optimizer_grouped_parameters, lr=5e-5, eps=1e-8)

    n_epochs = 2

    history = defaultdict(list)
    max_val_acc = -1

    print(f"Training {word_type}...")
    for i in range(n_epochs):
        
        t0 = time.time()
        
        loss_sum = 0
        n_batches = 0

        model.train()
        
        for batch in train_iterator:
            print('.', end='')
            sys.stdout.flush()

            text = batch.text.t()

            optimizer.zero_grad()

            outputs = model(text, labels=batch.label)
                        
            loss = outputs[0]
            
            loss.backward()
            optimizer.step()
                        
            loss_sum += loss.item()
            n_batches += 1
        
        train_loss = loss_sum / n_batches
        history['train_loss'].append(train_loss)
        
        n_correct = 0
        n_valid = len(valid)
        loss_sum = 0
        n_batches = 0

        model.eval()
        
        for batch in valid_iterator:
            print('.', end='')
            sys.stdout.flush()
            
            text = batch.text.t()
            
            with torch.no_grad():
                outputs = model(text, labels=batch.label)
                loss_batch, scores = outputs
                
            loss_sum += loss_batch.item()
            n_correct += evaluate_validation(scores, batch.label)
            n_batches += 1
            
            if n_batches % 50 == 0:
                print()

        val_acc = n_correct / n_valid
        val_loss = loss_sum / n_batches

        history['val_loss'].append(val_loss)
        history['val_acc'].append(val_acc)   

        if val_acc > max_val_acc:
            max_val_acc = val_acc
            models[word_type] = copy.deepcopy(model)
            max_verifications[word_type] = max_val_acc   
                
        t1 = time.time()
        print()
        print(f'Epoch {i+1}: train loss = {train_loss:.4f}, val loss = {val_loss:.4f}, val acc: {val_acc:.4f}, time = {t1-t0:.4f}')

    plt.plot(history['train_loss'])
    plt.plot(history['val_loss'])
    plt.plot(history['val_acc'])
    plt.legend(['training loss', 'validation loss', 'validation accuracy'])
    plt.show()
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Using DistilBertForSequenceClassification
# Training hold...
# ...................................................................................................
# Epoch 1: train loss = 1.4312, val loss = 0.7558, val acc: 0.7632, time = 19.2280
# ...................................................................................................
# Epoch 2: train loss = 0.6719, val loss = 0.5731, val acc: 0.8080, time = 19.2452
# Using DistilBertForSequenceClassification
# Training line...
# ..............................................................................................................................................................................
# Epoch 1: train loss = 0.4798, val loss = 0.2063, val acc: 0.9459, time = 33.9677
# ..............................................................................................................................................................................
# Epoch 2: train loss = 0.1242, val loss = 0.1131, val acc: 0.9702, time = 34.1066
# Using DistilBertForSequenceClassification
# Training positive...
# .......................................
# Epoch 1: train loss = 1.1826, val loss = 0.7287, val acc: 0.7572, time = 7.5194
# .......................................
# Epoch 2: train loss = 0.5249, val loss = 0.4445, val acc: 0.8683, time = 7.4649
# Using DistilBertForSequenceClassification
# Training force...
# .......................................................................................
# Epoch 1: train loss = 1.1364, val loss = 0.4012, val acc: 0.8875, time = 16.9517
# .......................................................................................
# Epoch 2: train loss = 0.3563, val loss = 0.3494, val acc: 0.8820, time = 16.8896
# Using DistilBertForSequenceClassification
# Training major...
# ................................................
# Epoch 1: train loss = 1.1652, val loss = 0.9519, val acc: 0.6113, time = 9.2666
# ................................................
# Epoch 2: train loss = 0.6979, val loss = 0.8242, val acc: 0.6645, time = 9.2586
# Using DistilBertForSequenceClassification
# Training keep...
# .........................................................................................................................................................................
# Epoch 1: train loss = 1.1593, val loss = 0.6093, val acc: 0.8091, time = 33.2263
# .........................................................................................................................................................................
# Epoch 2: train loss = 0.5052, val loss = 0.5629, val acc: 0.8239, time = 33.2616
# Using DistilBertForSequenceClassification
# Training case...
# ..........................................................................
# Epoch 1: train loss = 1.5669, val loss = 1.1884, val acc: 0.5626, time = 14.5708
# ..........................................................................
# Epoch 2: train loss = 0.8634, val loss = 0.9368, val acc: 0.6624, time = 14.5207
# Using DistilBertForSequenceClassification
# Training professional...
# ................................................................
# Epoch 1: train loss = 1.1085, val loss = 0.4844, val acc: 0.8055, time = 12.4118
# ................................................................
# Epoch 2: train loss = 0.4222, val loss = 0.4553, val acc: 0.7955, time = 12.4011
# Using DistilBertForSequenceClassification
# Training position...
# ......................................................................
# Epoch 1: train loss = 1.3002, val loss = 0.6913, val acc: 0.7680, time = 13.7129
# ......................................................................
# Epoch 2: train loss = 0.5567, val loss = 0.5188, val acc: 0.8198, time = 13.7447
# Using DistilBertForSequenceClassification
# Training serve...
# ...............................................................................................
# Epoch 1: train loss = 1.3934, val loss = 0.7157, val acc: 0.7706, time = 18.6404
# ...............................................................................................
# Epoch 2: train loss = 0.6703, val loss = 0.6252, val acc: 0.7822, time = 18.6571
# Using DistilBertForSequenceClassification
# Training follow...
# ........................................................................................................
# Epoch 1: train loss = 1.7335, val loss = 1.0581, val acc: 0.6813, time = 20.2569
# ........................................................................................................
# Epoch 2: train loss = 0.9350, val loss = 0.8979, val acc: 0.6813, time = 20.2876
# Using DistilBertForSequenceClassification
# Training life...
# ....................................................................
# Epoch 1: train loss = 1.3615, val loss = 0.7415, val acc: 0.7850, time = 13.1984
# ....................................................................
# Epoch 2: train loss = 0.4782, val loss = 0.5726, val acc: 0.8341, time = 13.2205
# Using DistilBertForSequenceClassification
# Training find...
# ...........................................................................
# Epoch 1: train loss = 1.4695, val loss = 0.7646, val acc: 0.7917, time = 14.8438
# ...........................................................................
# Epoch 2: train loss = 0.7652, val loss = 0.5887, val acc: 0.8229, time = 14.8015
# Using DistilBertForSequenceClassification
# Training see...
# .............................................................................................................................................................................................................
# Epoch 1: train loss = 0.8269, val loss = 0.5474, val acc: 0.8440, time = 40.4054
# .............................................................................................................................................................................................................
# Epoch 2: train loss = 0.4274, val loss = 0.4490, val acc: 0.8685, time = 40.3381
# Using DistilBertForSequenceClassification
# Training security...
# .....................................................................
# Epoch 1: train loss = 1.1244, val loss = 0.5103, val acc: 0.8545, time = 13.4478
# .....................................................................
# Epoch 2: train loss = 0.3653, val loss = 0.2742, val acc: 0.9215, time = 13.3832
# Using DistilBertForSequenceClassification
# Training bring...
# ...............................................................................
# Epoch 1: train loss = 1.5517, val loss = 1.1008, val acc: 0.5691, time = 15.5215
# ...............................................................................
# Epoch 2: train loss = 0.9878, val loss = 0.8941, val acc: 0.6934, time = 15.3238
# Using DistilBertForSequenceClassification
# Training physical...
# ............................................................
# Epoch 1: train loss = 1.2026, val loss = 0.8833, val acc: 0.7124, time = 11.7527
# ............................................................
# Epoch 2: train loss = 0.6237, val loss = 0.6794, val acc: 0.7704, time = 11.7208
# Using DistilBertForSequenceClassification
# Training critical...
# ..................................................
# Epoch 1: train loss = 1.2199, val loss = 0.6537, val acc: 0.8083, time = 9.7320
# ..................................................
# Epoch 2: train loss = 0.4539, val loss = 0.4361, val acc: 0.8466, time = 9.6747
# Using DistilBertForSequenceClassification
# Training point...
# ............................................................
# Epoch 1: train loss = 1.5664, val loss = 0.9588, val acc: 0.6919, time = 11.8193
# ............................................................
# Epoch 2: train loss = 0.6842, val loss = 0.5870, val acc: 0.8146, time = 11.7851
# Using DistilBertForSequenceClassification
# Training active...
# ...........................................
# Epoch 1: train loss = 1.1798, val loss = 0.6351, val acc: 0.7537, time = 8.3498
# ...........................................
# Epoch 2: train loss = 0.4827, val loss = 0.3857, val acc: 0.8843, time = 8.2965
# Using DistilBertForSequenceClassification
# Training time...
# ....................................................................
# Epoch 1: train loss = 1.2754, val loss = 0.7614, val acc: 0.7618, time = 13.1282
# ....................................................................
# Epoch 2: train loss = 0.5938, val loss = 0.6528, val acc: 0.7689, time = 13.0704
# Using DistilBertForSequenceClassification
# Training extend...
# ..............................................................................
# Epoch 1: train loss = 1.3813, val loss = 0.9430, val acc: 0.5918, time = 15.1169
# ..............................................................................
# Epoch 2: train loss = 0.8854, val loss = 0.8093, val acc: 0.6816, time = 15.1351
# Using DistilBertForSequenceClassification
# Training lead...
# ................................................................................
# Epoch 1: train loss = 1.6269, val loss = 1.0863, val acc: 0.5843, time = 15.7321
# ................................................................................
# Epoch 2: train loss = 0.9046, val loss = 0.7800, val acc: 0.7333, time = 15.6750
# Using DistilBertForSequenceClassification
# Training common...
# .......................................................
# Epoch 1: train loss = 1.0737, val loss = 0.7335, val acc: 0.6934, time = 11.7266
# .......................................................
# Epoch 2: train loss = 0.6264, val loss = 0.6764, val acc: 0.6991, time = 10.7114
# Using DistilBertForSequenceClassification
# Training national...
# ....................................................................
# Epoch 1: train loss = 1.4838, val loss = 0.8510, val acc: 0.7366, time = 13.2432
# ....................................................................
# Epoch 2: train loss = 0.5915, val loss = 0.5542, val acc: 0.8065, time = 13.1710
# Using DistilBertForSequenceClassification
# Training build...
# ...............................................................................
# Epoch 1: train loss = 1.9789, val loss = 1.7662, val acc: 0.3687, time = 15.3931
# ...............................................................................
# Epoch 2: train loss = 1.5075, val loss = 1.4127, val acc: 0.4890, time = 15.4391
# Using DistilBertForSequenceClassification
# Training place...
# ..............................................................
# Epoch 1: train loss = 1.2628, val loss = 0.5789, val acc: 0.8031, time = 11.9287
# ..............................................................
# Epoch 2: train loss = 0.5091, val loss = 0.3749, val acc: 0.8756, time = 11.9090
# Using DistilBertForSequenceClassification
# Training bad...
# .......................................................
# Epoch 1: train loss = 0.9173, val loss = 0.6237, val acc: 0.7630, time = 10.7654
# .......................................................
# Epoch 2: train loss = 0.4783, val loss = 0.3981, val acc: 0.8584, time = 10.6711
# Using DistilBertForSequenceClassification
# Training regular...
# ...............................................................
# Epoch 1: train loss = 1.6538, val loss = 1.1682, val acc: 0.6152, time = 12.1980
# ...............................................................
# Epoch 2: train loss = 1.0424, val loss = 0.9335, val acc: 0.6937, time = 12.1867
# Using DistilBertForSequenceClassification
# Training order...
# ................................................................
# Epoch 1: train loss = 1.0113, val loss = 0.4740, val acc: 0.8504, time = 12.4094
# ................................................................
# Epoch 2: train loss = 0.3322, val loss = 0.3178, val acc: 0.8978, time = 12.4096

# %%
avg = sum(max_verifications.values())/30

fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
plt.bar(list(max_verifications.keys()), max_verifications.values(), color='g')
x = [i for i in range(0,30)]
y = [0.3 for i in range(0,30)]
plt.plot(x,y,'b--')
x = [i for i in range(0,30)]
y = [avg for i in range(0,30)]
plt.plot(x,y,'b--')
plt.tick_params(axis='both', which='major', labelsize=30) 
plt.xticks(rotation='vertical')
axes = plt.gca()
axes.set_xlim([-0.5,29.5])
axes.set_ylim([0,1])
plt.show()

# %%
# !wget https://raw.githubusercontent.com/peterSvenningsson/NLP_documents_/master/wsd_test_blind.txt
# Out:
# --2019-11-13 09:58:43--  https://raw.githubusercontent.com/peterSvenningsson/NLP_documents_/master/wsd_test_blind.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7987686 (7.6M) [text/plain]
# Saving to: ‘wsd_test_blind.txt.1’
#
# wsd_test_blind.txt. 100%[===================>]   7.62M  --.-KB/s    in 0.04s
#
# 2019-11-13 09:58:44 (173 MB/s) - ‘wsd_test_blind.txt.1’ saved [7987686/7987686]

# %%
def read_test_data(corpus_file, doc_start):
    TEXT = torchtext.data.Field(sequential=True, tokenize=bert_tokenize, pad_token=tokenizer.pad_token,
                                init_token=tokenizer.cls_token, eos_token=tokenizer.sep_token)
    WORDTYPE = torchtext.data.Field()
    datafields = [('text', TEXT), ('wordtype', WORDTYPE)]
    pad_string = tokenizer.pad_token
    sentence_length = 140
    half_sentence_length = int(sentence_length/2)
    with open(corpus_file, encoding='utf-8') as f:
        examples = []
        for line in f:
            columns = line.strip().split(maxsplit=doc_start)
            position_of_wordtype = int(columns[2])

            # Split the long string doc into array and extract words before the wordtype.
            doc = columns[-1]
            doc_string_vector = doc.split()
            temp_pad = [pad_string for x in range(0,70)]

            padded_doc = []
            padded_doc.extend(temp_pad)
            padded_doc.extend(doc_string_vector)
            padded_doc.extend(temp_pad)

            sliced_doc = padded_doc[position_of_wordtype:position_of_wordtype + 140]

            if len(sliced_doc) != 140:
                print(sliced_doc)
                raise RuntimeError

            sliced_doc = " ".join(sliced_doc)

            wordtype = columns[1].split('.')[0]
            examples.append(torchtext.data.Example.fromlist([sliced_doc, wordtype], datafields))
    dataset = torchtext.data.Dataset(examples, datafields)
    return (dataset, TEXT, WORDTYPE)

# %%
test_dataset = read_test_data('wsd_test_blind.txt', doc_start=4)
for example in test_dataset[0].examples:
    test_example_string = example.text
    example_wordtype = example.wordtype[0]

    # Load vocabs
    example_vocab = model_vocabs[example_wordtype]
    example_label_vocabs = model_label_vocabs[example_wordtype]

    # Encode string
    encoded_example = torch.tensor([example_vocab.stoi[x] for x in test_example_string],device=device, requires_grad = False)    

    # Load correct model
    model = models[example_wordtype]

    # Get prediction
    labels = torch.tensor([1], device=device).unsqueeze(0)  # Batch size 1
    
    outputs = model(encoded_example.unsqueeze(0), labels=labels)
    loss, scores = outputs[:2]
    prediction = scores.argmax(dim=1)

    # Decode prediction
    decoded_prediction = example_label_vocabs.itos[prediction]
    print(decoded_prediction)
# Out:
# physical%5:00:00:material:01
# see%2:39:00::
# line%1:04:01::
# keep%2:41:03::
# national%3:01:01::
# keep%2:41:03::
# serve%2:42:12::
# keep%2:42:07::
# position%1:15:00::
# find%2:31:10::
# extend%2:30:06::
# line%1:04:01::
# keep%2:41:03::
# active%5:00:00:involved:00
# bad%3:00:00::
# see%2:31:03::
# national%5:00:00:public:00
# line%1:04:01::
# security%1:12:00::
# regular%5:00:00:standard:02
# order%1:14:00::
# follow%2:36:00::
# professional%3:00:01::
# bad%5:00:00:intense:00
# security%1:21:01::
# line%1:04:01::
# see%2:39:02::
# force%1:07:01::
# keep%2:41:03::
# build%2:30:00::
# line%1:06:01::
# hold%2:40:00::
# bring%2:36:00::
# extend%2:30:06::
# common%5:00:00:shared:00
# professional%3:01:00::
# hold%2:35:03::
# serve%2:42:03::
# find%2:40:02::
# professional%3:01:01::
# line%1:04:01::
# see%2:39:02::
# point%1:28:00::
# bring%2:36:01::
# life%1:28:00::
# order%1:10:00::
# bring%2:36:00::
# security%1:21:01::
# professional%3:01:01::
# find%2:32:00::
# positive%5:00:00:plus:00
# lead%2:41:00::
# life%1:28:02::
# see%2:31:00::
# keep%2:41:03::
# keep%2:41:03::
# follow%2:41:00::
# national%3:00:01::
# extend%2:30:06::
# keep%2:40:00::
# hold%2:31:01::
# position%1:26:00::
# see%2:31:00::
# see%2:31:00::
# keep%2:42:07::
# line%1:04:01::
# order%1:14:00::
# see%2:31:00::
# positive%3:00:01::
# life%1:26:01::
# see%2:32:00::
# build%2:36:00::
# line%1:04:01::
# see%2:39:00::
# force%1:14:00::
# line%1:04:01::
# critical%3:00:01::
# keep%2:40:00::
# common%3:00:01::
# keep%2:42:07::
# life%1:28:01::
# follow%2:36:00::
# lead%2:38:00::
# build%2:31:03::
# serve%2:42:01::
# keep%2:41:03::
# position%1:26:02::
# see%2:31:00::
# see%2:31:00::
# extend%2:30:06::
# force%1:14:01::
# order%1:26:00::
# major%3:00:06::
# order%1:14:00::
# hold%2:35:03::
# extend%2:30:01::
# follow%2:41:00::
# physical%3:01:00::
# extend%2:30:06::
# see%2:31:00::
# point%1:15:00::
# line%1:04:01::
# life%1:28:00::
# order%1:10:03::
# national%3:00:00::
# build%2:30:00::
# place%1:15:00::
# security%1:12:00::
# lead%2:42:01::
# case%1:26:00::
# major%3:00:06::
# hold%2:31:10::
# find%2:40:02::
# case%1:10:02::
# point%1:15:00::
# find%2:39:01::
# security%1:26:00::
# follow%2:38:01::
# serve%2:42:12::
# line%1:04:01::
# critical%5:00:00:indispensable:00
# common%5:00:00:shared:00
# force%1:04:01::
# keep%2:40:00::
# hold%2:35:00::
# see%2:31:00::
# follow%2:41:00::
# order%1:10:03::
# critical%3:00:03::
# life%1:18:00::
# line%1:04:01::
# physical%3:01:00::
# line%1:04:01::
# national%5:00:00:public:00
# place%1:15:04::
# professional%3:00:01::
# follow%2:42:02::
# major%3:00:07::
# hold%2:40:00::
# find%2:40:02::
# time%1:28:00::
# critical%5:00:00:indispensable:00
# line%1:04:01::
# keep%2:41:03::
# active%3:00:03::
# place%1:15:00::
# time%1:28:00::
# regular%5:00:00:scheduled:00
# physical%3:00:00::
# physical%5:00:00:material:01
# life%1:28:01::
# place%1:04:01::
# see%2:31:03::
# line%1:04:01::
# follow%2:41:00::
# active%5:00:00:involved:00
# extend%2:30:09::
# regular%5:00:00:symmetrical:00
# extend%2:40:04::
# bring%2:36:00::
# regular%5:00:00:frequent:00
# security%1:12:00::
# serve%2:42:03::
# bad%5:00:00:inferior:02
# build%2:36:00::
# line%1:04:01::
# point%1:28:00::
# line%1:06:07::
# national%3:00:01::
# bad%5:00:00:intense:00
# hold%2:36:00::
# build%2:36:00::
# physical%5:00:02:material:01
# lead%2:41:12::
# position%1:26:00::
# lead%2:38:00::
# see%2:31:03::
# security%1:12:00::
# order%1:10:01::
# line%1:04:01::
# follow%2:38:13::
# follow%2:40:00::
# order%1:10:01::
# life%1:28:01::
# professional%3:01:01::
# positive%3:00:01::
# line%1:04:01::
# active%3:00:03::
# national%3:00:00::
# line%1:04:01::
# bring%2:35:04::
# point%1:28:00::
# keep%2:41:03::
# force%1:18:00::
# serve%2:41:13::
# lead%2:38:00::
# physical%3:01:00::
# place%1:15:04::
# hold%2:40:04::
# bring%2:35:00::
# physical%5:00:02:material:01
# see%2:31:00::
# major%3:00:01::
# bad%5:00:00:intense:00
# common%5:00:00:familiar:02
# build%2:31:03::
# critical%3:00:03::
# serve%2:42:01::
# life%1:26:01::
# see%2:39:00::
# hold%2:35:03::
# major%3:00:06::
# see%2:39:00::
# physical%5:00:00:forceful:00
# major%3:00:06::
# keep%2:42:07::
# physical%5:00:00:material:01
# physical%5:00:00:forceful:00
# bring%2:36:00::
# extend%2:30:01::
# see%2:31:00::
# place%1:04:01::
# line%1:04:00::
# find%2:40:00::
# national%5:00:00:domestic:00
# find%2:39:01::
# order%1:10:00::
# national%3:00:00::
# common%5:00:00:familiar:02
# bring%2:36:01::
# point%1:09:02::
# time%1:28:06::
# security%1:14:00::
# find%2:32:00::
# keep%2:41:03::
# see%2:31:00::
# national%3:00:01::
# order%1:10:00::
# bring%2:35:00::
# active%5:00:00:operational:00
# physical%5:00:02:material:01
# case%1:04:00::
# build%2:36:00::
# extend%2:30:02::
# major%3:00:06::
# professional%3:00:02::
# critical%3:00:01::
# keep%2:42:07::
# bad%5:00:00:intense:00
# follow%2:38:00::
# active%3:00:03::
# lead%2:41:00::
# point%1:09:01::
# major%3:00:07::
# follow%2:38:13::
# follow%2:38:00::
# hold%2:35:03::
# serve%2:41:02::
# see%2:31:00::
# critical%3:00:03::
# bring%2:38:00::
# lead%2:42:03::
# extend%2:30:06::
# line%1:04:00::
# find%2:39:01::
# see%2:31:00::
# keep%2:40:01::
# see%2:39:00::
# find%2:39:02::
# extend%2:30:06::
# keep%2:41:03::
# major%3:00:07::
# security%1:26:00::
# hold%2:32:11::
# point%1:28:00::
# line%1:04:01::
# line%1:04:01::
# keep%2:42:00::
# line%1:04:01::
# point%1:15:00::
# position%1:15:00::
# position%1:26:00::
# lead%2:38:01::
# see%2:39:02::
# bring%2:35:00::
# see%2:31:00::
# see%2:31:03::
# force%1:14:00::
# life%1:28:01::
# professional%3:00:01::
# security%1:26:00::
# place%1:04:01::
# see%2:31:00::
# security%1:21:04::
# build%2:31:03::
# time%1:28:00::
# find%2:39:01::
# security%1:04:00::
# time%1:28:06::
# active%5:00:00:operational:00
# position%1:04:01::
# place%1:15:04::
# life%1:28:02::
# time%1:28:00::
# active%3:00:03::
# bring%2:36:01::
# hold%2:36:00::
# force%1:04:01::
# extend%2:30:06::
# point%1:28:00::
# serve%2:42:00::
# case%1:10:02::
# professional%5:00:00:white-collar:00
# line%1:06:07::
# follow%2:41:00::
# lead%2:38:00::
# national%5:00:00:domestic:00
# see%2:31:00::
# hold%2:40:00::
# hold%2:36:00::
# professional%3:01:01::
# lead%2:41:12::
# life%1:28:00::
# regular%5:00:00:standard:02
# find%2:40:02::
# major%3:00:06::
# national%5:00:00:public:00
# major%3:00:06::
# regular%5:00:00:symmetrical:00
# order%1:14:00::
# position%1:07:01::
# line%1:04:01::
# regular%5:00:00:scheduled:00
# critical%5:00:00:indispensable:00
# life%1:28:02::
# see%2:31:00::
# time%1:11:00::
# build%2:30:10::
# see%2:31:00::
# regular%5:00:00:scheduled:00
# bad%5:00:00:intense:00
# professional%3:01:01::
# security%1:14:00::
# see%2:31:00::
# professional%3:00:01::
# common%3:00:01::
# national%3:00:00::
# point%1:15:00::
# position%1:15:00::
# time%1:28:00::
# point%1:09:02::
# national%3:01:01::
# hold%2:35:03::
# build%2:30:02::
# force%1:18:00::
# security%1:12:00::
# follow%2:42:02::
# line%1:04:01::
# common%3:00:01::
# line%1:04:01::
# time%1:28:00::
# keep%2:40:00::
# keep%2:40:00::
# hold%2:40:04::
# point%1:09:01::
# line%1:04:01::
# case%1:10:01::
# security%1:26:00::
# force%1:14:02::
# force%1:07:02::
# see%2:31:00::
# physical%3:01:00::
# security%1:26:00::
# order%1:10:01::
# case%1:26:00::
# case%1:26:00::
# lead%2:41:12::
# order%1:26:00::
# position%1:09:00::
# follow%2:38:13::
# line%1:04:01::
# line%1:04:01::
# life%1:28:02::
# serve%2:42:12::
# line%1:04:01::
# keep%2:42:07::
# follow%2:38:01::
# security%1:26:00::
# national%5:00:00:domestic:00
# follow%2:38:01::
# hold%2:31:01::
# serve%2:41:13::
# see%2:39:00::
# see%2:31:01::
# professional%3:01:01::
# build%2:36:09::
# lead%2:42:12::
# active%3:00:03::
# keep%2:41:03::
# case%1:26:00::
# common%5:00:00:shared:00
# keep%2:42:00::
# build%2:30:10::
# line%1:04:01::
# see%2:31:00::
# serve%2:42:01::
# positive%3:00:01::
# order%1:26:00::
# build%2:31:03::
# point%1:15:00::
# see%2:31:00::
# professional%3:00:02::
# time%1:11:00::
# see%2:31:00::
# national%3:00:01::
# lead%2:38:01::
# line%1:04:01::
# physical%5:00:00:material:01
# find%2:39:01::
# national%5:00:00:public:00
# extend%2:30:06::
# time%1:11:00::
# force%1:14:00::
# find%2:40:02::
# keep%2:41:03::
# follow%2:38:00::
# bring%2:35:00::
# regular%5:00:00:scheduled:00
# common%5:00:00:familiar:02
# serve%2:35:00::
# professional%3:00:01::
# find%2:40:02::
# order%1:10:00::
# regular%3:00:00::
# bad%5:00:00:intense:00
# regular%5:00:00:symmetrical:00
# bring%2:38:00::
# hold%2:35:03::
# see%2:39:00::
# keep%2:41:03::
# extend%2:30:09::
# see%2:31:00::
# place%1:15:00::
# position%1:26:00::
# major%3:00:06::
# force%1:04:01::
# lead%2:38:00::
# keep%2:40:00::
# time%1:28:06::
# follow%2:38:01::
# find%2:31:10::
# bring%2:35:00::
# physical%3:01:00::
# extend%2:30:01::
# follow%2:41:00::
# place%1:15:04::
# see%2:39:00::
# keep%2:40:00::
# see%2:31:00::
# regular%5:00:00:symmetrical:00
# force%1:07:01::
# bad%5:00:00:intense:00
# regular%5:00:00:scheduled:00
# national%3:01:01::
# line%1:04:01::
# major%3:00:07::
# build%2:30:00::
# see%2:31:01::
# common%5:00:00:familiar:02
# follow%2:41:00::
# line%1:04:01::
# lead%2:38:00::
# point%1:15:00::
# line%1:04:01::
# keep%2:41:03::
# force%1:07:01::
# line%1:04:01::
# extend%2:40:04::
# physical%3:01:00::
# follow%2:41:00::
# physical%3:01:00::
# point%1:15:00::
# find%2:31:10::
# point%1:23:01::
# place%1:15:00::
# case%1:10:02::
# place%1:26:00::
# order%1:10:00::
# active%5:00:00:involved:00
# bring%2:38:00::
# see%2:31:00::
# case%1:26:00::
# lead%2:42:12::
# build%2:36:09::
# time%1:28:00::
# line%1:04:01::
# extend%2:40:04::
# hold%2:32:11::
# physical%5:00:02:material:01
# physical%5:00:02:material:01
# serve%2:41:13::
# order%1:14:00::
# force%1:07:02::
# active%5:00:00:operational:00
# see%2:31:00::
# point%1:15:00::
# force%1:14:00::
# life%1:28:00::
# follow%2:40:00::
# force%1:14:00::
# keep%2:42:00::
# keep%2:41:03::
# position%1:09:00::
# positive%3:00:01::
# case%1:11:00::
# build%2:36:00::
# major%3:00:06::
# common%5:00:00:familiar:02
# point%1:09:00::
# critical%3:00:03::
# physical%5:00:02:material:01
# see%2:31:00::
# keep%2:42:07::
# hold%2:31:10::
# build%2:36:09::
# line%1:04:01::
# keep%2:42:07::
# see%2:31:00::
# time%1:28:00::
# major%3:00:02::
# physical%5:00:02:material:01
# keep%2:42:00::
# hold%2:31:01::
# keep%2:42:07::
# professional%5:00:00:white-collar:00
# follow%2:38:00::
# positive%5:00:00:advantageous:00
# common%3:00:02::
# lead%2:42:12::
# place%1:04:01::
# security%1:12:00::
# find%2:39:02::
# line%1:04:01::
# place%1:04:01::
# line%1:04:01::
# security%1:10:00::
# case%1:04:00::
# life%1:26:01::
# bad%5:00:00:intense:00
# order%1:10:01::
# see%2:31:00::
# life%1:28:02::
# keep%2:42:00::
# lead%2:38:01::
# force%1:14:00::
# line%1:04:01::
# follow%2:38:13::
# case%1:10:01::
# case%1:26:00::
# serve%2:42:00::
# critical%5:00:00:indispensable:00
# extend%2:30:06::
# bad%3:00:00::
# life%1:18:00::
# time%1:11:00::
# force%1:04:01::
# line%1:04:01::
# place%1:26:00::
# time%1:28:00::
# see%2:31:01::
# bad%5:00:00:inferior:02
# life%1:26:01::
# serve%2:42:03::
# national%5:00:00:domestic:00
# hold%2:31:01::
# position%1:09:00::
# professional%3:00:01::
# line%1:04:01::
# active%3:00:03::
# case%1:18:03::
# hold%2:35:03::
# line%1:09:00::
# active%5:00:00:operational:00
# physical%3:00:00::
# follow%2:38:13::
# security%1:21:04::
# serve%2:42:03::
# national%3:00:01::
# critical%5:00:00:indispensable:00
# follow%2:42:02::
# point%1:10:01::
# case%1:10:02::
# keep%2:40:00::
# serve%2:42:03::
# life%1:03:00::
# hold%2:40:00::
# keep%2:42:07::
# line%1:04:01::
# place%1:15:04::
# bring%2:38:00::
# point%1:15:00::
# keep%2:40:00::
# national%5:00:00:public:00
# active%3:00:03::
# common%3:00:01::
# force%1:07:02::
# follow%2:36:00::
# extend%2:30:01::
# see%2:31:00::
# follow%2:38:01::
# see%2:31:00::
# life%1:26:01::
# security%1:14:00::
# positive%5:00:00:plus:00
# place%1:04:01::
# common%5:00:00:shared:00
# order%1:14:00::
# hold%2:31:01::
# keep%2:41:03::
# see%2:31:00::
# line%1:04:01::
# force%1:14:00::
# force%1:18:00::
# security%1:14:00::
# follow%2:38:00::
# hold%2:31:01::
# point%1:28:00::
# position%1:26:02::
# lead%2:38:00::
# extend%2:40:04::
# bad%5:00:00:intense:00
# serve%2:42:12::
# serve%2:42:01::
# position%1:26:00::
# follow%2:38:00::
# physical%3:01:00::
# serve%2:33:00::
# bad%5:00:00:intense:00
# bring%2:38:00::
# see%2:31:00::
# bad%3:00:00::
# bad%5:00:00:intense:00
# bring%2:38:00::
# order%1:10:00::
# case%1:26:00::
# case%1:26:00::
# line%1:04:01::
# build%2:31:03::
# time%1:28:00::
# bring%2:36:00::
# active%3:00:07::
# keep%2:42:00::
# critical%3:00:02::
# point%1:09:00::
# extend%2:40:04::
# positive%5:00:00:advantageous:00
# line%1:04:01::
# professional%3:00:01::
# hold%2:42:00::
# national%3:01:01::
# national%5:00:00:domestic:00
# force%1:14:00::
# security%1:14:00::
# hold%2:40:04::
# follow%2:38:00::
# line%1:04:01::
# position%1:26:02::
# line%1:04:01::
# find%2:40:02::
# regular%5:00:00:standard:02
# build%2:31:03::
# see%2:31:00::
# lead%2:38:01::
# build%2:36:00::
# keep%2:41:03::
# security%1:26:00::
# positive%5:00:00:advantageous:00
# time%1:28:00::
# order%1:10:03::
# find%2:31:10::
# extend%2:40:04::
# find%2:32:00::
# physical%3:00:00::
# see%2:31:00::
# keep%2:42:07::
# critical%5:00:00:indispensable:00
# positive%5:00:00:plus:00
# life%1:26:01::
# order%1:10:03::
# security%1:26:00::
# case%1:26:00::
# case%1:11:00::
# see%2:39:02::
# see%2:31:00::
# critical%3:00:03::
# follow%2:41:00::
# lead%2:41:12::
# extend%2:30:06::
# security%1:26:00::
# find%2:39:01::
# life%1:28:02::
# lead%2:41:00::
# life%1:26:01::
# line%1:04:01::
# bring%2:35:04::
# extend%2:30:09::
# position%1:26:00::
# keep%2:40:00::
# lead%2:38:01::
# positive%3:00:01::
# case%1:10:02::
# regular%5:00:00:standard:02
# physical%3:01:00::
# keep%2:42:00::
# force%1:18:00::
# see%2:39:00::
# extend%2:30:02::
# physical%5:00:00:material:01
# see%2:31:00::
# follow%2:42:02::
# professional%3:00:02::
# major%3:00:02::
# critical%3:00:03::
# build%2:36:00::
# regular%5:00:00:symmetrical:00
# life%1:28:01::
# line%1:09:00::
# national%3:00:01::
# hold%2:36:00::
# see%2:39:00::
# serve%2:33:00::
# serve%2:42:01::
# security%1:12:00::
# physical%5:00:00:forceful:00
# national%5:00:00:domestic:00
# find%2:32:01::
# common%5:00:00:shared:00
# security%1:21:01::
# see%2:31:00::
# keep%2:42:07::
# regular%5:00:00:frequent:00
# order%1:10:00::
# keep%2:41:03::
# extend%2:30:02::
# order%1:14:00::
# case%1:11:00::
# extend%2:30:02::
# life%1:26:01::
# national%3:01:01::
# find%2:32:01::
# regular%5:00:00:scheduled:00
# time%1:28:06::
# critical%3:00:03::
# force%1:07:01::
# bring%2:36:01::
# time%1:28:00::
# see%2:31:00::
# build%2:36:00::
# follow%2:41:00::
# order%1:10:03::
# hold%2:36:00::
# time%1:28:06::
# common%5:00:00:shared:00
# build%2:36:00::
# time%1:28:00::
# physical%3:01:00::
# order%1:10:00::
# time%1:11:00::
# order%1:14:00::
# case%1:04:00::
# build%2:36:00::
# physical%5:00:00:material:01
# see%2:31:00::
# follow%2:36:00::
# national%5:00:00:domestic:00
# active%5:00:00:involved:00
# serve%2:42:00::
# hold%2:36:00::
# national%3:00:00::
# serve%2:42:01::
# time%1:11:00::
# place%1:15:00::
# professional%3:01:01::
# position%1:04:01::
# hold%2:32:11::
# line%1:04:01::
# case%1:04:00::
# keep%2:42:07::
# hold%2:40:00::
# bad%5:00:00:intense:00
# critical%5:00:00:indispensable:00
# order%1:10:03::
# order%1:10:01::
# position%1:09:00::
# active%3:00:03::
# line%1:04:01::
# position%1:04:01::
# line%1:04:01::
# serve%2:42:00::
# national%5:00:00:public:00
# national%5:00:00:domestic:00
# see%2:31:00::
# point%1:09:01::
# force%1:07:01::
# build%2:36:00::
# national%5:00:00:domestic:00
# serve%2:42:12::
# hold%2:32:11::
# keep%2:40:00::
# see%2:31:00::
# extend%2:30:09::
# bring%2:36:00::
# follow%2:38:01::
# critical%3:00:01::
# point%1:09:01::
# lead%2:42:12::
# see%2:31:01::
# life%1:28:01::
# line%1:06:07::
# common%5:00:00:familiar:02
# line%1:04:01::
# find%2:39:02::
# order%1:14:00::
# life%1:28:01::
# order%1:14:00::
# see%2:31:00::
# extend%2:30:02::
# see%2:31:00::
# hold%2:35:03::
# extend%2:30:06::
# case%1:26:00::
# line%1:04:01::
# physical%3:01:00::
# hold%2:35:03::
# keep%2:41:03::
# regular%5:00:00:scheduled:00
# critical%3:00:03::
# physical%5:00:02:material:01
# professional%3:00:02::
# line%1:04:01::
# critical%3:00:03::
# position%1:09:00::
# national%5:00:00:public:00
# security%1:10:00::
# line%1:04:01::
# line%1:04:01::
# life%1:28:00::
# critical%5:00:00:indispensable:00
# lead%2:38:00::
# position%1:26:00::
# hold%2:36:00::
# follow%2:41:02::
# line%1:04:01::
# bad%5:00:00:intense:00
# order%1:14:00::
# force%1:14:00::
# force%1:04:01::
# order%1:14:00::
# keep%2:42:00::
# see%2:31:03::
# major%3:00:07::
# force%1:14:02::
# serve%2:41:13::
# see%2:39:00::
# case%1:10:01::
# case%1:11:00::
# force%1:07:02::
# build%2:36:00::
# find%2:40:02::
# see%2:31:01::
# life%1:28:02::
# follow%2:38:00::
# life%1:28:02::
# national%3:01:01::
# case%1:26:00::
# see%2:31:00::
# line%1:04:01::
# line%1:04:01::
# build%2:30:10::
# see%2:31:00::
# national%3:00:00::
# point%1:15:00::
# see%2:39:00::
# build%2:31:03::
# positive%3:00:01::
# national%5:00:00:domestic:00
# extend%2:30:01::
# line%1:04:01::
# major%3:00:02::
# keep%2:40:00::
# regular%5:00:00:symmetrical:00
# line%1:04:01::
# line%1:04:01::
# order%1:10:01::
# bring%2:35:04::
# lead%2:42:03::
# life%1:28:01::
# life%1:28:01::
# position%1:09:00::
# hold%2:31:01::
# bring%2:38:00::
# security%1:10:00::
# life%1:28:01::
# common%5:00:00:familiar:02
# find%2:39:02::
# hold%2:40:04::
# extend%2:30:02::
# time%1:28:00::
# life%1:28:01::
# hold%2:40:04::
# bring%2:36:01::
# force%1:14:00::
# life%1:03:00::
# keep%2:40:00::
# critical%3:00:01::
# positive%3:00:01::
# point%1:15:00::
# order%1:26:00::
# case%1:11:00::
# point%1:09:01::
# security%1:14:00::
# find%2:39:01::
# professional%3:01:01::
# see%2:39:00::
# line%1:04:01::
# follow%2:42:02::
# line%1:04:01::
# see%2:39:00::
# position%1:26:00::
# national%3:01:01::
# line%1:04:01::
# build%2:36:00::
# build%2:36:00::
# force%1:14:00::
# force%1:07:02::
# lead%2:42:12::
# see%2:39:02::
# see%2:31:00::
# hold%2:40:00::
# keep%2:42:00::
# physical%5:00:00:material:01
# regular%5:00:00:standard:02
# position%1:04:01::
# follow%2:36:00::
# position%1:04:01::
# active%3:00:03::
# life%1:28:00::
# physical%5:00:02:material:01
# positive%3:00:01::
# find%2:39:02::
# find%2:40:02::
# positive%5:00:00:plus:00
# active%5:00:00:operational:00
# follow%2:38:00::
# major%3:00:06::
# regular%5:00:00:scheduled:00
# national%3:00:01::
# build%2:30:10::
# see%2:31:00::
# physical%5:00:00:material:01
# order%1:10:01::
# see%2:31:03::
# find%2:40:02::
# line%1:04:01::
# line%1:04:01::
# find%2:32:00::
# active%3:00:03::
# line%1:04:01::
# keep%2:41:03::
# find%2:40:02::
# active%5:00:00:operational:00
# lead%2:38:01::
# follow%2:42:02::
# point%1:09:02::
# line%1:06:07::
# life%1:28:01::
# order%1:14:00::
# hold%2:32:11::
# see%2:31:00::
# national%3:00:00::
# professional%3:00:01::
# national%5:00:00:public:00
# line%1:09:00::
# follow%2:41:00::
# national%3:00:00::
# force%1:18:00::
# build%2:30:00::
# force%1:14:00::
# line%1:04:01::
# see%2:31:00::
# force%1:07:01::
# lead%2:38:00::
# case%1:26:00::
# see%2:31:00::
# line%1:04:01::
# common%3:00:02::
# see%2:31:00::
# time%1:11:00::
# point%1:28:00::
# hold%2:31:01::
# order%1:26:00::
# order%1:10:00::
# bring%2:35:00::
# order%1:26:00::
# line%1:04:01::
# see%2:39:00::
# national%3:00:01::
# line%1:04:01::
# serve%2:42:03::
# see%2:31:00::
# serve%2:42:00::
# see%2:39:02::
# serve%2:41:02::
# hold%2:40:00::
# line%1:04:01::
# see%2:31:00::
# order%1:14:00::
# see%2:39:02::
# see%2:39:00::
# professional%3:00:01::
# common%3:00:01::
# lead%2:41:12::
# line%1:04:01::
# serve%2:42:01::
# bad%5:00:00:intense:00
# case%1:10:01::
# lead%2:41:00::
# see%2:39:02::
# place%1:26:00::
# physical%3:01:00::
# case%1:11:00::
# serve%2:42:03::
# bad%5:00:00:intense:00
# place%1:15:00::
# order%1:14:00::
# line%1:09:00::
# see%2:39:02::
# position%1:09:00::
# find%2:32:00::
# security%1:21:04::
# follow%2:38:01::
# serve%2:33:00::
# serve%2:35:00::
# place%1:26:00::
# see%2:31:01::
# extend%2:30:02::
# find%2:39:02::
# lead%2:38:00::
# time%1:28:06::
# find%2:40:02::
# bring%2:35:00::
# major%3:00:02::
# position%1:26:00::
# physical%5:00:00:material:01
# keep%2:41:03::
# lead%2:41:12::
# see%2:39:00::
# time%1:11:00::
# line%1:04:01::
# common%3:00:02::
# position%1:04:01::
# point%1:09:01::
# national%3:01:00::
# active%5:00:00:involved:00
# position%1:09:00::
# life%1:26:01::
# order%1:10:00::
# major%3:00:06::
# regular%5:00:00:frequent:00
# find%2:39:01::
# hold%2:42:00::
# build%2:36:00::
# bring%2:35:00::
# extend%2:30:02::
# position%1:09:00::
# keep%2:40:00::
# life%1:28:01::
# common%3:00:02::
# keep%2:40:01::
# physical%5:00:02:material:01
# national%5:00:00:domestic:00
# serve%2:41:02::
# build%2:31:03::
# hold%2:35:03::
# build%2:36:09::
# extend%2:30:02::
# force%1:14:01::
# force%1:14:00::
# position%1:04:01::
# national%3:01:01::
# bring%2:38:00::
# regular%5:00:00:frequent:00
# serve%2:42:12::
# force%1:14:01::
# case%1:04:00::
# find%2:32:01::
# bad%5:00:00:intense:00
# case%1:26:00::
# point%1:15:00::
# see%2:31:00::
# follow%2:41:00::
# see%2:31:00::
# line%1:04:01::
# line%1:04:01::
# follow%2:36:00::
# critical%5:00:00:indispensable:00
# critical%3:00:01::
# keep%2:42:07::
# keep%2:42:07::
# common%3:00:02::
# follow%2:41:00::
# see%2:31:00::
# life%1:28:02::
# keep%2:40:00::
# critical%3:00:01::
# extend%2:30:01::
# follow%2:41:00::
# follow%2:41:00::
# follow%2:36:00::
# lead%2:38:00::
# critical%3:00:01::
# line%1:04:01::
# serve%2:33:00::
# positive%3:00:04::
# serve%2:41:02::
# security%1:21:01::
# point%1:15:00::
# life%1:28:01::
# line%1:04:01::
# find%2:40:02::
# build%2:36:00::
# active%3:00:03::
# position%1:26:00::
# force%1:14:02::
# keep%2:40:00::
# common%3:00:02::
# lead%2:41:00::
# see%2:31:03::
# force%1:04:01::
# security%1:12:00::
# bad%3:00:00::
# national%3:00:01::
# physical%5:00:00:forceful:00
# time%1:28:00::
# keep%2:41:03::
# hold%2:42:00::
# security%1:12:00::
# hold%2:40:00::
# time%1:28:00::
# hold%2:35:03::
# keep%2:41:03::
# national%5:00:00:domestic:00
# keep%2:40:00::
# see%2:39:02::
# regular%5:00:00:scheduled:00
# serve%2:41:13::
# line%1:04:01::
# see%2:41:11::
# case%1:10:02::
# line%1:04:01::
# life%1:28:01::
# time%1:28:06::
# lead%2:42:12::
# case%1:04:00::
# keep%2:42:07::
# critical%3:00:02::
# line%1:04:01::
# position%1:15:00::
# see%2:31:00::
# life%1:28:00::
# place%1:04:01::
# see%2:31:01::
# order%1:10:01::
# positive%5:00:00:plus:00
# security%1:21:01::
# time%1:28:06::
# see%2:31:00::
# order%1:14:00::
# keep%2:41:03::
# common%5:00:00:familiar:02
# see%2:31:00::
# line%1:04:01::
# see%2:31:00::
# keep%2:41:03::
# position%1:09:00::
# extend%2:30:01::
# regular%5:00:00:standard:02
# time%1:11:00::
# point%1:09:01::
# follow%2:36:00::
# professional%3:00:01::
# keep%2:41:01::
# national%5:00:00:domestic:00
# critical%3:00:01::
# serve%2:42:01::
# national%5:00:00:domestic:00
# serve%2:42:01::
# national%3:01:01::
# physical%3:00:00::
# time%1:28:06::
# lead%2:38:01::
# force%1:07:01::
# keep%2:41:03::
# security%1:21:01::
# national%3:00:01::
# find%2:39:02::
# serve%2:42:03::
# national%5:00:00:public:00
# active%3:00:03::
# life%1:28:01::
# see%2:39:02::
# keep%2:41:03::
# keep%2:40:00::
# extend%2:30:09::
# time%1:28:00::
# line%1:04:01::
# time%1:28:06::
# case%1:10:01::
# follow%2:41:00::
# major%3:00:02::
# keep%2:42:00::
# bad%5:00:00:intense:00
# build%2:31:03::
# serve%2:41:02::
# place%1:26:00::
# line%1:04:01::
# follow%2:38:01::
# national%3:00:00::
# bring%2:38:00::
# security%1:14:00::
# serve%2:41:02::
# see%2:31:00::
# extend%2:30:02::
# professional%3:00:01::
# critical%5:00:00:indispensable:00
# find%2:39:01::
# line%1:04:01::
# professional%5:00:00:white-collar:00
# keep%2:41:03::
# bad%3:00:00::
# line%1:04:01::
# life%1:26:01::
# point%1:09:02::
# point%1:15:00::
# positive%5:00:00:plus:00
# national%3:00:00::
# national%3:00:01::
# find%2:32:00::
# time%1:28:05::
# find%2:39:01::
# bring%2:36:00::
# bad%3:00:00::
# regular%3:00:00::
# line%1:04:01::
# follow%2:41:00::
# security%1:21:04::
# bad%5:00:00:intense:00
# regular%5:00:00:scheduled:00
# follow%2:38:00::
# keep%2:42:00::
# line%1:04:01::
# place%1:26:00::
# find%2:40:02::
# follow%2:38:01::
# time%1:28:00::
# see%2:39:02::
# keep%2:42:07::
# line%1:04:01::
# physical%5:00:00:forceful:00
# order%1:10:03::
# common%3:00:01::
# place%1:15:00::
# professional%3:00:02::
# time%1:11:00::
# positive%3:00:01::
# see%2:31:00::
# position%1:04:01::
# find%2:31:10::
# find%2:39:01::
# case%1:18:03::
# common%3:00:01::
# positive%5:00:00:plus:00
# follow%2:38:13::
# point%1:15:00::
# see%2:39:02::
# active%5:00:00:operational:00
# time%1:28:00::
# hold%2:31:10::
# line%1:04:01::
# lead%2:38:00::
# place%1:26:00::
# build%2:36:00::
# find%2:31:10::
# keep%2:41:03::
# keep%2:40:01::
# order%1:26:00::
# major%3:00:07::
# physical%5:00:00:material:01
# build%2:31:03::
# follow%2:38:00::
# point%1:28:00::
# security%1:21:01::
# bad%3:00:00::
# professional%3:01:01::
# hold%2:42:00::
# national%5:00:00:domestic:00
# bad%5:00:00:intense:00
# see%2:31:03::
# build%2:31:03::
# see%2:31:00::
# line%1:04:01::
# active%5:00:00:operational:00
# extend%2:30:01::
# extend%2:30:09::
# see%2:31:00::
# regular%5:00:00:scheduled:00
# see%2:31:01::
# extend%2:30:06::
# serve%2:42:01::
# security%1:21:01::
# position%1:26:00::
# regular%5:00:00:standard:02
# position%1:15:00::
# force%1:07:01::
# extend%2:40:04::
# keep%2:41:03::
# line%1:04:01::
# critical%3:00:01::
# major%3:00:06::
# hold%2:36:00::
# follow%2:38:01::
# security%1:21:04::
# keep%2:41:03::
# security%1:21:04::
# build%2:36:00::
# see%2:31:00::
# find%2:40:02::
# time%1:28:06::
# hold%2:36:00::
# active%3:00:07::
# follow%2:38:01::
# professional%3:01:00::
# bring%2:35:00::
# critical%3:00:02::
# critical%3:00:01::
# follow%2:38:01::
# bring%2:35:04::
# see%2:39:00::
# national%3:01:01::
# case%1:11:00::
# regular%3:00:00::
# line%1:04:01::
# place%1:15:04::
# serve%2:33:00::
# line%1:04:01::
# keep%2:42:00::
# major%3:00:07::
# line%1:04:01::
# lead%2:38:00::
# serve%2:41:13::
# point%1:15:00::
# lead%2:38:00::
# lead%2:42:12::
# position%1:26:02::
# see%2:39:00::
# keep%2:40:00::
# extend%2:30:06::
# national%5:00:00:domestic:00
# order%1:10:00::
# professional%5:00:00:white-collar:00
# keep%2:40:00::
# lead%2:41:12::
# national%3:01:01::
# order%1:10:00::
# hold%2:32:11::
# place%1:15:00::
# bad%3:00:00::
# point%1:09:01::
# line%1:04:01::
# see%2:31:00::
# physical%3:00:00::
# order%1:10:03::
# build%2:31:03::
# place%1:15:00::
# bring%2:36:01::
# keep%2:42:07::
# keep%2:42:07::
# critical%3:00:01::
# physical%3:00:00::
# see%2:31:03::
# place%1:04:01::
# follow%2:41:00::
# serve%2:42:01::
# critical%3:00:01::
# position%1:15:00::
# order%1:10:01::
# see%2:39:00::
# see%2:31:00::
# force%1:07:02::
# keep%2:42:00::
# see%2:31:00::
# positive%3:00:01::
# regular%5:00:00:scheduled:00
# life%1:03:00::
# find%2:39:02::
# force%1:14:00::
# security%1:21:04::
# professional%3:01:00::
# force%1:14:00::
# follow%2:38:00::
# see%2:31:03::
# order%1:10:00::
# extend%2:30:01::
# security%1:26:00::
# serve%2:42:03::
# case%1:06:00::
# keep%2:40:13::
# line%1:04:01::
# line%1:04:01::
# extend%2:30:06::
# keep%2:42:07::
# bad%5:00:00:intense:00
# national%3:00:01::
# keep%2:40:00::
# see%2:31:00::
# line%1:14:02::
# security%1:26:00::
# point%1:15:00::
# line%1:06:07::
# place%1:15:00::
# build%2:36:09::
# lead%2:42:03::
# order%1:14:00::
# hold%2:40:00::
# positive%3:00:01::
# serve%2:42:12::
# professional%5:00:00:white-collar:00
# serve%2:41:02::
# keep%2:40:00::
# see%2:31:00::
# line%1:09:00::
# force%1:04:01::
# hold%2:36:00::
# regular%5:00:00:scheduled:00
# keep%2:41:03::
# follow%2:38:01::
# critical%5:00:00:indispensable:00
# professional%5:00:00:white-collar:00
# regular%5:00:00:frequent:00
# line%1:04:01::
# case%1:11:00::
# lead%2:38:00::
# extend%2:30:06::
# follow%2:38:13::
# position%1:26:00::
# physical%5:00:00:forceful:00
# find%2:32:01::
# keep%2:41:03::
# point%1:15:00::
# case%1:10:01::
# common%5:00:00:familiar:02
# major%3:00:07::
# place%1:15:04::
# point%1:28:00::
# keep%2:41:03::
# keep%2:42:07::
# follow%2:36:00::
# force%1:07:01::
# bad%3:00:00::
# see%2:39:00::
# keep%2:41:03::
# see%2:31:00::
# hold%2:42:00::
# see%2:39:00::
# common%5:00:00:shared:00
# bad%5:00:00:intense:00
# national%3:00:01::
# keep%2:41:03::
# hold%2:35:03::
# security%1:26:00::
# extend%2:30:06::
# national%3:00:01::
# case%1:26:00::
# build%2:36:00::
# regular%5:00:00:frequent:00
# hold%2:40:00::
# see%2:31:00::
# common%5:00:00:familiar:02
# place%1:26:00::
# point%1:15:00::
# extend%2:30:09::
# bad%5:00:00:intense:00
# bring%2:38:00::
# keep%2:42:07::
# keep%2:40:00::
# keep%2:41:03::
# order%1:10:00::
# serve%2:42:00::
# line%1:04:01::
# national%3:00:00::
# line%1:04:01::
# hold%2:36:00::
# line%1:04:01::
# line%1:09:00::
# common%5:00:00:familiar:02
# national%3:01:01::
# position%1:26:00::
# time%1:28:00::
# line%1:04:01::
# see%2:39:02::
# case%1:11:00::
# position%1:09:00::
# build%2:30:00::
# position%1:04:01::
# keep%2:42:00::
# point%1:09:01::
# point%1:28:00::
# hold%2:42:00::
# see%2:31:01::
# follow%2:38:00::
# hold%2:42:00::
# national%3:00:00::
# life%1:28:00::
# see%2:31:03::
# regular%5:00:00:standard:02
# see%2:39:02::
# see%2:39:02::
# regular%5:00:00:standard:02
# physical%5:00:00:material:01
# extend%2:30:02::
# regular%5:00:00:frequent:00
# bring%2:38:00::
# keep%2:42:07::
# lead%2:42:03::
# security%1:21:01::
# keep%2:40:00::
# point%1:09:01::
# see%2:39:00::
# find%2:32:01::
# life%1:26:01::
# regular%5:00:00:frequent:00
# position%1:26:00::
# serve%2:42:03::
# see%2:31:00::
# see%2:31:00::
# position%1:09:00::
# professional%3:01:00::
# keep%2:40:00::
# serve%2:35:00::
# regular%3:00:00::
# regular%5:00:00:frequent:00
# hold%2:36:00::
# physical%5:00:00:material:01
# keep%2:42:07::
# serve%2:42:01::
# keep%2:41:03::
# keep%2:41:03::
# physical%5:00:02:material:01
# physical%5:00:02:material:01
# position%1:09:00::
# bring%2:38:00::
# serve%2:42:01::
# bad%5:00:00:intense:00
# professional%3:01:00::
# line%1:04:01::
# life%1:26:01::
# bad%5:00:00:intense:00
# find%2:39:01::
# line%1:04:01::
# life%1:28:00::
# see%2:39:02::
# line%1:04:01::
# line%1:04:01::
# follow%2:42:02::
# national%5:00:00:domestic:00
# extend%2:30:01::
# line%1:04:01::
# line%1:04:01::
# hold%2:31:01::
# professional%3:01:00::
# professional%5:00:00:white-collar:00
# hold%2:31:01::
# see%2:31:00::
# bring%2:38:00::
# physical%5:00:02:material:01
# life%1:28:00::
# extend%2:30:02::
# line%1:04:01::
# positive%3:00:01::
# see%2:39:02::
# professional%3:00:01::
# extend%2:30:06::
# build%2:30:02::
# follow%2:38:01::
# extend%2:30:06::
# place%1:04:01::
# force%1:04:01::
# point%1:09:01::
# build%2:36:00::
# follow%2:38:01::
# build%2:31:03::
# see%2:39:02::
# force%1:14:01::
# extend%2:30:06::
# follow%2:38:01::
# see%2:31:00::
# order%1:10:00::
# build%2:36:00::
# see%2:39:00::
# place%1:15:00::
# follow%2:42:02::
# build%2:30:02::
# lead%2:41:12::
# line%1:04:01::
# time%1:28:00::
# positive%3:00:01::
# force%1:14:00::
# time%1:28:05::
# common%5:00:00:shared:00
# regular%5:00:00:scheduled:00
# place%1:15:00::
# national%3:00:01::
# keep%2:41:03::
# critical%3:00:01::
# common%5:00:00:shared:00
# keep%2:41:03::
# line%1:04:01::
# build%2:36:00::
# professional%5:00:00:white-collar:00
# positive%5:00:00:plus:00
# force%1:14:00::
# common%3:00:02::
# physical%5:00:00:material:01
# time%1:28:06::
# order%1:10:03::
# bring%2:35:00::
# regular%5:00:00:frequent:00
# build%2:36:00::
# professional%3:00:01::
# see%2:39:02::
# extend%2:30:06::
# line%1:04:01::
# physical%5:00:00:forceful:00
# extend%2:30:02::
# keep%2:41:03::
# serve%2:42:03::
# build%2:31:03::
# order%1:10:00::
# major%3:00:06::
# see%2:39:02::
# common%3:00:01::
# keep%2:41:03::
# line%1:04:01::
# line%1:04:01::
# keep%2:42:00::
# position%1:26:00::
# place%1:26:00::
# force%1:14:01::
# follow%2:38:01::
# force%1:04:01::
# life%1:28:02::
# keep%2:40:00::
# physical%5:00:02:material:01
# security%1:21:04::
# regular%5:00:00:scheduled:00
# force%1:14:01::
# force%1:14:01::
# force%1:04:01::
# see%2:39:02::
# bad%5:00:00:intense:00
# point%1:28:00::
# follow%2:42:02::
# follow%2:41:00::
# bad%3:00:00::
# line%1:04:01::
# professional%3:00:02::
# find%2:32:00::
# serve%2:42:12::
# extend%2:30:09::
# lead%2:38:00::
# line%1:04:01::
# regular%5:00:00:symmetrical:00
# line%1:04:01::
# professional%3:01:00::
# time%1:28:05::
# point%1:26:00::
# common%3:00:01::
# hold%2:36:00::
# keep%2:42:00::
# find%2:31:10::
# lead%2:38:00::
# security%1:12:00::
# security%1:21:01::
# professional%3:01:00::
# see%2:31:00::
# keep%2:40:00::
# follow%2:38:00::
# national%3:01:01::
# extend%2:30:06::
# point%1:28:00::
# bring%2:35:04::
# national%3:01:01::
# bad%5:00:00:invalid:00
# positive%3:00:01::
# follow%2:38:13::
# positive%3:00:01::
# line%1:04:01::
# regular%5:00:00:standard:02
# national%3:00:01::
# regular%5:00:00:standard:02
# build%2:36:00::
# hold%2:35:00::
# point%1:15:00::
# life%1:28:00::
# regular%5:00:00:scheduled:00
# common%5:00:00:familiar:02
# regular%5:00:00:frequent:00
# see%2:39:00::
# serve%2:33:00::
# serve%2:42:00::
# line%1:04:01::
# time%1:28:00::
# common%3:00:01::
# physical%5:00:00:forceful:00
# national%5:00:00:domestic:00
# time%1:28:00::
# force%1:07:01::
# position%1:15:00::
# bring%2:36:00::
# see%2:39:02::
# case%1:26:00::
# regular%5:00:00:scheduled:00
# professional%3:01:01::
# line%1:09:00::
# regular%5:00:00:scheduled:00
# bad%5:00:00:intense:00
# extend%2:30:06::
# line%1:04:01::
# professional%3:00:01::
# common%3:00:02::
# lead%2:38:01::
# point%1:15:00::
# hold%2:31:10::
# build%2:36:09::
# see%2:31:00::
# see%2:31:00::
# national%5:00:00:domestic:00
# regular%5:00:00:frequent:00
# build%2:36:00::
# life%1:28:00::
# keep%2:41:03::
# lead%2:41:12::
# point%1:28:00::
# security%1:12:00::
# security%1:26:00::
# keep%2:41:03::
# hold%2:36:00::
# serve%2:41:02::
# positive%5:00:00:plus:00
# keep%2:41:03::
# find%2:39:02::
# national%3:00:01::
# time%1:28:05::
# see%2:31:00::
# life%1:26:01::
# order%1:10:01::
# order%1:14:00::
# line%1:04:01::
# see%2:31:01::
# common%3:00:01::
# point%1:28:00::
# point%1:15:00::
# serve%2:41:02::
# force%1:14:00::
# serve%2:41:02::
# time%1:28:00::
# professional%3:00:01::
# physical%5:00:02:material:01
# build%2:36:00::
# find%2:40:02::
# bring%2:38:00::
# place%1:15:00::
# security%1:26:00::
# keep%2:41:03::
# keep%2:41:03::
# critical%5:00:00:indispensable:00
# regular%5:00:00:scheduled:00
# find%2:32:00::
# hold%2:35:03::
# hold%2:36:00::
# line%1:14:02::
# hold%2:31:01::
# see%2:31:00::
# keep%2:42:07::
# regular%5:00:00:usual:00
# position%1:04:01::
# extend%2:30:01::
# place%1:15:00::
# line%1:04:01::
# case%1:26:00::
# build%2:36:09::
# extend%2:30:02::
# case%1:26:00::
# find%2:32:00::
# physical%5:00:00:material:01
# see%2:31:00::
# position%1:15:00::
# active%5:00:00:operational:00
# order%1:14:00::
# serve%2:42:00::
# keep%2:41:03::
# force%1:07:01::
# extend%2:40:04::
# serve%2:42:01::
# see%2:31:00::
# bring%2:36:00::
# serve%2:42:12::
# build%2:36:00::
# active%5:00:00:involved:00
# extend%2:30:09::
# find%2:32:01::
# lead%2:38:00::
# place%1:04:01::
# build%2:31:03::
# positive%3:00:01::
# life%1:28:00::
# security%1:21:01::
# case%1:11:00::
# build%2:36:09::
# national%3:01:00::
# major%3:00:02::
# lead%2:38:01::
# case%1:26:00::
# lead%2:38:01::
# time%1:28:06::
# see%2:31:03::
# place%1:04:01::
# see%2:31:00::
# national%3:00:01::
# force%1:07:01::
# force%1:07:01::
# critical%5:00:00:indispensable:00
# force%1:04:01::
# life%1:28:01::
# see%2:31:00::
# extend%2:30:06::
# serve%2:41:02::
# place%1:26:00::
# hold%2:40:00::
# life%1:28:00::
# critical%3:00:03::
# keep%2:40:00::
# national%5:00:00:public:00
# keep%2:42:00::
# extend%2:30:06::
# follow%2:38:00::
# major%3:00:06::
# critical%3:00:01::
# line%1:04:01::
# extend%2:40:04::
# bad%5:00:00:intense:00
# critical%5:00:00:indispensable:00
# bad%3:00:00::
# time%1:28:06::
# position%1:09:00::
# serve%2:42:03::
# case%1:26:00::
# follow%2:38:00::
# bad%5:00:00:intense:00
# extend%2:30:09::
# extend%2:40:04::
# security%1:14:00::
# life%1:28:02::
# security%1:21:01::
# follow%2:38:01::
# force%1:14:00::
# regular%5:00:00:scheduled:00
# position%1:04:01::
# major%3:00:02::
# professional%5:00:00:white-collar:00
# keep%2:42:07::
# professional%3:00:02::
# place%1:26:00::
# lead%2:41:00::
# bring%2:38:00::
# keep%2:42:07::
# professional%3:00:01::
# life%1:28:01::
# life%1:09:00::
# major%3:00:06::
# position%1:26:00::
# bad%5:00:00:intense:00
# follow%2:42:02::
# force%1:14:01::
# life%1:26:01::
# life%1:26:01::
# hold%2:40:00::
# lead%2:38:00::
# serve%2:42:01::
# common%5:00:00:shared:00
# place%1:15:00::
# national%3:01:01::
# hold%2:40:04::
# national%3:01:01::
# extend%2:30:06::
# point%1:15:00::
# hold%2:40:02::
# see%2:31:00::
# find%2:31:10::
# life%1:28:00::
# hold%2:35:03::
# line%1:04:01::
# keep%2:42:07::
# positive%3:00:01::
# extend%2:30:01::
# keep%2:41:03::
# see%2:39:00::
# critical%3:00:01::
# time%1:11:00::
# keep%2:40:00::
# find%2:40:02::
# place%1:15:00::
# case%1:10:01::
# extend%2:40:04::
# hold%2:40:00::
# bring%2:36:01::
# see%2:31:00::
# find%2:39:01::
# active%3:00:07::
# follow%2:36:00::
# bad%5:00:00:intense:00
# physical%5:00:02:material:01
# professional%3:01:01::
# follow%2:36:00::
# case%1:04:00::
# professional%3:01:00::
# see%2:39:00::
# point%1:28:00::
# hold%2:40:00::
# national%3:01:01::
# bring%2:36:00::
# hold%2:35:03::
# common%3:00:01::
# keep%2:42:07::
# point%1:15:00::
# keep%2:42:00::
# time%1:11:00::
# follow%2:38:01::
# follow%2:41:00::
# life%1:28:01::
# force%1:04:01::
# keep%2:41:03::
# position%1:15:00::
# critical%3:00:02::
# time%1:28:00::
# bring%2:36:01::
# order%1:10:01::
# keep%2:42:07::
# extend%2:40:04::
# security%1:04:00::
# line%1:04:01::
# extend%2:40:04::
# bad%5:00:00:intense:00
# critical%3:00:01::
# security%1:12:00::
# common%3:00:01::
# major%3:00:06::
# keep%2:41:03::
# find%2:40:00::
# professional%3:01:01::
# physical%5:00:02:material:01
# keep%2:40:00::
# national%3:01:01::
# force%1:07:01::
# bring%2:36:01::
# bring%2:35:04::
# national%3:00:01::
# point%1:15:00::
# bad%3:00:00::
# find%2:39:01::
# see%2:31:00::
# place%1:26:00::
# lead%2:42:12::
# position%1:26:00::
# professional%3:01:00::
# place%1:26:00::
# line%1:04:01::
# professional%3:00:01::
# time%1:28:00::
# follow%2:38:00::
# line%1:04:01::
# extend%2:30:02::
# security%1:26:00::
# major%3:00:06::
# hold%2:40:00::
# common%3:00:01::
# see%2:31:00::
# see%2:39:00::
# line%1:04:01::
# life%1:28:00::
# security%1:26:00::
# bring%2:35:00::
# common%3:00:01::
# see%2:39:00::
# place%1:26:00::
# security%1:26:00::
# build%2:30:00::
# follow%2:41:00::
# keep%2:41:03::
# regular%5:00:00:usual:00
# regular%5:00:00:standard:02
# see%2:39:00::
# bring%2:36:01::
# line%1:04:01::
# life%1:26:01::
# place%1:04:01::
# keep%2:42:00::
# hold%2:40:00::
# find%2:32:00::
# time%1:28:00::
# line%1:04:01::
# professional%5:00:00:white-collar:00
# lead%2:41:12::
# force%1:07:01::
# order%1:10:01::
# follow%2:41:00::
# force%1:07:02::
# find%2:40:02::
# national%3:00:01::
# line%1:04:01::
# position%1:26:00::
# regular%5:00:00:symmetrical:00
# professional%5:00:00:white-collar:00
# follow%2:42:02::
# serve%2:42:12::
# positive%3:00:01::
# line%1:04:01::
# follow%2:38:00::
# build%2:36:00::
# case%1:11:00::
# life%1:28:02::
# bring%2:35:04::
# national%3:00:01::
# place%1:15:00::
# line%1:04:01::
# life%1:28:02::
# bring%2:38:00::
# follow%2:41:00::
# hold%2:36:00::
# build%2:36:09::
# place%1:15:04::
# national%3:01:00::
# serve%2:42:03::
# keep%2:42:00::
# serve%2:42:00::
# bring%2:35:00::
# line%1:06:03::
# critical%3:00:01::
# see%2:39:00::
# security%1:12:00::
# lead%2:41:12::
# national%3:00:01::
# line%1:04:01::
# order%1:10:03::
# life%1:26:01::
# active%5:00:00:involved:00
# bad%5:00:00:intense:00
# line%1:04:01::
# life%1:28:00::
# lead%2:41:12::
# line%1:04:01::
# regular%5:00:00:frequent:00
# extend%2:30:02::
# life%1:28:01::
# regular%5:00:00:frequent:00
# bad%5:00:00:intense:00
# extend%2:30:06::
# place%1:15:00::
# lead%2:42:12::
# keep%2:41:03::
# keep%2:31:00::
# build%2:31:03::
# professional%3:00:02::
# major%3:00:02::
# build%2:30:10::
# position%1:15:00::
# professional%3:00:02::
# life%1:09:00::
# line%1:04:01::
# national%5:00:00:public:00
# follow%2:36:00::
# keep%2:40:01::
# point%1:15:00::
# see%2:39:00::
# build%2:36:00::
# serve%2:42:03::
# build%2:36:00::
# keep%2:41:03::
# critical%3:00:03::
# national%5:00:00:domestic:00
# see%2:31:00::
# time%1:11:00::
# extend%2:30:01::
# regular%5:00:00:standard:02
# keep%2:42:07::
# see%2:39:00::
# keep%2:41:03::
# line%1:04:01::
# keep%2:40:00::
# see%2:31:00::
# force%1:18:00::
# professional%3:00:01::
# physical%5:00:02:material:01
# critical%5:00:00:indispensable:00
# extend%2:40:04::
# point%1:09:01::
# position%1:15:00::
# hold%2:32:11::
# extend%2:30:06::
# point%1:28:00::
# keep%2:40:00::
# bring%2:36:00::
# line%1:09:00::
# serve%2:33:00::
# keep%2:41:03::
# hold%2:40:00::
# see%2:39:02::
# major%3:00:02::
# bring%2:35:00::
# extend%2:30:06::
# order%1:10:01::
# professional%5:00:00:white-collar:00
# follow%2:38:01::
# follow%2:38:01::
# line%1:15:02::
# point%1:15:00::
# major%3:00:06::
# line%1:04:01::
# place%1:15:00::
# hold%2:31:01::
# build%2:36:09::
# line%1:04:01::
# common%5:00:00:familiar:02
# life%1:26:01::
# common%5:00:00:shared:00
# point%1:15:00::
# physical%5:00:00:material:01
# follow%2:41:00::
# see%2:31:00::
# lead%2:41:12::
# hold%2:40:00::
# find%2:32:01::
# find%2:39:02::
# national%5:00:00:domestic:00
# hold%2:36:00::
# professional%3:00:01::
# place%1:04:01::
# force%1:14:00::
# keep%2:42:00::
# order%1:26:00::
# physical%3:01:00::
# time%1:28:00::
# follow%2:42:02::
# serve%2:33:00::
# lead%2:38:00::
# find%2:40:02::
# find%2:32:01::
# serve%2:42:00::
# find%2:40:02::
# position%1:26:00::
# time%1:28:06::
# force%1:18:00::
# force%1:07:01::
# professional%3:01:00::
# see%2:31:00::
# build%2:36:09::
# build%2:30:00::
# critical%3:00:03::
# lead%2:41:12::
# active%5:00:00:involved:00
# point%1:09:01::
# force%1:04:01::
# case%1:26:00::
# case%1:11:00::
# active%5:00:00:operational:00
# extend%2:30:06::
# case%1:04:00::
# common%3:00:01::
# major%3:00:06::
# hold%2:36:00::
# line%1:04:01::
# national%3:00:01::
# active%3:00:07::
# see%2:31:00::
# bring%2:35:00::
# physical%3:01:00::
# serve%2:42:00::
# see%2:31:01::
# active%3:00:07::
# keep%2:42:07::
# lead%2:42:03::
# keep%2:41:03::
# see%2:31:03::
# line%1:04:01::
# lead%2:41:12::
# professional%3:00:01::
# positive%3:00:01::
# follow%2:38:13::
# life%1:28:00::
# extend%2:29:01::
# national%3:01:01::
# position%1:09:00::
# build%2:30:10::
# keep%2:41:03::
# lead%2:42:01::
# hold%2:35:03::
# build%2:30:10::
# force%1:07:02::
# serve%2:42:03::
# keep%2:41:03::
# find%2:31:10::
# line%1:04:01::
# professional%3:00:01::
# force%1:07:02::
# find%2:40:02::
# regular%5:00:00:standard:02
# follow%2:38:01::
# lead%2:38:01::
# order%1:10:01::
# case%1:04:00::
# serve%2:42:00::
# positive%3:00:01::
# line%1:04:01::
# life%1:18:00::
# active%5:00:00:operational:00
# force%1:14:01::
# keep%2:40:00::
# bring%2:38:00::
# regular%5:00:00:scheduled:00
# see%2:31:01::
# see%2:31:00::
# regular%5:00:00:scheduled:00
# national%3:00:00::
# keep%2:42:00::
# order%1:14:00::
# major%3:00:02::
# security%1:10:00::
# active%5:00:00:operational:00
# build%2:36:00::
# follow%2:41:00::
# build%2:30:10::
# positive%3:00:04::
# physical%3:01:00::
# keep%2:42:00::
# keep%2:41:03::
# hold%2:31:01::
# security%1:21:04::
# lead%2:42:01::
# find%2:40:02::
# security%1:21:01::
# hold%2:31:01::
# see%2:39:00::
# follow%2:38:13::
# build%2:36:00::
# follow%2:38:13::
# build%2:36:00::
# bring%2:38:00::
# lead%2:42:03::
# physical%5:00:00:material:01
# critical%3:00:02::
# professional%3:01:01::
# life%1:28:01::
# order%1:10:01::
# case%1:11:00::
# position%1:09:00::
# see%2:39:00::
# national%3:01:00::
# national%3:00:01::
# national%3:00:00::
# see%2:31:00::
# extend%2:30:06::
# life%1:26:01::
# active%5:00:00:involved:00
# serve%2:41:02::
# position%1:09:00::
# national%5:00:00:public:00
# hold%2:32:11::
# extend%2:30:02::
# build%2:36:00::
# see%2:31:00::
# serve%2:42:00::
# keep%2:40:00::
# position%1:04:01::
# see%2:31:00::
# security%1:21:01::
# build%2:36:00::
# life%1:28:00::
# keep%2:41:03::
# follow%2:38:13::
# physical%3:00:00::
# see%2:39:02::
# critical%3:00:03::
# see%2:39:00::
# security%1:14:00::
# follow%2:36:00::
# positive%3:00:01::
# see%2:39:00::
# time%1:28:06::
# serve%2:42:03::
# see%2:39:00::
# positive%3:00:04::
# critical%5:00:00:indispensable:00
# see%2:31:00::
# follow%2:36:00::
# security%1:10:00::
# build%2:36:00::
# positive%3:00:04::
# position%1:09:00::
# build%2:30:00::
# line%1:04:01::
# force%1:18:00::
# keep%2:40:00::
# keep%2:42:00::
# follow%2:38:13::
# extend%2:30:01::
# extend%2:30:06::
# time%1:28:06::
# see%2:31:00::
# place%1:15:00::
# see%2:31:00::
# time%1:28:00::
# follow%2:36:00::
# critical%3:00:03::
# life%1:28:01::
# follow%2:38:01::
# see%2:31:00::
# line%1:04:01::
# major%3:00:01::
# see%2:31:03::
# build%2:36:00::
# order%1:10:01::
# time%1:28:05::
# regular%5:00:00:standard:02
# build%2:36:09::
# case%1:26:00::
# lead%2:38:00::
# bring%2:35:00::
# order%1:10:00::
# line%1:06:03::
# regular%5:00:00:frequent:00
# hold%2:36:00::
# physical%3:00:00::
# force%1:04:01::
# active%3:00:07::
# find%2:40:02::
# extend%2:30:09::
# follow%2:38:13::
# bad%5:00:00:intense:00
# lead%2:41:00::
# regular%5:00:00:symmetrical:00
# hold%2:42:00::
# point%1:15:00::
# point%1:15:00::
# regular%5:00:00:scheduled:00
# see%2:31:00::
# force%1:14:00::
# order%1:10:00::
# case%1:11:00::
# line%1:04:01::
# active%5:00:00:operational:00
# common%5:00:00:shared:00
# bring%2:35:04::
# serve%2:42:01::
# regular%5:00:00:standard:02
# line%1:04:01::
# see%2:39:00::
# keep%2:41:03::
# position%1:26:00::
# bad%5:00:00:intense:00
# force%1:14:00::
# professional%3:01:00::
# serve%2:42:12::
# force%1:14:00::
# major%3:00:02::
# see%2:39:00::
# line%1:04:01::
# build%2:31:03::
# hold%2:32:11::
# regular%5:00:00:scheduled:00
# hold%2:31:10::
# bring%2:35:04::
# time%1:28:06::
# keep%2:41:03::
# physical%5:00:00:material:01
# force%1:14:00::
# see%2:39:00::
# find%2:32:01::
# security%1:14:00::
# see%2:39:02::
# position%1:15:00::
# security%1:21:01::
# lead%2:38:00::
# point%1:28:00::
# see%2:31:03::
# line%1:04:01::
# lead%2:41:12::
# serve%2:42:00::
# hold%2:31:10::
# extend%2:30:06::
# keep%2:42:07::
# find%2:39:01::
# lead%2:41:00::
# keep%2:40:00::
# line%1:04:01::
# place%1:15:00::
# national%5:00:00:domestic:00
# physical%5:00:02:material:01
# bring%2:35:04::
# force%1:07:01::
# see%2:31:00::
# bring%2:35:00::
# life%1:28:00::
# keep%2:41:03::
# major%3:00:06::
# force%1:07:02::
# see%2:31:00::
# find%2:31:10::
# see%2:31:00::
# case%1:04:00::
# follow%2:38:13::
# place%1:26:00::
# keep%2:42:00::
# follow%2:38:01::
# line%1:04:01::
# line%1:04:01::
# point%1:15:00::
# point%1:09:01::
# keep%2:42:07::
# lead%2:42:12::
# point%1:15:00::
# place%1:04:01::
# professional%3:00:02::
# extend%2:30:02::
# case%1:11:00::
# force%1:07:01::
# life%1:28:00::
# physical%3:00:00::
# place%1:15:04::
# find%2:40:00::
# critical%3:00:03::
# security%1:12:00::
# build%2:36:09::
# positive%3:00:04::
# extend%2:30:06::
# place%1:15:00::
# hold%2:40:00::
# security%1:04:00::
# force%1:07:02::
# life%1:26:01::
# place%1:15:00::
# see%2:31:00::
# see%2:31:00::
# keep%2:41:03::
# follow%2:36:00::
# point%1:09:01::
# common%3:00:01::
# keep%2:41:03::
# order%1:10:00::
# see%2:31:00::
# physical%3:01:00::
# keep%2:41:03::
# major%3:00:06::
# bring%2:38:00::
# line%1:15:02::
# security%1:14:00::
# case%1:04:00::
# force%1:14:00::
# time%1:11:00::
# build%2:36:00::
# keep%2:40:00::
# common%3:00:02::
# line%1:04:01::
# bad%5:00:00:intense:00
# position%1:15:00::
# point%1:15:00::
# find%2:32:00::
# force%1:07:02::
# professional%3:00:01::
# line%1:04:01::
# critical%5:00:00:indispensable:00
# lead%2:38:00::
# case%1:18:03::
# case%1:26:00::
# line%1:04:01::
# extend%2:29:01::
# active%5:00:00:operational:00
# keep%2:40:00::
# follow%2:38:01::
# bring%2:36:00::
# national%3:01:01::
# hold%2:31:10::
# bad%5:00:00:intense:00
# lead%2:41:00::
# follow%2:41:00::
# physical%5:00:00:material:01
# build%2:36:00::
# follow%2:38:00::
# extend%2:29:01::
# build%2:36:00::
# physical%5:00:00:material:01
# life%1:28:01::
# see%2:31:00::
# extend%2:30:06::
# serve%2:42:03::
# time%1:28:00::
# see%2:39:02::
# force%1:18:00::
# force%1:14:00::
# extend%2:30:01::
# build%2:36:00::
# lead%2:38:00::
# physical%3:01:00::
# bad%5:00:00:intense:00
# bring%2:38:00::
# hold%2:35:03::
# physical%3:00:00::
# professional%5:00:00:white-collar:00
# hold%2:36:00::
# order%1:10:03::
# position%1:09:00::
# life%1:09:00::
# follow%2:36:00::
# serve%2:42:00::
# professional%3:00:02::
# physical%3:00:00::
# keep%2:42:00::
# critical%5:00:00:indispensable:00
# national%3:00:01::
# follow%2:41:00::
# point%1:15:00::
# hold%2:40:02::
# regular%5:00:00:standard:02
# bring%2:36:01::
# see%2:31:00::
# critical%3:00:02::
# national%3:01:00::
# line%1:06:07::
# national%3:00:01::
# keep%2:42:07::
# lead%2:42:12::
# hold%2:40:00::
# point%1:15:00::
# national%3:00:00::
# position%1:09:00::
# line%1:10:02::
# bring%2:35:00::
# bad%5:00:00:intense:00
# time%1:28:05::
# hold%2:36:00::
# national%3:01:00::
# keep%2:41:03::
# physical%5:00:00:material:01
# keep%2:40:00::
# keep%2:40:00::
# follow%2:38:01::
# point%1:15:00::
# regular%5:00:00:symmetrical:00
# line%1:04:01::
# force%1:04:01::
# line%1:04:01::
# see%2:31:00::
# physical%5:00:00:material:01
# regular%5:00:00:standard:02
# follow%2:38:13::
# serve%2:42:12::
# position%1:15:00::
# order%1:14:00::
# keep%2:41:03::
# see%2:39:02::
# find%2:32:00::
# professional%3:00:02::
# point%1:28:00::
# find%2:32:01::
# common%5:00:00:shared:00
# bring%2:35:04::
# national%3:00:01::
# time%1:11:00::
# line%1:04:01::
# build%2:36:00::
# point%1:09:01::
# case%1:06:00::
# active%3:00:03::
# regular%5:00:00:standard:02
# point%1:15:00::
# position%1:09:00::
# common%3:00:01::
# see%2:31:00::
# line%1:04:01::
# serve%2:42:03::
# force%1:04:01::
# place%1:15:00::
# case%1:11:00::
# national%3:00:01::
# major%3:00:02::
# case%1:04:00::
# keep%2:42:07::
# follow%2:38:01::
# follow%2:41:00::
# see%2:39:02::
# line%1:04:01::
# line%1:04:01::
# life%1:28:00::
# find%2:32:00::
# follow%2:38:13::
# life%1:28:02::
# line%1:04:01::
# security%1:26:00::
# see%2:31:00::
# positive%5:00:00:plus:00
# position%1:15:00::
# serve%2:42:00::
# build%2:36:00::
# national%3:01:01::
# life%1:18:00::
# follow%2:38:13::
# order%1:14:00::
# force%1:07:02::
# place%1:04:01::
# hold%2:36:00::
# serve%2:42:00::
# serve%2:42:03::
# keep%2:41:03::
# physical%3:01:00::
# position%1:26:02::
# major%3:00:02::
# see%2:31:00::
# extend%2:30:01::
# case%1:26:00::
# build%2:36:00::
# life%1:26:01::
# time%1:11:00::
# security%1:10:00::
# follow%2:42:02::
# see%2:31:00::
# order%1:10:03::
# case%1:10:02::
# order%1:10:01::
# active%3:00:03::
# position%1:15:00::
# find%2:31:10::
# bring%2:35:00::
# lead%2:41:12::
# extend%2:30:02::
# line%1:04:01::
# national%5:00:00:domestic:00
# find%2:40:02::
# hold%2:40:04::
# line%1:04:01::
# force%1:14:00::
# bring%2:38:00::
# line%1:09:00::
# bring%2:38:00::
# keep%2:40:00::
# bad%5:00:00:intense:00
# find%2:32:00::
# life%1:28:00::
# critical%5:00:00:indispensable:00
# bad%5:00:00:intense:00
# point%1:09:00::
# bring%2:36:01::
# keep%2:41:03::
# regular%5:00:00:scheduled:00
# keep%2:40:00::
# build%2:31:03::
# positive%3:00:04::
# point%1:09:00::
# place%1:15:04::
# national%5:00:00:public:00
# extend%2:30:02::
# point%1:15:00::
# follow%2:41:00::
# follow%2:38:01::
# follow%2:38:13::
# line%1:04:01::
# keep%2:41:03::
# order%1:10:00::
# see%2:31:00::
# critical%3:00:03::
# see%2:31:00::
# find%2:32:00::
# hold%2:31:01::
# follow%2:38:13::
# extend%2:30:06::
# position%1:26:00::
# case%1:10:02::
# keep%2:41:03::
# line%1:04:01::
# extend%2:40:04::
# order%1:10:00::
# serve%2:42:03::
# regular%5:00:00:standard:02
# serve%2:41:02::
# see%2:31:00::
# extend%2:30:06::
# find%2:40:02::
# hold%2:32:11::
# serve%2:41:13::
# point%1:09:01::
# extend%2:29:01::
# lead%2:42:12::
# serve%2:42:03::
# find%2:32:01::
# place%1:15:04::
# keep%2:40:00::
# point%1:09:01::
# professional%3:01:01::
# keep%2:41:03::
# order%1:26:00::
# security%1:21:01::
# line%1:04:01::
# bad%5:00:00:intense:00
# critical%3:00:03::
# see%2:31:00::
# force%1:04:01::
# find%2:40:02::
# national%3:00:01::
# order%1:10:00::
# serve%2:42:12::
# life%1:26:01::
# case%1:11:00::
# force%1:14:01::
# security%1:14:00::
# major%3:00:06::
# professional%3:00:02::
# serve%2:41:02::
# force%1:04:01::
# find%2:32:01::
# keep%2:42:00::
# build%2:31:03::
# regular%5:00:00:usual:00
# bad%3:00:00::
# extend%2:30:06::
# national%3:00:01::
# hold%2:36:00::
# positive%3:00:01::
# place%1:04:01::
# lead%2:38:00::
# major%3:00:06::
# active%3:00:07::
# order%1:26:00::
# build%2:36:00::
# see%2:31:00::
# national%5:00:00:domestic:00
# ...
# build%2:30:00::
# life%1:18:00::
# find%2:39:01::
# physical%3:00:00::
# bring%2:35:04::
# bring%2:35:00::
# force%1:18:00::
# keep%2:40:00::
# bring%2:35:00::
# serve%2:42:12::
# physical%3:00:00::
# find%2:31:10::
# follow%2:42:02::
# place%1:15:06::
# positive%3:00:04::
# common%3:00:01::
# point%1:15:00::
# line%1:04:01::
# keep%2:42:07::
# national%3:01:01::
# serve%2:41:02::
# line%1:06:09::
# see%2:39:02::
# point%1:15:00::
# point%1:28:00::
# lead%2:38:01::
# security%1:21:01::
# see%2:31:00::
# positive%3:00:01::
# force%1:04:01::
# bring%2:38:00::
# keep%2:42:07::
# professional%3:01:00::
# find%2:31:10::
# see%2:39:00::
# order%1:10:01::
# life%1:28:01::
# common%3:00:01::
# see%2:31:00::
# line%1:04:01::
# serve%2:41:13::
# follow%2:38:01::
# find%2:32:01::
# serve%2:41:02::
# extend%2:40:04::
# hold%2:36:00::
# national%5:00:00:public:00
# line%1:06:07::
# line%1:04:01::
# critical%5:00:00:indispensable:00
# major%3:00:07::
# see%2:39:00::
# serve%2:35:00::
# force%1:04:01::
# physical%5:00:02:material:01
# life%1:28:00::
# build%2:30:00::
# line%1:04:01::
# common%3:00:01::
# professional%3:00:01::
# point%1:15:00::
# line%1:04:01::
# extend%2:29:01::
# find%2:31:10::
# line%1:04:01::
# lead%2:38:00::
# keep%2:41:03::
# keep%2:40:00::
# find%2:32:01::
# keep%2:42:00::
# place%1:15:00::
# extend%2:40:04::
# major%3:00:06::
# position%1:04:01::
# active%3:00:07::
# follow%2:41:00::
# time%1:28:00::
# keep%2:40:00::
# critical%3:00:01::
# security%1:14:00::
# follow%2:38:00::
# see%2:31:00::
# place%1:04:01::
# case%1:10:01::
# line%1:04:01::
# force%1:18:00::
# security%1:12:00::
# see%2:31:00::
# serve%2:42:12::
# find%2:40:02::
# see%2:31:01::
# hold%2:40:00::
# major%3:00:06::
# serve%2:41:02::
# major%3:00:06::
# major%3:00:06::
# position%1:26:02::
# line%1:04:01::
# see%2:31:00::
# serve%2:42:03::
# see%2:39:00::
# line%1:06:03::
# see%2:31:00::
# bad%5:00:00:intense:00
# keep%2:42:00::
# order%1:10:01::
# professional%3:01:00::
# see%2:31:00::
# place%1:15:00::
# time%1:28:05::
# active%3:00:03::
# bad%5:00:00:intense:00
# hold%2:32:11::
# positive%3:00:01::
# follow%2:41:02::
# hold%2:40:04::
# follow%2:36:00::
# see%2:39:02::
# order%1:10:00::
# time%1:11:00::
# regular%5:00:00:standard:02
# line%1:04:01::
# extend%2:30:09::
# security%1:12:00::
# serve%2:33:00::
# case%1:10:01::
# physical%5:00:02:material:01
# case%1:26:00::
# security%1:12:00::
# keep%2:42:07::
# position%1:09:00::
# national%3:00:01::
# position%1:15:00::
# hold%2:40:00::
# keep%2:40:00::
# active%3:00:07::
# serve%2:42:12::
# line%1:06:07::
# lead%2:38:01::
# line%1:04:01::
# follow%2:41:00::
# major%3:00:02::
# line%1:04:01::
# hold%2:40:04::
# security%1:26:00::
# case%1:10:01::
# build%2:31:03::
# force%1:07:02::
# professional%5:00:00:white-collar:00
# order%1:14:00::
# regular%5:00:00:symmetrical:00
# see%2:31:00::
# line%1:14:02::
# see%2:39:00::
# order%1:10:00::
# security%1:21:01::
# lead%2:42:01::
# positive%3:00:01::
# line%1:04:01::
# force%1:07:01::
# line%1:04:01::
# lead%2:41:12::
# point%1:15:00::
# lead%2:42:12::
# common%3:00:02::
# serve%2:33:00::
# hold%2:40:02::
# position%1:26:00::
# see%2:31:00::
# see%2:31:00::
# active%5:00:00:operational:00
# lead%2:38:00::
# lead%2:38:01::
# see%2:31:00::
# point%1:15:00::
# place%1:26:00::
# point%1:15:00::
# line%1:04:01::
# extend%2:30:06::
# follow%2:36:00::
# critical%3:00:01::
# hold%2:40:04::
# build%2:30:10::
# active%5:00:00:involved:00
# case%1:11:00::
# see%2:31:00::
# hold%2:32:11::
# bring%2:36:00::
# line%1:04:01::
# serve%2:41:13::
# positive%3:00:01::
# force%1:18:00::
# life%1:28:01::
# case%1:11:00::
# physical%5:00:00:material:01
# see%2:31:00::
# hold%2:35:03::
# keep%2:41:03::
# build%2:36:09::
# bad%5:00:00:intense:00
# force%1:04:01::
# see%2:31:00::
# life%1:03:00::
# bring%2:35:04::
# serve%2:41:02::
# bad%5:00:00:intense:00
# see%2:31:00::
# see%2:31:00::
# serve%2:42:12::
# keep%2:41:03::
# common%3:00:02::
# see%2:31:00::
# order%1:10:00::
# bring%2:38:00::
# active%5:00:00:involved:00
# regular%5:00:00:scheduled:00
# line%1:04:01::
# lead%2:38:00::
# line%1:04:01::
# time%1:28:05::
# security%1:26:00::
# hold%2:40:00::
# positive%3:00:01::
# keep%2:40:00::
# professional%3:00:01::
# regular%5:00:00:standard:02
# keep%2:42:07::
# follow%2:38:00::
# find%2:39:02::
# follow%2:38:13::
# critical%3:00:03::
# common%3:00:01::
# position%1:09:00::
# keep%2:41:03::
# see%2:31:00::
# security%1:21:04::
# common%3:00:02::
# follow%2:36:00::
# lead%2:42:12::
# major%3:00:07::
# active%5:00:00:operational:00
# line%1:04:01::
# time%1:11:00::
# see%2:39:02::
# lead%2:41:12::
# keep%2:42:07::
# follow%2:38:00::
# bad%5:00:00:intense:00
# serve%2:42:03::
# physical%5:00:02:material:01
# major%3:00:06::
# hold%2:36:00::
# build%2:31:03::
# order%1:26:00::
# common%3:00:02::
# position%1:04:01::
# line%1:04:01::
# follow%2:38:13::
# keep%2:40:00::
# lead%2:41:12::
# see%2:31:00::
# professional%3:00:01::
# point%1:28:00::
# professional%3:01:01::
# active%5:00:00:involved:00
# line%1:04:01::
# national%3:01:00::
# national%3:01:00::
# serve%2:42:03::
# position%1:09:00::
# find%2:40:02::
# build%2:36:00::
# find%2:32:01::
# time%1:28:00::
# line%1:04:01::
# point%1:09:01::
# line%1:06:07::
# build%2:36:00::
# see%2:31:00::
# bad%5:00:00:intense:00
# hold%2:42:00::
# major%3:00:02::
# serve%2:42:03::
# lead%2:38:00::
# build%2:36:00::
# follow%2:38:00::
# line%1:04:01::
# serve%2:33:00::
# security%1:04:00::
# force%1:04:01::
# extend%2:30:02::
# regular%5:00:00:symmetrical:00
# line%1:06:07::
# regular%3:00:00::
# build%2:36:00::
# see%2:31:00::
# line%1:04:01::
# serve%2:33:00::
# line%1:04:01::
# case%1:26:00::
# follow%2:38:00::
# security%1:14:00::
# case%1:26:00::
# critical%3:00:01::
# line%1:04:01::
# life%1:28:00::
# national%5:00:00:domestic:00
# see%2:31:00::
# hold%2:35:03::
# lead%2:38:01::
# force%1:14:01::
# time%1:28:00::
# keep%2:41:03::
# follow%2:41:00::
# critical%5:00:00:indispensable:00
# professional%3:00:02::
# regular%5:00:00:symmetrical:00
# positive%5:00:00:advantageous:00
# bring%2:35:00::
# serve%2:33:00::
# force%1:04:01::
# bring%2:35:00::
# physical%3:00:00::
# keep%2:41:03::
# security%1:14:00::
# extend%2:30:06::
# see%2:31:00::
# keep%2:40:00::
# lead%2:41:00::
# time%1:11:00::
# place%1:15:00::
# extend%2:30:02::
# lead%2:41:00::
# see%2:31:00::
# time%1:28:06::
# serve%2:42:12::
# bad%5:00:00:intense:00
# bad%5:00:00:intense:00
# security%1:21:01::
# critical%3:00:02::
# hold%2:36:00::
# see%2:31:00::
# keep%2:42:00::
# line%1:04:01::
# hold%2:31:01::
# serve%2:42:03::
# line%1:06:07::
# positive%5:00:00:advantageous:00
# time%1:11:00::
# point%1:15:00::
# place%1:04:01::
# build%2:30:02::
# lead%2:41:12::
# national%3:01:00::
# serve%2:41:02::
# build%2:36:09::
# force%1:07:01::
# point%1:28:00::
# see%2:31:00::
# extend%2:40:04::
# force%1:18:00::
# lead%2:42:12::
# active%5:00:00:involved:00
# critical%3:00:01::
# critical%5:00:00:indispensable:00
# position%1:26:00::
# serve%2:33:00::
# physical%3:01:00::
# follow%2:38:01::
# position%1:15:00::
# bad%5:00:00:intense:00
# lead%2:42:03::
# case%1:26:00::
# follow%2:38:13::
# case%1:11:00::
# common%5:00:00:shared:00
# active%5:00:00:involved:00
# see%2:39:02::
# line%1:04:01::
# security%1:12:00::
# order%1:10:00::
# line%1:04:01::
# build%2:36:00::
# serve%2:33:00::
# keep%2:41:03::
# critical%3:00:01::
# point%1:09:01::
# extend%2:30:02::
# order%1:14:00::
# active%5:00:00:operational:00
# force%1:07:01::
# life%1:26:01::
# see%2:31:00::
# serve%2:42:03::
# security%1:14:00::
# lead%2:42:01::
# security%1:21:01::
# force%1:07:01::
# force%1:07:02::
# national%3:00:01::
# build%2:31:03::
# place%1:04:01::
# keep%2:40:01::
# physical%5:00:02:material:01
# see%2:31:00::
# bad%5:00:00:intense:00
# serve%2:33:00::
# see%2:31:00::
# line%1:04:01::
# line%1:04:01::
# professional%3:00:01::
# time%1:28:00::
# physical%5:00:00:forceful:00
# common%3:00:02::
# extend%2:29:01::
# force%1:07:01::
# security%1:14:00::
# serve%2:35:00::
# time%1:11:00::
# major%3:00:06::
# hold%2:42:00::
# line%1:04:01::
# extend%2:30:06::
# see%2:39:02::
# follow%2:41:00::
# line%1:04:01::
# lead%2:41:00::
# line%1:04:01::
# see%2:31:00::
# bring%2:36:00::
# major%3:00:06::
# national%3:00:00::
# hold%2:42:00::
# lead%2:42:12::
# place%1:26:00::
# keep%2:42:07::
# see%2:31:00::
# line%1:10:02::
# position%1:15:00::
# physical%5:00:02:material:01
# line%1:04:01::
# critical%3:00:03::
# force%1:14:01::
# life%1:28:02::
# serve%2:41:02::
# national%3:01:01::
# follow%2:38:00::
# see%2:31:00::
# see%2:31:00::
# physical%3:00:00::
# extend%2:40:04::
# regular%5:00:00:frequent:00
# life%1:28:02::
# bad%3:00:00::
# place%1:15:04::
# place%1:26:00::
# line%1:06:07::
# security%1:04:00::
# see%2:31:00::
# common%3:00:01::
# position%1:26:00::
# serve%2:42:00::
# keep%2:41:03::
# position%1:15:00::
# extend%2:40:04::
# see%2:31:00::
# see%2:31:00::
# see%2:39:02::
# position%1:09:00::
# force%1:04:01::
# life%1:28:00::
# common%5:00:00:familiar:02
# lead%2:38:01::
# major%3:00:02::
# bring%2:38:00::
# position%1:26:00::
# case%1:26:00::
# bring%2:36:00::
# serve%2:42:00::
# see%2:31:01::
# line%1:04:01::
# extend%2:30:09::
# bad%3:00:00::
# lead%2:38:00::
# keep%2:40:01::
# point%1:09:01::
# bring%2:35:00::
# serve%2:42:03::
# case%1:26:00::
# hold%2:40:00::
# national%5:00:00:public:00
# national%3:01:00::
# national%5:00:00:domestic:00
# force%1:14:01::
# line%1:04:01::
# life%1:28:01::
# regular%5:00:00:scheduled:00
# bring%2:35:04::
# case%1:11:00::
# follow%2:36:00::
# security%1:26:00::
# line%1:04:01::
# serve%2:35:00::
# position%1:15:00::
# critical%3:00:01::
# find%2:40:02::
# professional%3:01:00::
# keep%2:40:00::
# national%5:00:00:public:00
# security%1:26:00::
# keep%2:40:00::
# place%1:26:00::
# bad%3:00:00::
# life%1:28:01::
# common%3:00:02::
# time%1:28:00::
# line%1:04:01::
# serve%2:33:00::
# case%1:26:00::
# line%1:06:07::
# time%1:28:00::
# build%2:36:09::
# see%2:31:00::
# case%1:10:01::
# place%1:04:01::
# follow%2:36:00::
# common%5:00:00:shared:00
# case%1:26:00::
# place%1:15:00::
# place%1:15:04::
# life%1:26:01::
# see%2:39:00::
# time%1:28:06::
# serve%2:41:13::
# follow%2:36:00::
# security%1:10:00::
# bad%5:00:00:intense:00
# critical%3:00:03::
# active%3:00:03::
# time%1:28:06::
# see%2:31:00::
# see%2:31:00::
# hold%2:31:01::
# follow%2:41:00::
# follow%2:38:13::
# find%2:40:02::
# bring%2:36:01::
# hold%2:31:01::
# position%1:04:01::
# follow%2:41:00::
# major%3:00:06::
# hold%2:31:01::
# major%3:00:06::
# professional%3:01:01::
# extend%2:30:01::
# build%2:36:00::
# place%1:15:00::
# order%1:26:00::
# active%5:00:00:operational:00
# bad%5:00:00:intense:00
# physical%5:00:00:material:01
# keep%2:41:03::
# critical%3:00:01::
# major%3:00:06::
# build%2:30:00::
# hold%2:35:03::
# order%1:10:03::
# position%1:04:01::
# bring%2:35:00::
# line%1:04:01::
# lead%2:38:00::
# force%1:07:02::
# time%1:11:00::
# security%1:21:01::
# extend%2:30:06::
# regular%5:00:00:standard:02
# critical%3:00:01::
# life%1:03:00::
# see%2:39:00::
# regular%5:00:00:frequent:00
# regular%5:00:00:frequent:00
# keep%2:42:00::
# order%1:26:00::
# life%1:28:00::
# life%1:28:02::
# find%2:32:00::
# time%1:28:00::
# keep%2:42:07::
# see%2:31:00::
# point%1:09:01::
# line%1:04:01::
# major%3:00:02::
# hold%2:40:04::
# life%1:28:01::
# keep%2:41:03::
# hold%2:35:03::
# physical%5:00:00:forceful:00
# build%2:31:03::
# lead%2:38:01::
# serve%2:42:12::
# major%3:00:07::
# position%1:26:00::
# case%1:10:01::
# order%1:10:03::
# keep%2:42:00::
# build%2:31:03::
# follow%2:38:13::
# extend%2:30:01::
# hold%2:40:00::
# physical%5:00:02:material:01
# force%1:18:00::
# bring%2:35:00::
# time%1:28:05::
# bad%5:00:00:intense:00
# life%1:26:01::
# build%2:36:00::
# time%1:28:05::
# keep%2:41:03::
# follow%2:38:00::
# extend%2:30:06::
# see%2:39:02::
# line%1:04:01::
# time%1:28:05::
# follow%2:42:02::
# order%1:10:00::
# find%2:39:01::
# see%2:31:00::
# force%1:14:00::
# find%2:40:02::
# case%1:10:01::
# serve%2:41:02::
# hold%2:40:00::
# place%1:04:01::
# line%1:09:00::
# see%2:31:00::
# professional%3:01:01::
# place%1:15:00::
# case%1:11:00::
# hold%2:31:01::
# position%1:15:00::
# see%2:31:00::
# life%1:28:01::
# active%5:00:00:operational:00
# physical%3:00:00::
# force%1:14:00::
# regular%5:00:00:standard:02
# position%1:15:00::
# bring%2:36:00::
# major%3:00:02::
# keep%2:40:00::
# case%1:10:02::
# place%1:15:00::
# see%2:39:00::
# hold%2:40:04::
# active%3:00:03::
# major%3:00:02::
# keep%2:42:07::
# line%1:04:01::
# lead%2:41:12::
# position%1:09:00::
# keep%2:40:00::
# find%2:39:01::
# find%2:39:02::
# bring%2:36:00::
# follow%2:36:00::
# see%2:31:00::
# extend%2:29:01::
# build%2:36:00::
# find%2:32:00::
# hold%2:36:00::
# position%1:26:02::
# keep%2:41:03::
# serve%2:42:03::
# line%1:04:01::
# serve%2:42:12::
# active%5:00:00:operational:00
# bring%2:36:01::
# professional%3:00:01::
# follow%2:41:00::
# see%2:39:00::
# line%1:04:01::
# order%1:10:01::
# life%1:28:01::
# line%1:04:01::
# build%2:36:00::
# national%3:01:01::
# build%2:36:00::
# time%1:28:06::
# see%2:31:00::
# keep%2:41:03::
# professional%3:01:00::
# keep%2:42:07::
# order%1:10:00::
# physical%5:00:02:material:01
# positive%3:00:01::
# common%3:00:01::
# keep%2:40:00::
# point%1:15:00::
# position%1:26:02::
# position%1:04:01::
# line%1:04:01::
# life%1:28:02::
# extend%2:40:04::
# order%1:10:00::
# time%1:28:00::
# major%3:00:06::
# bring%2:35:04::
# lead%2:41:00::
# hold%2:31:01::
# professional%3:00:02::
# critical%5:00:00:indispensable:00
# physical%5:00:02:material:01
# professional%3:01:01::
# build%2:36:00::
# critical%3:00:03::
# professional%3:00:01::
# serve%2:42:03::
# bring%2:38:00::
# force%1:14:00::
# common%5:00:00:familiar:02
# hold%2:35:03::
# extend%2:30:02::
# line%1:04:01::
# active%3:00:07::
# life%1:28:01::
# line%1:06:09::
# line%1:04:01::
# place%1:04:01::
# common%5:00:00:familiar:02
# find%2:32:01::
# force%1:14:00::
# see%2:39:00::
# bad%5:00:00:intense:00
# hold%2:32:11::
# critical%3:00:03::
# hold%2:40:04::
# national%5:00:00:public:00
# hold%2:32:11::
# order%1:26:00::
# keep%2:41:03::
# national%3:00:01::
# national%3:00:01::
# extend%2:30:01::
# line%1:04:01::
# follow%2:40:00::
# common%5:00:00:shared:00
# time%1:11:00::
# see%2:31:00::
# bad%3:00:00::
# case%1:11:00::
# point%1:15:00::
# see%2:31:03::
# see%2:31:00::
# position%1:04:01::
# find%2:32:01::
# build%2:30:10::
# keep%2:40:00::
# bring%2:36:01::
# force%1:07:02::
# line%1:09:00::
# critical%3:00:02::
# extend%2:30:01::
# order%1:10:01::
# extend%2:30:06::
# line%1:04:01::
# find%2:31:10::
# time%1:28:00::
# major%3:00:02::
# line%1:04:01::
# follow%2:36:00::
# security%1:21:04::
# positive%5:00:00:advantageous:00
# bad%3:00:00::
# active%3:00:07::
# major%3:00:06::
# see%2:31:00::
# hold%2:40:00::
# case%1:04:00::
# position%1:26:02::
# follow%2:42:02::
# place%1:15:04::
# time%1:11:00::
# build%2:36:00::
# keep%2:41:03::
# active%3:00:03::
# keep%2:42:07::
# follow%2:41:00::
# security%1:26:00::
# line%1:04:01::
# lead%2:38:00::
# force%1:07:02::
# time%1:28:06::
# follow%2:41:00::
# major%3:00:07::
# serve%2:42:03::
# see%2:39:00::
# security%1:21:01::
# positive%3:00:04::
# case%1:26:00::
# line%1:04:01::
# see%2:31:00::
# serve%2:42:12::
# lead%2:41:12::
# national%3:01:00::
# point%1:15:00::
# line%1:04:01::
# extend%2:29:01::
# active%5:00:00:involved:00
# see%2:31:03::
# keep%2:41:03::
# position%1:26:02::
# physical%3:00:00::
# physical%5:00:02:material:01
# find%2:40:02::
# national%3:01:01::
# see%2:31:00::
# see%2:39:02::
# major%3:00:02::
# see%2:31:00::
# critical%3:00:01::
# place%1:15:04::
# positive%5:00:00:advantageous:00
# find%2:32:00::
# case%1:11:00::
# follow%2:41:00::
# life%1:28:01::
# professional%3:01:00::
# force%1:18:00::
# bring%2:35:00::
# regular%5:00:00:standard:02
# common%5:00:00:familiar:02
# extend%2:30:06::
# extend%2:30:06::
# hold%2:32:11::
# keep%2:40:00::
# keep%2:41:03::
# position%1:26:00::
# positive%3:00:01::
# security%1:12:00::
# lead%2:42:12::
# see%2:41:11::
# lead%2:42:12::
# active%3:00:03::
# order%1:10:00::
# time%1:28:00::
# common%5:00:00:familiar:02
# life%1:26:01::
# positive%3:00:01::
# see%2:31:00::
# order%1:10:01::
# line%1:04:01::
# extend%2:30:09::
# hold%2:40:00::
# extend%2:40:04::
# case%1:26:00::
# keep%2:42:00::
# bring%2:35:00::
# active%5:00:00:involved:00
# extend%2:30:06::
# keep%2:41:03::
# common%5:00:00:shared:00
# life%1:28:00::
# lead%2:41:12::
# critical%3:00:01::
# regular%5:00:00:scheduled:00
# national%5:00:00:public:00
# line%1:04:01::
# position%1:09:00::
# force%1:14:00::
# life%1:28:01::
# bring%2:35:00::
# physical%5:00:02:material:01
# active%3:00:03::
# keep%2:41:03::
# active%5:00:00:operational:00
# national%3:00:00::
# line%1:15:02::
# keep%2:40:00::
# keep%2:42:07::
# time%1:28:00::
# follow%2:38:00::
# keep%2:42:00::
# see%2:39:00::
# physical%5:00:00:material:01
# see%2:31:00::
# life%1:28:01::
# lead%2:42:12::
# keep%2:41:03::
# regular%5:00:00:normal:01
# professional%3:01:01::
# see%2:31:00::
# professional%3:00:01::
# place%1:15:04::
# see%2:31:00::
# point%1:28:00::
# force%1:14:01::
# keep%2:42:07::
# positive%5:00:00:plus:00
# keep%2:42:00::
# find%2:32:01::
# life%1:26:01::
# national%5:00:00:domestic:00
# bring%2:35:00::
# major%3:00:06::
# point%1:15:00::
# lead%2:41:12::
# find%2:32:00::
# follow%2:41:00::
# life%1:28:00::
# major%3:00:02::
# see%2:39:00::
# security%1:14:00::
# line%1:04:01::
# line%1:04:01::
# build%2:36:00::
# bring%2:35:04::
# build%2:36:00::
# keep%2:41:03::
# case%1:11:00::
# serve%2:42:03::
# life%1:28:00::
# follow%2:42:02::
# line%1:09:00::
# critical%3:00:02::
# major%3:00:02::
# keep%2:42:07::
# time%1:28:00::
# follow%2:38:00::
# hold%2:40:00::
# regular%5:00:00:scheduled:00

# %%
print(avg)
# Out:
# 0.7911336685488515
